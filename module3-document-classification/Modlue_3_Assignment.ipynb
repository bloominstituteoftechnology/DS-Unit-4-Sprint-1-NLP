# %%
import pandas as pd
from sklearn.pipeline import Pipeline
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import GridSearchCV
from sklearn.feature_extraction.text import CountVectorizer
import xgboost as xgb
import spacy
nlp = spacy.load("en_core_web_lg")

# %%
test_path = '/Users/nickburkhalter/Desktop/Lambda School/Unit 4/DS-Unit-4-Sprint-1-NLP/module3-document-classification/data/test.csv'
train_path = '/Users/nickburkhalter/Desktop/Lambda School/Unit 4/DS-Unit-4-Sprint-1-NLP/module3-document-classification/data/train.csv'

test = pd.read_csv(test_path)
train = pd.read_csv(train_path)

# %%
train = train.dropna()

# %%
print(train.shape)
train.head()
# Out:
# (2586, 3)
#    id                                        description  category
# 0   1  A marriage of 13 and 18 year old bourbons. A m...         2
# 1   2  There have been some legendary Bowmores from t...         1
# 2   3  This bottling celebrates master distiller Park...         2
# 3   4  What impresses me most is how this whisky evol...         1
# 4   9  A caramel-laden fruit bouquet, followed by une...         2

# %%
# TFIDF + RF 
# --------------------ROUND 1-----------------------
rf = RandomForestClassifier(random_state=42)
vect = TfidfVectorizer()

pipeline = Pipeline([('vect', vect), ('rf', rf)])

# %%
pipeline.fit(train['description'], train['category'])
# Out:
# /anaconda3/envs/u4s1env/lib/python3.7/site-packages/sklearn/ensemble/forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# Pipeline(memory=None,
#      steps=[('vect', TfidfVectorizer(analyzer='word', binary=False, decode_error='strict',
#         dtype=<class 'numpy.float64'>, encoding='utf-8', input='content',
#         lowercase=True, max_df=1.0, max_features=None, min_df=1,
#         ngram_range=(1, 1), norm='l2', preprocessor=None, smooth_idf=True,
# ...mators=10, n_jobs=None,
#             oob_score=False, random_state=42, verbose=0, warm_start=False))])

# %%
parameters = {
    'vect__max_df': (0.5, 0.75, 1.0),
    'vect__min_df': (.02, .05),
    'vect__max_features': ( 100, 500, 1000),
    'rf__n_estimators': (20, 100, 400),
}

grid_search = GridSearchCV(pipeline, parameters, cv=5, n_jobs=-1, verbose=10)

# %%
grid_search.fit(train.description, train.category)
# Out:
# Fitting 5 folds for each of 54 candidates, totalling 270 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   5 tasks      | elapsed:    3.4s
# [Parallel(n_jobs=-1)]: Done  10 tasks      | elapsed:    4.1s
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:    5.6s
# [Parallel(n_jobs=-1)]: Done  24 tasks      | elapsed:    6.6s
# [Parallel(n_jobs=-1)]: Done  33 tasks      | elapsed:    8.8s
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:   10.5s
# [Parallel(n_jobs=-1)]: Done  53 tasks      | elapsed:   13.0s
# [Parallel(n_jobs=-1)]: Done  64 tasks      | elapsed:   14.9s
# [Parallel(n_jobs=-1)]: Done  77 tasks      | elapsed:   18.0s
# [Parallel(n_jobs=-1)]: Done  90 tasks      | elapsed:   20.8s
# [Parallel(n_jobs=-1)]: Done 105 tasks      | elapsed:   27.3s
# [Parallel(n_jobs=-1)]: Done 120 tasks      | elapsed:   34.6s
# [Parallel(n_jobs=-1)]: Done 137 tasks      | elapsed:   42.7s
# [Parallel(n_jobs=-1)]: Done 154 tasks      | elapsed:   50.1s
# [Parallel(n_jobs=-1)]: Done 173 tasks      | elapsed:   59.6s
# [Parallel(n_jobs=-1)]: Done 192 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 213 tasks      | elapsed:  1.8min
# [Parallel(n_jobs=-1)]: Done 234 tasks      | elapsed:  2.3min
# [Parallel(n_jobs=-1)]: Done 257 tasks      | elapsed:  2.8min
# [Parallel(n_jobs=-1)]: Done 270 out of 270 | elapsed:  3.1min finished
# GridSearchCV(cv=5, error_score='raise-deprecating',
#        estimator=Pipeline(memory=None,
#      steps=[('vect', TfidfVectorizer(analyzer='word', binary=False, decode_error='strict',
#         dtype=<class 'numpy.float64'>, encoding='utf-8', input='content',
#         lowercase=True, max_df=1.0, max_features=None, min_df=1,
#         ngram_range=(1, 1), norm='l2', preprocessor=None, smooth_idf=True,
# ...mators=10, n_jobs=None,
#             oob_score=False, random_state=42, verbose=0, warm_start=False))]),
#        fit_params=None, iid='warn', n_jobs=-1,
#        param_grid={'vect__max_df': (0.5, 0.75, 1.0), 'vect__min_df': (0.02, 0.05), 'vect__max_features': (100, 500, 1000), 'rf__n_estimators': (20, 100, 400)},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring=None, verbose=10)

# %%
grid_search.best_score_
# Out:
# 0.8901778808971385

# %%
grid_search.predict(train['description'])
# Out:
# array([2, 1, 2, ..., 3, 1, 2])

# %%
y_pred = grid_search.predict(test['description'])

# %%
y_submission = pd.read_csv('/Users/nickburkhalter/Desktop/Lambda School/Unit 4/DS-Unit-4-Sprint-1-NLP/module3-document-classification/data/sample_submission.csv')
assert y_submission.shape[0] == y_pred.shape[0]

y_submission.category = y_pred.astype(int)
y_submission.to_csv('pred1.csv', index=None)

# %%
# TFIDF + SVD + SGDC
#-------------------ROUND 2---------------------
from sklearn.decomposition import TruncatedSVD
from sklearn.linear_model import SGDClassifier


vect = TfidfVectorizer()
svd = TruncatedSVD(algorithm='randomized',
                   random_state=42)
sgdc = SGDClassifier(random_state=42)

pipe2 = Pipeline([('vect', vect), 
                 ('svd', svd), 
                 ('sgdc', sgdc)])

param2 = {
    #'vect__max_df': (1.0,),
    #'vect__min_df': (.02,),
    'svd__n_components': (100, 300, 1000),
    'sgdc__max_iter': (300, 1000, 3000),
}

grid2 = GridSearchCV(pipe2, param2, cv=5, n_jobs=-1, verbose=1000)

# %%
grid2.fit(train.description, train.category)
# Out:
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2068,), dtype=int64).
# Pickling array (shape=(518,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2068,), dtype=int64).
# Pickling array (shape=(518,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2069,), dtype=int64).
# Pickling array (shape=(517,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2069,), dtype=int64).
# Pickling array (shape=(517,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2070,), dtype=int64).
# Pickling array (shape=(516,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    1.8s
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    1.8s
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2068,), dtype=int64).
# Pickling array (shape=(518,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    1.9s
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2068,), dtype=int64).
# Pickling array (shape=(518,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:    2.0s
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2069,), dtype=int64).
# Pickling array (shape=(517,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2069,), dtype=int64).
# Pickling array (shape=(517,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done   5 tasks      | elapsed:    3.9s
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2070,), dtype=int64).
# Pickling array (shape=(516,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done   6 tasks      | elapsed:    6.2s
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2068,), dtype=int64).
# Pickling array (shape=(518,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done   7 tasks      | elapsed:    6.2s
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2068,), dtype=int64).
# Pickling array (shape=(518,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done   8 tasks      | elapsed:    6.3s
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2069,), dtype=int64).
# Pickling array (shape=(517,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:    8.0s
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2069,), dtype=int64).
# Pickling array (shape=(517,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  10 tasks      | elapsed:   10.5s
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2070,), dtype=int64).
# Pickling array (shape=(516,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  11 tasks      | elapsed:   23.2s
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2068,), dtype=int64).
# Pickling array (shape=(518,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  12 tasks      | elapsed:   23.3s
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2068,), dtype=int64).
# Pickling array (shape=(518,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  13 tasks      | elapsed:   24.7s
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2069,), dtype=int64).
# Pickling array (shape=(517,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  14 tasks      | elapsed:   27.1s
# [Parallel(n_jobs=-1)]: Done  15 tasks      | elapsed:   27.2s
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2069,), dtype=int64).
# Pickling array (shape=(517,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2070,), dtype=int64).
# Pickling array (shape=(516,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  16 tasks      | elapsed:   28.7s
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2068,), dtype=int64).
# Pickling array (shape=(518,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:   32.8s
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2068,), dtype=int64).
# Pickling array (shape=(518,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  18 tasks      | elapsed:   32.9s
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2069,), dtype=int64).
# Pickling array (shape=(517,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  19 tasks      | elapsed:   35.0s
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2069,), dtype=int64).
# Pickling array (shape=(517,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  20 tasks      | elapsed:   45.7s
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2070,), dtype=int64).
# Pickling array (shape=(516,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed:   47.0s
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2068,), dtype=int64).
# Pickling array (shape=(518,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  22 tasks      | elapsed:   47.2s
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2068,), dtype=int64).
# Pickling array (shape=(518,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  23 tasks      | elapsed:   49.2s
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2069,), dtype=int64).
# Pickling array (shape=(517,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  24 tasks      | elapsed:   58.0s
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2069,), dtype=int64).
# Pickling array (shape=(517,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  25 tasks      | elapsed:   58.8s
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2070,), dtype=int64).
# Pickling array (shape=(516,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  26 tasks      | elapsed:  1.4min
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2068,), dtype=int64).
# Pickling array (shape=(518,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  27 tasks      | elapsed:  1.4min
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2068,), dtype=int64).
# Pickling array (shape=(518,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  28 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=-1)]: Done  29 tasks      | elapsed:  1.5min
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2069,), dtype=int64).
# Pickling array (shape=(517,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2069,), dtype=int64).
# Pickling array (shape=(517,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  30 tasks      | elapsed:  1.5min
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2070,), dtype=int64).
# Pickling array (shape=(516,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  31 tasks      | elapsed:  1.7min
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).[Parallel(n_jobs=-1)]: Done  32 tasks      | elapsed:  1.7min
#
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2068,), dtype=int64).
# Pickling array (shape=(518,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2068,), dtype=int64).
# Pickling array (shape=(518,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  33 tasks      | elapsed:  1.7min
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2069,), dtype=int64).
# Pickling array (shape=(517,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:  1.8min
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2069,), dtype=int64).
# Pickling array (shape=(517,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  35 tasks      | elapsed:  1.8min
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2070,), dtype=int64).
# Pickling array (shape=(516,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  36 tasks      | elapsed:  1.9min
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2068,), dtype=int64).
# Pickling array (shape=(518,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  37 tasks      | elapsed:  2.0min
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2068,), dtype=int64).
# Pickling array (shape=(518,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  38 tasks      | elapsed:  2.1min
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2069,), dtype=int64).
# Pickling array (shape=(517,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  39 out of  45 | elapsed:  2.1min remaining:   19.5s
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2069,), dtype=int64).
# Pickling array (shape=(517,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  40 out of  45 | elapsed:  2.3min remaining:   17.1s
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2070,), dtype=int64).
# Pickling array (shape=(516,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  41 out of  45 | elapsed:  2.9min remaining:   16.8s
# [Parallel(n_jobs=-1)]: Done  42 out of  45 | elapsed:  3.0min remaining:   12.8s
# [Parallel(n_jobs=-1)]: Done  43 out of  45 | elapsed:  3.0min remaining:    8.4s
# [Parallel(n_jobs=-1)]: Done  45 out of  45 | elapsed:  3.6min remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  45 out of  45 | elapsed:  3.6min finished
# /anaconda3/envs/u4s1env/lib/python3.7/site-packages/sklearn/linear_model/stochastic_gradient.py:183: FutureWarning: max_iter and tol parameters have been added in SGDClassifier in 0.19. If max_iter is set but tol is left unset, the default value for tol in 0.19 and 0.20 will be None (which is equivalent to -infinity, so it has no effect) but will change in 0.21 to 1e-3. Specify tol to silence this warning.
#   FutureWarning)
# GridSearchCV(cv=5, error_score='raise-deprecating',
#        estimator=Pipeline(memory=None,
#      steps=[('vect', TfidfVectorizer(analyzer='word', binary=False, decode_error='strict',
#         dtype=<class 'numpy.float64'>, encoding='utf-8', input='content',
#         lowercase=True, max_df=1.0, max_features=None, min_df=1,
#         ngram_range=(1, 1), norm='l2', preprocessor=None, smooth_idf=True,
# ...dom_state=42, shuffle=True, tol=None,
#        validation_fraction=0.1, verbose=0, warm_start=False))]),
#        fit_params=None, iid='warn', n_jobs=-1,
#        param_grid={'svd__n_components': (100, 300, 1000), 'sgdc__max_iter': (300, 1000, 3000)},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring=None, verbose=1000)

# %%
grid2.best_score_
# Out:
# 0.934261407579273

# %%
grid2.predict(train['description'])
# Out:
# array([2, 1, 2, ..., 3, 1, 2])

# %%
y_pred2 = grid2.predict(test['description'])

# %%
y_submission = pd.read_csv('/Users/nickburkhalter/Desktop/Lambda School/Unit 4/DS-Unit-4-Sprint-1-NLP/module3-document-classification/data/sample_submission.csv')
assert y_submission.shape[0] == y_pred2.shape[0]

y_submission.category = y_pred2.astype(int)
y_submission.to_csv('pred2.csv', index=None)

# %%
# TFIDF + SGDC
#-------------------ROUND 3---------------------
sgdc = SGDClassifier()
pipe3 = Pipeline([('vect', vect), 
                  ('sgdc', sgdc)])

param3 = {
    'vect__max_df': (0.5, 0.75, 1.0),
    'vect__min_df': (.02, .05),
    'vect__max_features': ( 100, 500, 1000),
    'sgdc__max_iter': (300, 1000, 3000),
}

grid3 = GridSearchCV(pipe3, param3, cv=5, n_jobs=-1, verbose=100)

# %%
grid3.fit(train['description'], train['category'])
# Out:
# Fitting 5 folds for each of 54 candidates, totalling 270 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2068,), dtype=int64).
# Pickling array (shape=(518,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2068,), dtype=int64).
# Pickling array (shape=(518,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2069,), dtype=int64).
# Pickling array (shape=(517,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2069,), dtype=int64).
# Pickling array (shape=(517,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2070,), dtype=int64).
# Pickling array (shape=(516,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    2.5s
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    2.5s
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    2.5s
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2068,), dtype=int64).
# Pickling array (shape=(518,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).[Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:    2.6s
#
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2068,), dtype=int64).
# Pickling array (shape=(518,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2069,), dtype=int64).
# Pickling array (shape=(517,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2069,), dtype=int64).
# Pickling array (shape=(517,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done   5 tasks      | elapsed:    3.3s
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2070,), dtype=int64).
# Pickling array (shape=(516,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done   6 tasks      | elapsed:    3.3s
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2068,), dtype=int64).
# Pickling array (shape=(518,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done   7 tasks      | elapsed:    3.4s
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2068,), dtype=int64).
# Pickling array (shape=(518,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done   8 tasks      | elapsed:    3.4s
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2069,), dtype=int64).
# Pickling array (shape=(517,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:    4.6s
# [Parallel(n_jobs=-1)]: Done  10 tasks      | elapsed:    4.6s
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2069,), dtype=int64).
# Pickling array (shape=(517,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2070,), dtype=int64).
# Pickling array (shape=(516,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  11 tasks      | elapsed:    4.7s
# [Parallel(n_jobs=-1)]: Done  12 tasks      | elapsed:    4.7s
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2068,), dtype=int64).
# Pickling array (shape=(518,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2068,), dtype=int64).
# Pickling array (shape=(518,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  13 tasks      | elapsed:    5.6s
# [Parallel(n_jobs=-1)]: Done  14 tasks      | elapsed:    5.6s
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2069,), dtype=int64).
# Pickling array (shape=(517,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2069,), dtype=int64).
# Pickling array (shape=(517,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  15 tasks      | elapsed:    5.7s
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2070,), dtype=int64).
# Pickling array (shape=(516,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  16 tasks      | elapsed:    5.8s
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2068,), dtype=int64).
# Pickling array (shape=(518,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:    6.7s
# [Parallel(n_jobs=-1)]: Done  18 tasks      | elapsed:    6.7s
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2068,), dtype=int64).
# Pickling array (shape=(518,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  19 tasks      | elapsed:    6.7s
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2069,), dtype=int64).
# Pickling array (shape=(517,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2069,), dtype=int64).
# Pickling array (shape=(517,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  20 tasks      | elapsed:    6.9s
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2070,), dtype=int64).
# Pickling array (shape=(516,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed:    7.7s
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2068,), dtype=int64).
# Pickling array (shape=(518,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  22 tasks      | elapsed:    7.8s
# [Parallel(n_jobs=-1)]: Done  23 tasks      | elapsed:    7.8s
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2068,), dtype=int64).
# Pickling array (shape=(518,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2069,), dtype=int64).
# Pickling array (shape=(517,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  24 tasks      | elapsed:    8.1s
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2069,), dtype=int64).
# Pickling array (shape=(517,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  25 tasks      | elapsed:    8.8s
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2070,), dtype=int64).
# Pickling array (shape=(516,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  26 tasks      | elapsed:    8.8s
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).[Parallel(n_jobs=-1)]: Done  27 tasks      | elapsed:    8.8s
#
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2068,), dtype=int64).
# Pickling array (shape=(518,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2068,), dtype=int64).
# Pickling array (shape=(518,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  28 tasks      | elapsed:    9.1s
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2069,), dtype=int64).
# Pickling array (shape=(517,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  29 tasks      | elapsed:    9.8s
# [Parallel(n_jobs=-1)]: Done  30 tasks      | elapsed:    9.8s
# [Parallel(n_jobs=-1)]: Done  31 tasks      | elapsed:    9.8s
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2069,), dtype=int64).
# Pickling array (shape=(517,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2070,), dtype=int64).
# Pickling array (shape=(516,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2068,), dtype=int64).
# Pickling array (shape=(518,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  32 tasks      | elapsed:   10.1s
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2068,), dtype=int64).
# Pickling array (shape=(518,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  33 tasks      | elapsed:   10.9s
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   10.9s
# [Parallel(n_jobs=-1)]: Done  35 tasks      | elapsed:   10.9s
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2069,), dtype=int64).
# Pickling array (shape=(517,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2069,), dtype=int64).
# Pickling array (shape=(517,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2070,), dtype=int64).
# Pickling array (shape=(516,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  36 tasks      | elapsed:   11.3s
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2068,), dtype=int64).
# Pickling array (shape=(518,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  37 tasks      | elapsed:   11.9s
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2068,), dtype=int64).
# Pickling array (shape=(518,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  38 tasks      | elapsed:   11.9s
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2069,), dtype=int64).
# Pickling array (shape=(517,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  39 tasks      | elapsed:   12.0s
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2069,), dtype=int64).
# Pickling array (shape=(517,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  40 tasks      | elapsed:   12.1s
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2070,), dtype=int64).
# Pickling array (shape=(516,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  41 tasks      | elapsed:   12.9s
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).[Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:   13.0s
#
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2068,), dtype=int64).
# Pickling array (shape=(518,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2068,), dtype=int64).
# Pickling array (shape=(518,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  43 tasks      | elapsed:   13.1s
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2069,), dtype=int64).
# Pickling array (shape=(517,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  44 tasks      | elapsed:   13.3s
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2069,), dtype=int64).
# Pickling array (shape=(517,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  45 tasks      | elapsed:   14.2s
# [Parallel(n_jobs=-1)]: Done  46 tasks      | elapsed:   14.2s
# [Parallel(n_jobs=-1)]: Done  47 tasks      | elapsed:   14.2s
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2070,), dtype=int64).
# Pickling array (shape=(516,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2068,), dtype=int64).
# Pickling array (shape=(518,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2068,), dtype=int64).
# Pickling array (shape=(518,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  48 tasks      | elapsed:   14.4s
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2069,), dtype=int64).
# Pickling array (shape=(517,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  49 tasks      | elapsed:   15.2s
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2069,), dtype=int64).
# Pickling array (shape=(517,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  50 tasks      | elapsed:   15.2s
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2070,), dtype=int64).
# Pickling array (shape=(516,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  51 tasks      | elapsed:   15.5s
# [Parallel(n_jobs=-1)]: Done  52 tasks      | elapsed:   15.5s
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2068,), dtype=int64).
# Pickling array (shape=(518,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2068,), dtype=int64).
# Pickling array (shape=(518,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  53 tasks      | elapsed:   16.4s
# [Parallel(n_jobs=-1)]: Done  54 tasks      | elapsed:   16.5s
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2069,), dtype=int64).
# Pickling array (shape=(517,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2069,), dtype=int64).
# Pickling array (shape=(517,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  55 tasks      | elapsed:   16.6s
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2070,), dtype=int64).
# Pickling array (shape=(516,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  56 tasks      | elapsed:   16.7s
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2068,), dtype=int64).
# Pickling array (shape=(518,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  57 tasks      | elapsed:   17.4s
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2068,), dtype=int64).
# Pickling array (shape=(518,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  58 tasks      | elapsed:   17.6s
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2069,), dtype=int64).
# Pickling array (shape=(517,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  59 tasks      | elapsed:   17.8s
# [Parallel(n_jobs=-1)]: Done  60 tasks      | elapsed:   17.8s
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2069,), dtype=int64).
# Pickling array (shape=(517,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2070,), dtype=int64).
# Pickling array (shape=(516,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  61 tasks      | elapsed:   18.4s
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2068,), dtype=int64).
# Pickling array (shape=(518,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  62 tasks      | elapsed:   18.7s
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2068,), dtype=int64).
# Pickling array (shape=(518,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  63 tasks      | elapsed:   18.8s
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2069,), dtype=int64).
# Pickling array (shape=(517,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  64 tasks      | elapsed:   18.8s
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2069,), dtype=int64).
# Pickling array (shape=(517,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  65 tasks      | elapsed:   19.6s
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2070,), dtype=int64).
# Pickling array (shape=(516,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  66 tasks      | elapsed:   19.8s
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2068,), dtype=int64).
# Pickling array (shape=(518,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  67 tasks      | elapsed:   19.9s
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2068,), dtype=int64).
# Pickling array (shape=(518,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  68 tasks      | elapsed:   19.9s
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2069,), dtype=int64).
# Pickling array (shape=(517,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  69 tasks      | elapsed:   20.6s
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2069,), dtype=int64).
# Pickling array (shape=(517,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  70 tasks      | elapsed:   20.9s
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2070,), dtype=int64).
# Pickling array (shape=(516,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  71 tasks      | elapsed:   21.1s
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2068,), dtype=int64).
# Pickling array (shape=(518,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  72 tasks      | elapsed:   21.2s
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2068,), dtype=int64).
# Pickling array (shape=(518,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  73 tasks      | elapsed:   21.7s
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2069,), dtype=int64).
# Pickling array (shape=(517,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  74 tasks      | elapsed:   22.0s
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2069,), dtype=int64).
# Pickling array (shape=(517,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  75 tasks      | elapsed:   22.2s
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2070,), dtype=int64).
# Pickling array (shape=(516,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  76 tasks      | elapsed:   22.3s
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2068,), dtype=int64).
# Pickling array (shape=(518,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  77 tasks      | elapsed:   22.8s
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2068,), dtype=int64).
# Pickling array (shape=(518,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  78 tasks      | elapsed:   23.1s
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2069,), dtype=int64).
# Pickling array (shape=(517,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  79 tasks      | elapsed:   23.3s
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2069,), dtype=int64).
# Pickling array (shape=(517,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  80 tasks      | elapsed:   23.4s
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2070,), dtype=int64).
# Pickling array (shape=(516,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  81 tasks      | elapsed:   23.9s
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2068,), dtype=int64).
# Pickling array (shape=(518,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  82 tasks      | elapsed:   24.3s
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2068,), dtype=int64).
# Pickling array (shape=(518,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  83 tasks      | elapsed:   24.6s
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2069,), dtype=int64).
# Pickling array (shape=(517,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  84 tasks      | elapsed:   24.7s
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2069,), dtype=int64).
# Pickling array (shape=(517,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  85 tasks      | elapsed:   25.2s
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2070,), dtype=int64).
# Pickling array (shape=(516,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  86 tasks      | elapsed:   25.4s
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2068,), dtype=int64).
# Pickling array (shape=(518,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  87 tasks      | elapsed:   25.7s
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2068,), dtype=int64).
# Pickling array (shape=(518,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  88 tasks      | elapsed:   25.8s
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2069,), dtype=int64).
# Pickling array (shape=(517,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  89 tasks      | elapsed:   26.2s
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2069,), dtype=int64).
# Pickling array (shape=(517,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  90 tasks      | elapsed:   26.4s
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2070,), dtype=int64).
# Pickling array (shape=(516,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  91 tasks      | elapsed:   27.3s
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2068,), dtype=int64).
# Pickling array (shape=(518,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  92 tasks      | elapsed:   27.4s
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2068,), dtype=int64).
# Pickling array (shape=(518,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  93 tasks      | elapsed:   27.8s
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2069,), dtype=int64).
# Pickling array (shape=(517,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  94 tasks      | elapsed:   28.0s
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2069,), dtype=int64).
# Pickling array (shape=(517,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  95 tasks      | elapsed:   28.9s
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2070,), dtype=int64).
# Pickling array (shape=(516,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  96 tasks      | elapsed:   29.1s
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2068,), dtype=int64).
# Pickling array (shape=(518,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  97 tasks      | elapsed:   29.4s
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2068,), dtype=int64).
# Pickling array (shape=(518,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  98 tasks      | elapsed:   29.7s
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2069,), dtype=int64).
# Pickling array (shape=(517,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  99 tasks      | elapsed:   30.5s
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2069,), dtype=int64).
# Pickling array (shape=(517,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done 100 tasks      | elapsed:   30.6s
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2070,), dtype=int64).
# Pickling array (shape=(516,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done 101 tasks      | elapsed:   31.4s
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2068,), dtype=int64).
# Pickling array (shape=(518,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done 102 tasks      | elapsed:   31.6s
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2068,), dtype=int64).
# Pickling array (shape=(518,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done 103 tasks      | elapsed:   32.5s
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2069,), dtype=int64).
# Pickling array (shape=(517,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done 104 tasks      | elapsed:   32.6s
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2069,), dtype=int64).
# Pickling array (shape=(517,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done 105 tasks      | elapsed:   33.2s
# [Parallel(n_jobs=-1)]: Done 106 tasks      | elapsed:   33.2s
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2070,), dtype=int64).
# Pickling array (shape=(516,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2068,), dtype=int64).
# Pickling array (shape=(518,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done 107 tasks      | elapsed:   34.2s
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2068,), dtype=int64).
# Pickling array (shape=(518,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done 108 tasks      | elapsed:   34.4s
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2069,), dtype=int64).
# Pickling array (shape=(517,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done 109 tasks      | elapsed:   34.9s
# [Parallel(n_jobs=-1)]: Done 110 tasks      | elapsed:   35.0s
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2069,), dtype=int64).
# Pickling array (shape=(517,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2070,), dtype=int64).
# Pickling array (shape=(516,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done 111 tasks      | elapsed:   36.2s
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2068,), dtype=int64).
# Pickling array (shape=(518,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done 112 tasks      | elapsed:   36.3s
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2068,), dtype=int64).
# Pickling array (shape=(518,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done 113 tasks      | elapsed:   37.0s
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2069,), dtype=int64).
# Pickling array (shape=(517,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done 114 tasks      | elapsed:   37.2s
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2069,), dtype=int64).
# Pickling array (shape=(517,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done 115 tasks      | elapsed:   38.2s
# [Parallel(n_jobs=-1)]: Done 116 tasks      | elapsed:   38.2s
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2070,), dtype=int64).
# Pickling array (shape=(516,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2068,), dtype=int64).
# Pickling array (shape=(518,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done 117 tasks      | elapsed:   38.7s
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2068,), dtype=int64).
# Pickling array (shape=(518,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done 118 tasks      | elapsed:   38.9s
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2069,), dtype=int64).
# Pickling array (shape=(517,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done 119 tasks      | elapsed:   39.8s
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2069,), dtype=int64).
# Pickling array (shape=(517,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done 120 tasks      | elapsed:   39.9s
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2070,), dtype=int64).
# Pickling array (shape=(516,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done 121 tasks      | elapsed:   40.4s
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2068,), dtype=int64).
# Pickling array (shape=(518,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done 122 tasks      | elapsed:   40.5s
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2068,), dtype=int64).
# Pickling array (shape=(518,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done 123 tasks      | elapsed:   41.6s
# [Parallel(n_jobs=-1)]: Done 124 tasks      | elapsed:   41.6s
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# ...
# [Parallel(n_jobs=-1)]: Done 227 tasks      | elapsed:  1.9min
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2068,), dtype=int64).
# Pickling array (shape=(518,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done 228 tasks      | elapsed:  1.9min
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2069,), dtype=int64).
# Pickling array (shape=(517,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done 229 tasks      | elapsed:  2.0min
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2069,), dtype=int64).
# Pickling array (shape=(517,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done 230 tasks      | elapsed:  2.0min
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2070,), dtype=int64).
# Pickling array (shape=(516,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done 231 tasks      | elapsed:  2.0min
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2068,), dtype=int64).
# Pickling array (shape=(518,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done 232 tasks      | elapsed:  2.0min
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2068,), dtype=int64).
# Pickling array (shape=(518,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done 233 tasks      | elapsed:  2.1min
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2069,), dtype=int64).
# Pickling array (shape=(517,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done 234 tasks      | elapsed:  2.1min
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2069,), dtype=int64).
# Pickling array (shape=(517,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done 235 tasks      | elapsed:  2.1min
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2070,), dtype=int64).
# Pickling array (shape=(516,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done 236 tasks      | elapsed:  2.1min
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2068,), dtype=int64).
# Pickling array (shape=(518,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done 237 tasks      | elapsed:  2.2min
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2068,), dtype=int64).
# Pickling array (shape=(518,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done 238 tasks      | elapsed:  2.2min
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2069,), dtype=int64).
# Pickling array (shape=(517,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done 239 tasks      | elapsed:  2.2min
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2069,), dtype=int64).
# Pickling array (shape=(517,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done 240 tasks      | elapsed:  2.2min
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2070,), dtype=int64).
# Pickling array (shape=(516,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done 241 tasks      | elapsed:  2.2min
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2068,), dtype=int64).
# Pickling array (shape=(518,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done 242 tasks      | elapsed:  2.2min
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2068,), dtype=int64).
# Pickling array (shape=(518,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done 243 tasks      | elapsed:  2.2min
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2069,), dtype=int64).
# Pickling array (shape=(517,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done 244 tasks      | elapsed:  2.3min
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2069,), dtype=int64).
# Pickling array (shape=(517,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done 245 tasks      | elapsed:  2.3min
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2070,), dtype=int64).
# Pickling array (shape=(516,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done 246 tasks      | elapsed:  2.3min
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2068,), dtype=int64).
# Pickling array (shape=(518,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done 247 tasks      | elapsed:  2.3min
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2068,), dtype=int64).
# Pickling array (shape=(518,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done 248 tasks      | elapsed:  2.3min
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2069,), dtype=int64).
# Pickling array (shape=(517,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done 249 tasks      | elapsed:  2.4min
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2069,), dtype=int64).
# Pickling array (shape=(517,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done 250 tasks      | elapsed:  2.4min
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2070,), dtype=int64).
# Pickling array (shape=(516,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done 251 tasks      | elapsed:  2.4min
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2068,), dtype=int64).
# Pickling array (shape=(518,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done 252 tasks      | elapsed:  2.4min
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2068,), dtype=int64).
# Pickling array (shape=(518,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done 253 tasks      | elapsed:  2.4min
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2069,), dtype=int64).
# Pickling array (shape=(517,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done 254 tasks      | elapsed:  2.5min
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2069,), dtype=int64).
# Pickling array (shape=(517,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done 255 tasks      | elapsed:  2.5min
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2070,), dtype=int64).
# Pickling array (shape=(516,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done 256 tasks      | elapsed:  2.5min
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2068,), dtype=int64).
# Pickling array (shape=(518,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done 257 tasks      | elapsed:  2.5min
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2068,), dtype=int64).
# Pickling array (shape=(518,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done 258 tasks      | elapsed:  2.5min
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2069,), dtype=int64).
# Pickling array (shape=(517,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done 259 tasks      | elapsed:  2.5min
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2069,), dtype=int64).
# Pickling array (shape=(517,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done 260 tasks      | elapsed:  2.5min
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2070,), dtype=int64).
# Pickling array (shape=(516,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done 261 tasks      | elapsed:  2.6min
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2068,), dtype=int64).
# Pickling array (shape=(518,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done 262 tasks      | elapsed:  2.6min
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2068,), dtype=int64).
# Pickling array (shape=(518,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done 263 tasks      | elapsed:  2.6min
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2069,), dtype=int64).
# Pickling array (shape=(517,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2069,), dtype=int64).
# Pickling array (shape=(517,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2070,), dtype=int64).
# Pickling array (shape=(516,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done 266 out of 270 | elapsed:  2.7min remaining:    2.4s
# [Parallel(n_jobs=-1)]: Done 270 out of 270 | elapsed:  2.7min finished
# /anaconda3/envs/u4s1env/lib/python3.7/site-packages/sklearn/linear_model/stochastic_gradient.py:183: FutureWarning: max_iter and tol parameters have been added in SGDClassifier in 0.19. If max_iter is set but tol is left unset, the default value for tol in 0.19 and 0.20 will be None (which is equivalent to -infinity, so it has no effect) but will change in 0.21 to 1e-3. Specify tol to silence this warning.
#   FutureWarning)
# GridSearchCV(cv=5, error_score='raise-deprecating',
#        estimator=Pipeline(memory=None,
#      steps=[('vect', TfidfVectorizer(analyzer='word', binary=False, decode_error='strict',
#         dtype=<class 'numpy.float64'>, encoding='utf-8', input='content',
#         lowercase=True, max_df=1.0, max_features=None, min_df=1,
#         ngram_range=(1, 1), norm='l2', preprocessor=None, smooth_idf=True,
# ...m_state=None, shuffle=True, tol=None,
#        validation_fraction=0.1, verbose=0, warm_start=False))]),
#        fit_params=None, iid='warn', n_jobs=-1,
#        param_grid={'vect__max_df': (0.5, 0.75, 1.0), 'vect__min_df': (0.02, 0.05), 'vect__max_features': (100, 500, 1000), 'sgdc__max_iter': (300, 1000, 3000)},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring=None, verbose=100)

# %%
grid3.best_score_
# Out:
# 0.9075792730085074

# %%
y_pred3 = grid3.predict(test['description'])

# %%
y_submission = pd.read_csv('/Users/nickburkhalter/Desktop/Lambda School/Unit 4/DS-Unit-4-Sprint-1-NLP/module3-document-classification/data/sample_submission.csv')
assert y_submission.shape[0] == y_pred3.shape[0]

y_submission.category = y_pred3.astype(int)
y_submission.to_csv('pred3.csv', index=None)

# %%
# TFIDF + SVD + SGDC
# Remove stopwords
#-------------------ROUND 4---------------------
from sklearn.decomposition import TruncatedSVD
from sklearn.linear_model import SGDClassifier


vect = TfidfVectorizer(stop_words='english')
svd = TruncatedSVD(algorithm='randomized',
                   random_state=42)
sgdc = SGDClassifier(random_state=42)

pipe4 = Pipeline([('vect', vect), 
                 ('svd', svd), 
                 ('sgdc', sgdc)])

param4 = {
    #'vect__max_df': (1.0,),
    #'vect__min_df': (.02,),
    'svd__n_components': (100, 300, 1000),
    'sgdc__max_iter': (300, 1000, 3000),
}

grid4 = GridSearchCV(pipe4, param4, cv=5, n_jobs=-1, verbose=1000)

# %%
grid4.fit(train['description'], train['category'])
# Out:
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2068,), dtype=int64).
# Pickling array (shape=(518,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2068,), dtype=int64).
# Pickling array (shape=(518,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2069,), dtype=int64).
# Pickling array (shape=(517,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2069,), dtype=int64).
# Pickling array (shape=(517,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2070,), dtype=int64).
# Pickling array (shape=(516,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    3.8s
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    3.8s
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2068,), dtype=int64).
# Pickling array (shape=(518,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    3.9s
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2068,), dtype=int64).
# Pickling array (shape=(518,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:    3.9s
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2069,), dtype=int64).
# Pickling array (shape=(517,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2069,), dtype=int64).
# Pickling array (shape=(517,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done   5 tasks      | elapsed:    5.8s
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2070,), dtype=int64).
# Pickling array (shape=(516,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done   6 tasks      | elapsed:    8.2s
# [Parallel(n_jobs=-1)]: Done   7 tasks      | elapsed:    8.3s
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2068,), dtype=int64).
# Pickling array (shape=(518,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2068,), dtype=int64).
# Pickling array (shape=(518,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done   8 tasks      | elapsed:    8.4s
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2069,), dtype=int64).
# Pickling array (shape=(517,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:   10.0s
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2069,), dtype=int64).
# Pickling array (shape=(517,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  10 tasks      | elapsed:   12.5s
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2070,), dtype=int64).
# Pickling array (shape=(516,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  11 tasks      | elapsed:   27.4s
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2068,), dtype=int64).
# Pickling array (shape=(518,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  12 tasks      | elapsed:   27.7s
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2068,), dtype=int64).
# Pickling array (shape=(518,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  13 tasks      | elapsed:   29.2s
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2069,), dtype=int64).
# Pickling array (shape=(517,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  14 tasks      | elapsed:   31.3s
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2069,), dtype=int64).
# Pickling array (shape=(517,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  15 tasks      | elapsed:   31.4s
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2070,), dtype=int64).
# Pickling array (shape=(516,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  16 tasks      | elapsed:   32.7s
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2068,), dtype=int64).
# Pickling array (shape=(518,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:   35.3s
# [Parallel(n_jobs=-1)]: Done  18 tasks      | elapsed:   35.3s
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2068,), dtype=int64).
# Pickling array (shape=(518,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2069,), dtype=int64).
# Pickling array (shape=(517,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  19 tasks      | elapsed:   37.3s
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2069,), dtype=int64).
# Pickling array (shape=(517,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  20 tasks      | elapsed:   43.3s
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2070,), dtype=int64).
# Pickling array (shape=(516,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed:   44.3s
# [Parallel(n_jobs=-1)]: Done  22 tasks      | elapsed:   44.3s
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2068,), dtype=int64).
# Pickling array (shape=(518,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2068,), dtype=int64).
# Pickling array (shape=(518,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  23 tasks      | elapsed:   46.2s
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2069,), dtype=int64).
# Pickling array (shape=(517,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  24 tasks      | elapsed:   54.1s
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2069,), dtype=int64).
# Pickling array (shape=(517,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  25 tasks      | elapsed:   55.4s
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2070,), dtype=int64).
# Pickling array (shape=(516,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  26 tasks      | elapsed:  1.3min
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2068,), dtype=int64).
# Pickling array (shape=(518,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  27 tasks      | elapsed:  1.3min
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2068,), dtype=int64).
# Pickling array (shape=(518,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  28 tasks      | elapsed:  1.4min
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2069,), dtype=int64).
# Pickling array (shape=(517,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  29 tasks      | elapsed:  1.4min
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2069,), dtype=int64).
# Pickling array (shape=(517,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  30 tasks      | elapsed:  1.5min
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2070,), dtype=int64).
# Pickling array (shape=(516,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  31 tasks      | elapsed:  1.6min
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2068,), dtype=int64).
# Pickling array (shape=(518,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  32 tasks      | elapsed:  1.6min
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2068,), dtype=int64).
# Pickling array (shape=(518,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  33 tasks      | elapsed:  1.6min
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2069,), dtype=int64).
# Pickling array (shape=(517,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:  1.7min
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2069,), dtype=int64).
# Pickling array (shape=(517,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  35 tasks      | elapsed:  1.7min
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2070,), dtype=int64).
# Pickling array (shape=(516,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  36 tasks      | elapsed:  1.9min
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2068,), dtype=int64).
# Pickling array (shape=(518,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  37 tasks      | elapsed:  1.9min
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2068,), dtype=int64).
# Pickling array (shape=(518,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  38 tasks      | elapsed:  2.0min
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2069,), dtype=int64).
# Pickling array (shape=(517,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  39 out of  45 | elapsed:  2.0min remaining:   18.6s
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2069,), dtype=int64).
# Pickling array (shape=(517,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  40 out of  45 | elapsed:  2.2min remaining:   16.7s
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2070,), dtype=int64).
# Pickling array (shape=(516,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  41 out of  45 | elapsed:  2.9min remaining:   17.3s
# [Parallel(n_jobs=-1)]: Done  42 out of  45 | elapsed:  3.1min remaining:   13.1s
# [Parallel(n_jobs=-1)]: Done  43 out of  45 | elapsed:  3.1min remaining:    8.6s
# [Parallel(n_jobs=-1)]: Done  45 out of  45 | elapsed:  3.6min remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  45 out of  45 | elapsed:  3.6min finished
# /anaconda3/envs/u4s1env/lib/python3.7/site-packages/sklearn/linear_model/stochastic_gradient.py:183: FutureWarning: max_iter and tol parameters have been added in SGDClassifier in 0.19. If max_iter is set but tol is left unset, the default value for tol in 0.19 and 0.20 will be None (which is equivalent to -infinity, so it has no effect) but will change in 0.21 to 1e-3. Specify tol to silence this warning.
#   FutureWarning)
# GridSearchCV(cv=5, error_score='raise-deprecating',
#        estimator=Pipeline(memory=None,
#      steps=[('vect', TfidfVectorizer(analyzer='word', binary=False, decode_error='strict',
#         dtype=<class 'numpy.float64'>, encoding='utf-8', input='content',
#         lowercase=True, max_df=1.0, max_features=None, min_df=1,
#         ngram_range=(1, 1), norm='l2', preprocessor=None, smooth_idf=True,
# ...dom_state=42, shuffle=True, tol=None,
#        validation_fraction=0.1, verbose=0, warm_start=False))]),
#        fit_params=None, iid='warn', n_jobs=-1,
#        param_grid={'svd__n_components': (100, 300, 1000), 'sgdc__max_iter': (300, 1000, 3000)},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring=None, verbose=1000)

# %%
grid4.best_score_  # Promising!
# Out:
# 0.9280742459396751

# %%
y_pred4 = grid4.predict(test['description'])

# %%
y_submission = pd.read_csv('/Users/nickburkhalter/Desktop/Lambda School/Unit 4/DS-Unit-4-Sprint-1-NLP/module3-document-classification/data/sample_submission.csv')
assert y_submission.shape[0] == y_pred4.shape[0]

y_submission.category = y_pred4.astype(int)
y_submission.to_csv('pred4.csv', index=None)

# %%
# TFIDF + SVD + SVC
#-------------------ROUND 5---------------------

# THIS ONE SUCKS - DON'T USE!!!
from sklearn.svm import SVC

# %%
vect = TfidfVectorizer(stop_words='english')
svd = TruncatedSVD(algorithm='randomized',
                   random_state=42)
svc = SVC(random_state=42)

pipe5 = Pipeline([('vect', vect), 
                 ('svd', svd), 
                 ('svc', svc)])

param5 = {
    'svd__n_components': (100, 300, 1000),
    'svc__degree': (5, 7),
    'svc__max_iter': (300, 1000, 3000),
}

grid5 = GridSearchCV(pipe5, param5, cv=5, n_jobs=-1, verbose=1000)

# %%
grid5.fit(train['description'], train['category'])
# Out:
# Fitting 5 folds for each of 18 candidates, totalling 90 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2068,), dtype=int64).
# Pickling array (shape=(518,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2068,), dtype=int64).
# Pickling array (shape=(518,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2069,), dtype=int64).
# Pickling array (shape=(517,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2069,), dtype=int64).
# Pickling array (shape=(517,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2070,), dtype=int64).
# Pickling array (shape=(516,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    2.2s
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2068,), dtype=int64).
# Pickling array (shape=(518,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    2.2s
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2068,), dtype=int64).
# Pickling array (shape=(518,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    2.3s
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:    2.3s
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2069,), dtype=int64).
# Pickling array (shape=(517,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2069,), dtype=int64).
# Pickling array (shape=(517,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done   5 tasks      | elapsed:    4.4s
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2070,), dtype=int64).
# Pickling array (shape=(516,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done   6 tasks      | elapsed:    8.6s
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2068,), dtype=int64).
# Pickling array (shape=(518,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done   7 tasks      | elapsed:    8.7s
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2068,), dtype=int64).
# Pickling array (shape=(518,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done   8 tasks      | elapsed:    9.0s
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2069,), dtype=int64).
# Pickling array (shape=(517,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:   11.6s
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2069,), dtype=int64).
# Pickling array (shape=(517,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  10 tasks      | elapsed:   17.2s
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2070,), dtype=int64).
# Pickling array (shape=(516,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  11 tasks      | elapsed:   36.2s
# [Parallel(n_jobs=-1)]: Done  12 tasks      | elapsed:   36.3s
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2068,), dtype=int64).
# Pickling array (shape=(518,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2068,), dtype=int64).
# Pickling array (shape=(518,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  13 tasks      | elapsed:   38.7s
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2069,), dtype=int64).
# Pickling array (shape=(517,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  14 tasks      | elapsed:   39.4s
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2069,), dtype=int64).
# Pickling array (shape=(517,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  15 tasks      | elapsed:   41.4s
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2070,), dtype=int64).
# Pickling array (shape=(516,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  16 tasks      | elapsed:   42.4s
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2068,), dtype=int64).
# Pickling array (shape=(518,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:   43.2s
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2068,), dtype=int64).
# Pickling array (shape=(518,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  18 tasks      | elapsed:   44.4s
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2069,), dtype=int64).
# Pickling array (shape=(517,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  19 tasks      | elapsed:   45.1s
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2069,), dtype=int64).
# Pickling array (shape=(517,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  20 tasks      | elapsed:   49.5s
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2070,), dtype=int64).
# Pickling array (shape=(516,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed:   50.4s
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2068,), dtype=int64).
# Pickling array (shape=(518,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  22 tasks      | elapsed:   51.3s
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2068,), dtype=int64).
# Pickling array (shape=(518,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  23 tasks      | elapsed:   55.5s
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2069,), dtype=int64).
# Pickling array (shape=(517,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  24 tasks      | elapsed:   56.5s
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2069,), dtype=int64).
# Pickling array (shape=(517,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  25 tasks      | elapsed:   59.8s
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2070,), dtype=int64).
# Pickling array (shape=(516,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  26 tasks      | elapsed:  1.2min
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2068,), dtype=int64).
# Pickling array (shape=(518,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  27 tasks      | elapsed:  1.3min
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2068,), dtype=int64).
# Pickling array (shape=(518,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  28 tasks      | elapsed:  1.4min
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2069,), dtype=int64).
# Pickling array (shape=(517,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  29 tasks      | elapsed:  1.4min
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2069,), dtype=int64).
# Pickling array (shape=(517,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  30 tasks      | elapsed:  1.4min
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2070,), dtype=int64).
# Pickling array (shape=(516,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  31 tasks      | elapsed:  1.4min
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2068,), dtype=int64).
# Pickling array (shape=(518,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  32 tasks      | elapsed:  1.4min
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2068,), dtype=int64).
# Pickling array (shape=(518,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  33 tasks      | elapsed:  1.4min
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2069,), dtype=int64).
# Pickling array (shape=(517,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:  1.4min
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2069,), dtype=int64).
# Pickling array (shape=(517,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  35 tasks      | elapsed:  1.5min
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2070,), dtype=int64).
# Pickling array (shape=(516,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  36 tasks      | elapsed:  1.5min
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2068,), dtype=int64).
# Pickling array (shape=(518,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  37 tasks      | elapsed:  1.5min
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2068,), dtype=int64).
# Pickling array (shape=(518,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  38 tasks      | elapsed:  1.6min
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2069,), dtype=int64).
# Pickling array (shape=(517,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  39 tasks      | elapsed:  1.6min
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2069,), dtype=int64).
# Pickling array (shape=(517,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  40 tasks      | elapsed:  1.6min
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2070,), dtype=int64).
# Pickling array (shape=(516,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  41 tasks      | elapsed:  2.0min
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2068,), dtype=int64).
# Pickling array (shape=(518,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:  2.1min
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2068,), dtype=int64).
# Pickling array (shape=(518,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  43 tasks      | elapsed:  2.1min
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2069,), dtype=int64).
# Pickling array (shape=(517,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  44 tasks      | elapsed:  2.1min
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2069,), dtype=int64).
# Pickling array (shape=(517,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  45 tasks      | elapsed:  2.1min
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2070,), dtype=int64).
# Pickling array (shape=(516,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  46 tasks      | elapsed:  2.2min
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2068,), dtype=int64).
# Pickling array (shape=(518,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  47 tasks      | elapsed:  2.2min
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2068,), dtype=int64).
# Pickling array (shape=(518,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  48 tasks      | elapsed:  2.2min
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2069,), dtype=int64).
# Pickling array (shape=(517,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  49 tasks      | elapsed:  2.2min
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2069,), dtype=int64).
# Pickling array (shape=(517,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  50 tasks      | elapsed:  2.3min
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2070,), dtype=int64).
# Pickling array (shape=(516,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  51 tasks      | elapsed:  2.3min
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2068,), dtype=int64).
# Pickling array (shape=(518,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  52 tasks      | elapsed:  2.3min
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2068,), dtype=int64).
# Pickling array (shape=(518,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  53 tasks      | elapsed:  2.4min
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2069,), dtype=int64).
# Pickling array (shape=(517,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  54 tasks      | elapsed:  2.4min
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2069,), dtype=int64).
# Pickling array (shape=(517,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  55 tasks      | elapsed:  2.4min
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2070,), dtype=int64).
# Pickling array (shape=(516,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  56 tasks      | elapsed:  2.7min
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2068,), dtype=int64).
# Pickling array (shape=(518,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  57 tasks      | elapsed:  2.8min
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2068,), dtype=int64).
# Pickling array (shape=(518,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  58 tasks      | elapsed:  2.8min
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2069,), dtype=int64).
# Pickling array (shape=(517,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  59 tasks      | elapsed:  2.8min
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2069,), dtype=int64).
# Pickling array (shape=(517,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  60 tasks      | elapsed:  2.8min
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2070,), dtype=int64).
# Pickling array (shape=(516,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  61 tasks      | elapsed:  2.8min
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2068,), dtype=int64).
# Pickling array (shape=(518,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  62 tasks      | elapsed:  2.8min
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2068,), dtype=int64).
# Pickling array (shape=(518,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  63 tasks      | elapsed:  2.9min
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2069,), dtype=int64).
# Pickling array (shape=(517,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  64 tasks      | elapsed:  2.9min
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2069,), dtype=int64).
# Pickling array (shape=(517,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  65 tasks      | elapsed:  3.0min
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2070,), dtype=int64).
# Pickling array (shape=(516,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  66 tasks      | elapsed:  3.0min
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2068,), dtype=int64).
# Pickling array (shape=(518,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  67 tasks      | elapsed:  3.0min
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2068,), dtype=int64).
# Pickling array (shape=(518,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  68 tasks      | elapsed:  3.1min
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2069,), dtype=int64).
# Pickling array (shape=(517,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  69 tasks      | elapsed:  3.1min
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).[Parallel(n_jobs=-1)]: Done  70 tasks      | elapsed:  3.1min
#
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2069,), dtype=int64).
# Pickling array (shape=(517,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2070,), dtype=int64).
# Pickling array (shape=(516,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  71 tasks      | elapsed:  3.4min
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2068,), dtype=int64).
# Pickling array (shape=(518,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  72 tasks      | elapsed:  3.5min
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2068,), dtype=int64).
# Pickling array (shape=(518,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  73 tasks      | elapsed:  3.5min
# [Parallel(n_jobs=-1)]: Done  74 tasks      | elapsed:  3.5min
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2069,), dtype=int64).
# Pickling array (shape=(517,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2069,), dtype=int64).
# Pickling array (shape=(517,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  75 tasks      | elapsed:  3.6min
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2070,), dtype=int64).
# Pickling array (shape=(516,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  76 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=-1)]: Done  77 tasks      | elapsed:  3.6min
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2068,), dtype=int64).
# Pickling array (shape=(518,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2068,), dtype=int64).
# Pickling array (shape=(518,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  78 tasks      | elapsed:  3.6min
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2069,), dtype=int64).
# Pickling array (shape=(517,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  79 tasks      | elapsed:  3.6min
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2069,), dtype=int64).
# Pickling array (shape=(517,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  80 tasks      | elapsed:  3.7min
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2070,), dtype=int64).
# Pickling array (shape=(516,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  81 tasks      | elapsed:  3.7min
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2068,), dtype=int64).
# Pickling array (shape=(518,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  82 tasks      | elapsed:  3.7min
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2068,), dtype=int64).
# Pickling array (shape=(518,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  83 tasks      | elapsed:  3.8min
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2069,), dtype=int64).
# Pickling array (shape=(517,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  84 out of  90 | elapsed:  3.8min remaining:   16.4s
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2069,), dtype=int64).
# Pickling array (shape=(517,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  85 out of  90 | elapsed:  3.8min remaining:   13.5s
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2070,), dtype=int64).
# Pickling array (shape=(516,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  86 out of  90 | elapsed:  4.1min remaining:   11.5s
# [Parallel(n_jobs=-1)]: Done  87 out of  90 | elapsed:  4.2min remaining:    8.7s
# [Parallel(n_jobs=-1)]: Done  88 out of  90 | elapsed:  4.2min remaining:    5.7s
# [Parallel(n_jobs=-1)]: Done  90 out of  90 | elapsed:  4.4min remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  90 out of  90 | elapsed:  4.4min finished
# /anaconda3/envs/u4s1env/lib/python3.7/site-packages/sklearn/svm/base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# /anaconda3/envs/u4s1env/lib/python3.7/site-packages/sklearn/svm/base.py:244: ConvergenceWarning: Solver terminated early (max_iter=300).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# GridSearchCV(cv=5, error_score='raise-deprecating',
#        estimator=Pipeline(memory=None,
#      steps=[('vect', TfidfVectorizer(analyzer='word', binary=False, decode_error='strict',
#         dtype=<class 'numpy.float64'>, encoding='utf-8', input='content',
#         lowercase=True, max_df=1.0, max_features=None, min_df=1,
#         ngram_range=(1, 1), norm='l2', preprocessor=None, smooth_idf=True,
# ...rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))]),
#        fit_params=None, iid='warn', n_jobs=-1,
#        param_grid={'svd__n_components': (100, 300, 1000), 'svc__degree': (5, 7), 'svc__max_iter': (300, 1000, 3000)},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring=None, verbose=1000)

# %%
grid5.best_score_  # CRAP!
# Out:
# 0.7540603248259861

# %%
# TFIDF + SVD + SGD
# Increase # iterations on svd
#-------------------ROUND 6---------------------
vect = TfidfVectorizer()
svd = TruncatedSVD(algorithm='randomized',
                   n_iter=15,
                   random_state=42)
sgdc = SGDClassifier(random_state=42)

pipe6 = Pipeline([('vect', vect), 
                 ('svd', svd), 
                 ('sgdc', sgdc)])

param6 = {
    #'vect__max_df': (1.0,),
    #'vect__min_df': (.02,),
    'svd__n_components': (100, 300, 1000),
    'sgdc__max_iter': (300, 1000, 3000),
}

grid6 = GridSearchCV(pipe6, param6, cv=5, n_jobs=-1, verbose=1000)

# %%
grid6.fit(train['description'], train['category'])
# Out:
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2068,), dtype=int64).
# Pickling array (shape=(518,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2068,), dtype=int64).
# Pickling array (shape=(518,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2069,), dtype=int64).
# Pickling array (shape=(517,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2069,), dtype=int64).
# Pickling array (shape=(517,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2070,), dtype=int64).
# Pickling array (shape=(516,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    2.8s
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2068,), dtype=int64).
# Pickling array (shape=(518,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    3.0s
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    3.0s
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:    3.0s
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2068,), dtype=int64).
# Pickling array (shape=(518,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2069,), dtype=int64).
# Pickling array (shape=(517,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2069,), dtype=int64).
# Pickling array (shape=(517,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done   5 tasks      | elapsed:    5.5s
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2070,), dtype=int64).
# Pickling array (shape=(516,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done   6 tasks      | elapsed:   11.0s
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2068,), dtype=int64).
# Pickling array (shape=(518,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done   7 tasks      | elapsed:   11.2s
# [Parallel(n_jobs=-1)]: Done   8 tasks      | elapsed:   11.2s
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2068,), dtype=int64).
# Pickling array (shape=(518,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2069,), dtype=int64).
# Pickling array (shape=(517,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:   13.4s
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2069,), dtype=int64).
# Pickling array (shape=(517,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  10 tasks      | elapsed:   19.1s
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2070,), dtype=int64).
# Pickling array (shape=(516,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  11 tasks      | elapsed:   42.6s
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2068,), dtype=int64).
# Pickling array (shape=(518,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  12 tasks      | elapsed:   42.8s
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2068,), dtype=int64).
# Pickling array (shape=(518,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  13 tasks      | elapsed:   45.2s
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2069,), dtype=int64).
# Pickling array (shape=(517,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  14 tasks      | elapsed:   47.3s
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2069,), dtype=int64).
# Pickling array (shape=(517,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  15 tasks      | elapsed:   49.1s
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2070,), dtype=int64).
# Pickling array (shape=(516,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  16 tasks      | elapsed:   49.8s
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2068,), dtype=int64).
# Pickling array (shape=(518,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:   51.8s
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2068,), dtype=int64).
# Pickling array (shape=(518,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  18 tasks      | elapsed:   53.6s
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2069,), dtype=int64).
# Pickling array (shape=(517,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  19 tasks      | elapsed:   54.5s
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2069,), dtype=int64).
# Pickling array (shape=(517,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  20 tasks      | elapsed:  1.0min
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2070,), dtype=int64).
# Pickling array (shape=(516,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed:  1.1min
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2068,), dtype=int64).
# Pickling array (shape=(518,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  22 tasks      | elapsed:  1.1min
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2068,), dtype=int64).
# Pickling array (shape=(518,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  23 tasks      | elapsed:  1.1min
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2069,), dtype=int64).
# Pickling array (shape=(517,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  24 tasks      | elapsed:  1.2min
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2069,), dtype=int64).
# Pickling array (shape=(517,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  25 tasks      | elapsed:  1.3min
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2070,), dtype=int64).
# Pickling array (shape=(516,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  26 tasks      | elapsed:  1.8min
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2068,), dtype=int64).
# Pickling array (shape=(518,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  27 tasks      | elapsed:  1.8min
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2068,), dtype=int64).
# Pickling array (shape=(518,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  28 tasks      | elapsed:  1.9min
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2069,), dtype=int64).
# Pickling array (shape=(517,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  29 tasks      | elapsed:  2.0min
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2069,), dtype=int64).
# Pickling array (shape=(517,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  30 tasks      | elapsed:  2.0min
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2070,), dtype=int64).
# Pickling array (shape=(516,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  31 tasks      | elapsed:  2.1min
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2068,), dtype=int64).
# Pickling array (shape=(518,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  32 tasks      | elapsed:  2.1min
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2068,), dtype=int64).
# Pickling array (shape=(518,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  33 tasks      | elapsed:  2.2min
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2069,), dtype=int64).
# Pickling array (shape=(517,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:  2.3min
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2069,), dtype=int64).
# Pickling array (shape=(517,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  35 tasks      | elapsed:  2.4min
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2070,), dtype=int64).
# Pickling array (shape=(516,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  36 tasks      | elapsed:  2.5min
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2068,), dtype=int64).
# Pickling array (shape=(518,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  37 tasks      | elapsed:  2.5min
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2068,), dtype=int64).
# Pickling array (shape=(518,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  38 tasks      | elapsed:  2.6min
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2069,), dtype=int64).
# Pickling array (shape=(517,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  39 out of  45 | elapsed:  2.8min remaining:   25.4s
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2069,), dtype=int64).
# Pickling array (shape=(517,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  40 out of  45 | elapsed:  2.9min remaining:   21.6s
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=object).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2586,), dtype=int64).
# Pickling array (shape=(2070,), dtype=int64).
# Pickling array (shape=(516,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  41 out of  45 | elapsed:  3.8min remaining:   22.0s
# [Parallel(n_jobs=-1)]: Done  42 out of  45 | elapsed:  3.9min remaining:   16.6s
# [Parallel(n_jobs=-1)]: Done  43 out of  45 | elapsed:  4.0min remaining:   11.1s
# [Parallel(n_jobs=-1)]: Done  45 out of  45 | elapsed:  4.6min remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  45 out of  45 | elapsed:  4.6min finished
# /anaconda3/envs/u4s1env/lib/python3.7/site-packages/sklearn/linear_model/stochastic_gradient.py:183: FutureWarning: max_iter and tol parameters have been added in SGDClassifier in 0.19. If max_iter is set but tol is left unset, the default value for tol in 0.19 and 0.20 will be None (which is equivalent to -infinity, so it has no effect) but will change in 0.21 to 1e-3. Specify tol to silence this warning.
#   FutureWarning)
# GridSearchCV(cv=5, error_score='raise-deprecating',
#        estimator=Pipeline(memory=None,
#      steps=[('vect', TfidfVectorizer(analyzer='word', binary=False, decode_error='strict',
#         dtype=<class 'numpy.float64'>, encoding='utf-8', input='content',
#         lowercase=True, max_df=1.0, max_features=None, min_df=1,
#         ngram_range=(1, 1), norm='l2', preprocessor=None, smooth_idf=True,
# ...dom_state=42, shuffle=True, tol=None,
#        validation_fraction=0.1, verbose=0, warm_start=False))]),
#        fit_params=None, iid='warn', n_jobs=-1,
#        param_grid={'svd__n_components': (100, 300, 1000), 'sgdc__max_iter': (300, 1000, 3000)},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring=None, verbose=1000)

# %%
grid6.best_score_  # HELL YEAH!
# Out:
# 0.9358081979891725

# %%
y_pred6 = grid6.predict(test['description'])

# %%
y_submission = pd.read_csv('/Users/nickburkhalter/Desktop/Lambda School/Unit 4/DS-Unit-4-Sprint-1-NLP/module3-document-classification/data/sample_submission.csv')
assert y_submission.shape[0] == y_pred6.shape[0]

y_submission.category = y_pred6.astype(int)
y_submission.to_csv('pred6.csv', index=None)

# %%
# MAJORITY CLASSIFIER

# Filenames of your submissions you want to ensemble
files = ['pred1.csv', 'pred2.csv', 'pred3.csv', 'pred4.csv', 'pred6.csv']

target = 'category'
submissions = (pd.read_csv(file)[[target]] for file in files)
ensemble = pd.concat(submissions, axis='columns')
majority_vote = ensemble.mode(axis='columns')[0].astype(int)

sample_submission = pd.read_csv('/Users/nickburkhalter/Desktop/Lambda School/Unit 4/DS-Unit-4-Sprint-1-NLP/module3-document-classification/data/sample_submission.csv')
submission = sample_submission.copy()
submission[target] = majority_vote
submission.to_csv('my-ultimate-ensemble-submission.csv', index=False)

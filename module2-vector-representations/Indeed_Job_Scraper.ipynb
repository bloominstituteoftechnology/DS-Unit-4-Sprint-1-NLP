# %% [markdown]
# # Indeed Job Scraper
#
# The tobias-fyi fork of the repository can be found here: [tobias-fyi/Indeed-Job-Scraper](https://github.com/tobias-fyi/Indeed-Job-Scraper/)
#
# ---
# ---

# %%
# ====== Imports ====== #
from bs4 import BeautifulSoup
import requests, json
import pandas as pd
from multiprocessing import Pool
from functools import partial

# %%
# ====== Scraping parameters ====== #
parameters = {
    "search_query": "data science",
    "location": "Denver, CO",
    "miles": 50,
    "ordered_keywords": "data",
    "exclude_keywords": "",
    "title_keywords": "",
    "pages": 1,
}

# %%
# ====== Class for scraping Indeed ====== #
# ======   With multiprocessing    ====== #

class Scrape:
    def __init__(self, parameters):
        self.output_frame = None
        self.loading = False
        
        # Retain parameter dict
        self.parameters = parameters

        # Create base Indeed URL for all further scraping
        self.what = parameters["search_query"]
        self.where = parameters["location"]
        self.miles = parameters["miles"]
        self.base_url = f"https://www.indeed.com/jobs?q={self.what}&l={self.where}"
        
        # Set other attributes
        self.keywords = parameters["ordered_keywords"]
        self.title_keywords = parameters["title_keywords"]
        self.exclude_keywords = parameters["exclude_keywords"]
        self.pages = parameters["pages"]

        self.total_keywords = len(self.keywords) + len(self.title_keywords)

    def rate_job(self, j_title, j_soup):
        """Rate job based on input parameters."""

        description = j_soup.find(id="jobDescriptionText").get_text()

        # Reset the params
        keywords_present = []
        title_keywords_present = []
        rating = 0

        # Check for keyword, add value to rating depending on ranking
        for index, keyword in enumerate(self.keywords):
            if keyword in description:
                rating += len(keywords) - index
                keywords_present.append(keyword)

        # Check for title keywords
        for index, keyword in enumerate(self.title_keywords):
            if keyword in j_title:
                rating += total_keywords - index
                title_keywords_present.append(keyword)

        # Normalise rating
        rating = rating / sum(range(1, self.total_keywords + 1))

        # Check for excluded keywords
        for keyword in self.exclude_keywords:
            if keyword in j_title:
                rating = 0
                break

        return description, rating, keywords_present, title_keywords_present


    def get_job_details(self, job):
        """Obtain details of the job (company, title, description etc.)"""

        # Get link and title
        job_url = job.find(class_="title").a["href"]

        job_url = ( # Correct for truncated URLs
            "https://www.indeed.com" + job_url if (job_url.startswith("/")) else job_url
        )
        job_page = requests.get(job_url)
        job_soup = BeautifulSoup(job_page.content, "html.parser")

        # Give URL after redirect (ads/analytics etc.)
        job_url = job_page.url

        # Get job title and company name
        title = job.find(class_="title").a["title"]
        company = job_soup.find(class_="icl-u-lg-mr--sm").get_text()

        # Get description, rating and present keywords
        description, rating, keywords_present, title_keywords_present = self.rate_job(
            title, job_soup
        )

        return (
            title,
            company,
            job_url,
            description,
            rating,
            keywords_present,
            title_keywords_present,
        )

    def parallel_scrape(self, parameters, url, page_num):
        """Parallel scraping routine. Run through MapPool using Multiprocessing library"""
        
        # Get page
        current_page = requests.get(url, timeout=5)
        page_soup = BeautifulSoup(current_page.content, "html.parser")
        page_output = []

        # Parse every job in page
        for job in page_soup.select(".jobsearch-SerpJobCard"):

            (
                title,
                company,
                url,
                description,
                rating,
                keywords_present,
                title_keywords_present,
            ) = self.get_job_details(job)

            page_output.append(
                [
                    rating,
                    title,
                    company,
                    description,
                    url,
                    str(keywords_present),
                    str(title_keywords_present),
                    page_num,
                ]
            )

        return page_output

    def get_scrape(self):
        """Primary method for obtaining scraped jobs."""

        # Reset output and progress
        self.loading = True

        # Output list and frame
        output = []

        # Create pool of workers
        pool = Pool(min(self.pages, 5))

        # Dirty list comprehension to create argument list for pool workers
        pool_args = [
            (self.base_url + "&start=" + str(x * 10), x + 1)
            if (x != 0)
            else (self.base_url, x + 1)
            for x in range(0, self.pages)
        ]

        # Get output of pool workers
        output = pool.starmap(partial(self.parallel_scrape, self.parameters), pool_args)
        output = [x for sublist in output for x in sublist]

        # Create dataframe from list of jobs
        df_output_frame = (
            pd.DataFrame(
                output,
                columns=[
                    "Rating",
                    "Job Title",
                    "Company",
                    "Description",
                    "Job URL",
                    "Keywords Present",
                    "Title Keywords",
                    "Page Found",
                ],
            )
            .sort_values(by="Rating", ascending=False)
            .reset_index(drop=True)
        )

        # Sort df by rating
        df_output_frame["Rating"] = df_output_frame["Rating"].round(decimals=3)
        df_output_frame = df_output_frame.drop_duplicates(
            subset=["Rating", "Job Title", "Company"]
        )
        self.loading = False

        return df_output_frame

    # For outputting to csv locally
    def output_csv(self, df):
        df.to_csv("indeed_job_scraper.csv", index=False)

# %%
# ====== Class for scraping Indeed ====== #
# ======  Without multiprocessing  ====== #

class Scrape:
    def __init__(self, parameters):
        self.output_frame = None
        self.loading = False
        
        # Retain parameter dict
        self.parameters = parameters

        # Create base Indeed URL for all further scraping
        self.what = parameters["search_query"]
        self.where = parameters["location"]
        self.miles = parameters["miles"]
        self.base_url = f"https://www.indeed.com/jobs?q={self.what}&l={self.where}"
        
        # Set other attributes
        self.keywords = parameters["ordered_keywords"]
        self.title_keywords = parameters["title_keywords"]
        self.exclude_keywords = parameters["exclude_keywords"]
        self.pages = parameters["pages"]

        self.total_keywords = len(self.keywords) + len(self.title_keywords)

    def rate_job(self, j_title, j_soup):
        """Rate job based on input parameters."""

        description = j_soup.find(id="jobDescriptionText").get_text()

        # Reset the params
        keywords_present = []
        title_keywords_present = []
        rating = 0

        # Check for keyword, add value to rating depending on ranking
        for index, keyword in enumerate(self.keywords):
            if keyword in description:
                rating += len(self.keywords) - index
                keywords_present.append(keyword)

        # Check for title keywords
        for index, keyword in enumerate(self.title_keywords):
            if keyword in j_title:
                rating += self.total_keywords - index
                title_keywords_present.append(keyword)

        # Normalise rating
        rating = rating / sum(range(1, self.total_keywords + 1))

        # Check for excluded keywords
        for keyword in self.exclude_keywords:
            if keyword in j_title:
                rating = 0
                break

        return description, rating, keywords_present, title_keywords_present


    def get_job_details(self, job):
        """Obtain details of the job (company, title, description etc.)"""

        # Get link and title
        job_url = job.find(class_="title").a["href"]

        job_url = ( # Correct for truncated URLs
            "https://www.indeed.com" + job_url if (job_url.startswith("/")) else job_url
        )
        job_page = requests.get(job_url)
        job_soup = BeautifulSoup(job_page.content, "html.parser")

        # Give URL after redirect (ads/analytics etc.)
        job_url = job_page.url

        # Get job title and company name
        title = job.find(class_="title").a["title"]
        company = job_soup.find(class_="icl-u-lg-mr--sm").get_text()

        # Get description, rating and present keywords
        description, rating, keywords_present, title_keywords_present = self.rate_job(
            title, job_soup
        )

        return (
            title,
            company,
            job_url,
            description,
            rating,
            keywords_present,
            title_keywords_present,
        )

    def get_scrape(self):
        """Primary method for obtaining scraped jobs."""

        # Reset output and progress
        self.loading = True

        # Output list and frame
        output = []

        for x in range(0, self.pages):
            if x == 0:
                page_append = ""
            else:
                page_append = "&start=" + str(x * 10)

            # get page
            current_page = requests.get(self.base_url + page_append, timeout=5)
            page_soup = BeautifulSoup(current_page.content, "html.parser")

            for job in page_soup.select(".jobsearch-SerpJobCard"):
                (
                    title,
                    company,
                    url,
                    description,
                    rating,
                    keywords_present,
                    title_keywords_present,
                ) = self.get_job_details(job)
                output.append(
                    [
                        rating,
                        title,
                        company,
                        description,
                        url,
                        keywords_present,
                        title_keywords_present,
                        x + 1,
                    ]
                )

            print(f"Page {x+1} completed", end="\r")

        # Create dataframe from list of jobs
        df_output_frame = (
            pd.DataFrame(
                output,
                columns=[
                    "Rating",
                    "Job Title",
                    "Company",
                    "Description",
                    "Job URL",
                    "Keywords Present",
                    "Title Keywords",
                    "Page Found",
                ],
            )
            .sort_values(by="Rating", ascending=False)
            .reset_index(drop=True)
        )

        # Sort df by rating
        df_output_frame["Rating"] = df_output_frame["Rating"].round(decimals=3)
        df_output_frame = df_output_frame.drop_duplicates(
            subset=["Rating", "Job Title", "Company"]
        )
        self.loading = False

        return df_output_frame

    # For outputting to csv locally
    def output_csv(self, df):
        df.to_csv("indeed_job_scraper.csv", index=False)

# %% [markdown]
# ## Time to let 'er rip!

# %%
# First, instantiate a scraper object with the parameters
scraper = Scrape(parameters)

# %%
# Then, use the `.get_scrape()` method to use the instance of the scraper
df1 = scraper.get_scrape()
# Out:
# Page 1 completed

# %%
print(df1.shape)
df1.head()
# Out:
# (16, 8)
#    Rating                Job Title                     Company  \
# 0     1.0            Data Engineer              Seen by Indeed
# 1     1.0           Data Scientist  Aegis Premier Technologies
# 2     1.0  Data Warehouse Engineer              Seen by Indeed
# 3     1.0           Data Scientist                 Merkle Inc.
# 4     1.0           Data Scientist                    Deloitte
#
#                                          Description  \
# 0  Seen by Indeed is a free service that connects...
# 1  About Us We are a group of passionate technolo...
# 2  Seen by Indeed is a free service that connects...
# 3  Job Description\n\nDesign, develop, test, depl...
# 4  Deloitte Services LP includes internal support...
#
#                                              Job URL Keywords Present  \
# 0  https://www.indeed.com/viewjob?jk=790e2b4b32f9...     [d, a, t, a]
# 1  https://www.indeed.com/viewjob?cmp=Aegis-Premi...     [d, a, t, a]
# 2  https://www.indeed.com/viewjob?jk=2246c6b11155...     [d, a, t, a]
# 3  https://www.indeed.com/viewjob?jk=9c9be388d642...     [d, a, t, a]
# 4  https://www.indeed.com/viewjob?jk=1f37f96bae2b...     [d, a, t, a]
#
#   Title Keywords  Page Found
# 0             []           1
# 1             []           1
# 2             []           1
# 3             []           1
# 4             []           1

# %%
# Save to csv
df1.to_csv("indeed_1pg_test.csv", index=False)

# %% [markdown]
# ---
#
# ## The Full Monty (Python)
#
# Now I'm going to really let 'er rip to get the full dataset. A little edit to show me what page is being processed.

# %%
# ====== Class for scraping Indeed ====== #
# ======  Without multiprocessing  ====== #

class Scrape:
    def __init__(self, parameters):
        self.output_frame = None
        self.loading = False
        
        # Retain parameter dict
        self.parameters = parameters

        # Create base Indeed URL for all further scraping
        self.what = parameters["search_query"]
        self.where = parameters["location"]
        self.miles = parameters["miles"]
        self.base_url = f"https://www.indeed.com/jobs?q={self.what}&l={self.where}"
        
        # Set other attributes
        self.keywords = parameters["ordered_keywords"]
        self.title_keywords = parameters["title_keywords"]
        self.exclude_keywords = parameters["exclude_keywords"]
        self.pages = parameters["pages"]

        self.total_keywords = len(self.keywords) + len(self.title_keywords)

    def rate_job(self, j_title, j_soup):
        """Rate job based on input parameters."""

        description = j_soup.find(id="jobDescriptionText").get_text()

        # Reset the params
        keywords_present = []
        title_keywords_present = []
        rating = 0

        # Check for keyword, add value to rating depending on ranking
        for index, keyword in enumerate(self.keywords):
            if keyword in description:
                rating += len(self.keywords) - index
                keywords_present.append(keyword)

        # Check for title keywords
        for index, keyword in enumerate(self.title_keywords):
            if keyword in j_title:
                rating += self.total_keywords - index
                title_keywords_present.append(keyword)

        # Normalise rating
        rating = rating / sum(range(1, self.total_keywords + 1))

        # Check for excluded keywords
        for keyword in self.exclude_keywords:
            if keyword in j_title:
                rating = 0
                break

        return description, rating, keywords_present, title_keywords_present


    def get_job_details(self, job):
        """Obtain details of the job (company, title, description etc.)"""

        # Get link and title
        job_url = job.find(class_="title").a["href"]

        job_url = ( # Correct for truncated URLs
            "https://www.indeed.com" + job_url if (job_url.startswith("/")) else job_url
        )
        job_page = requests.get(job_url)
        job_soup = BeautifulSoup(job_page.content, "html.parser")

        # Give URL after redirect (ads/analytics etc.)
        job_url = job_page.url

        # Get job title and company name
        try:
            title = job.find(class_="title").a["title"]
        except:
            title = "No title found"
        
        try:
            company = job_soup.find(class_="icl-u-lg-mr--sm").get_text()
        except:
            company = "No company found."
            

        # Get description, rating and present keywords
        description, rating, keywords_present, title_keywords_present = self.rate_job(
            title, job_soup
        )

        return (
            title,
            company,
            job_url,
            description,
            rating,
            keywords_present,
            title_keywords_present,
        )

    def get_scrape(self):
        """Primary method for obtaining scraped jobs."""

        # Reset output and progress
        self.loading = True

        # Output list and frame
        output = []

        for x in range(0, self.pages):
            print(f"Processing page {x + 1}...")
            
            if x == 0:
                page_append = ""
            else:
                page_append = "&start=" + str(x * 10)

            # get page
            current_page = requests.get(self.base_url + page_append, timeout=5)
            page_soup = BeautifulSoup(current_page.content, "html.parser")

            for job in page_soup.select(".jobsearch-SerpJobCard"):
                (
                    title,
                    company,
                    url,
                    description,
                    rating,
                    keywords_present,
                    title_keywords_present,
                ) = self.get_job_details(job)
                output.append(
                    [
                        rating,
                        title,
                        company,
                        description,
                        url,
                        keywords_present,
                        title_keywords_present,
                        x + 1,
                    ]
                )

            print(f"Page {x+1} completed", end="\r")

        # Create dataframe from list of jobs
        df_output_frame = (
            pd.DataFrame(
                output,
                columns=[
                    "Rating",
                    "Job Title",
                    "Company",
                    "Description",
                    "Job URL",
                    "Keywords Present",
                    "Title Keywords",
                    "Page Found",
                ],
            )
            .sort_values(by="Rating", ascending=False)
            .reset_index(drop=True)
        )

        # Sort df by rating
        df_output_frame["Rating"] = df_output_frame["Rating"].round(decimals=3)
        df_output_frame = df_output_frame.drop_duplicates(
            subset=["Rating", "Job Title", "Company"]
        )
        self.loading = False

        return df_output_frame

    # For outputting to csv locally
    def output_csv(self, df):
        df.to_csv("indeed_job_scraper.csv", index=False)

# %%
# ====== Scraping parameters ====== #
parameters2 = {
    "search_query": "data science",
    "location": "Denver, CO",
    "miles": 50,
    "ordered_keywords": ["data", "science"],
    "exclude_keywords": "",
    "title_keywords": "",
    "pages": 15,
}

# %%
# First, instantiate a scraper object with the parameters
scraper2 = Scrape(parameters2)

# %%
# Then, use the `.get_scrape()` method to use the instance of the scraper
df2 = scraper2.get_scrape()
# Out:
# Processing page 1...
# Processing page 2...
# Processing page 3...
# Processing page 4...
# Processing page 5...
# Processing page 6...
# Processing page 7...
# Processing page 8...
# Processing page 9...
# Processing page 10...
# Processing page 11...
# Processing page 12...
# Processing page 13...
# Processing page 14...
# Processing page 15...
# Page 15 completed

# %%
print(df2.shape)
df2.head()
# Out:
# (118, 8)
#    Rating                                 Job Title           Company  \
# 0     1.0            Lead Geospatial Data Scientist  Cloud Agronomics
# 1     1.0                             Data Engineer   Valen Analytics
# 2     1.0  US Contractor - Data Engineer (Big Data)               GHX
# 3     1.0                  Financial Analyst Intern            ViaSat
# 4     1.0        Data Scientist - Behavioral Health     Denver Health
#
#                                          Description  \
# 0  About Us:\nCloud Ag is an AgTech startup apply...
# 1  Join a high performing and rapidly growing tea...
# 2  We work to solve deep technical problems that ...
# 3  Bigger challenges. Bolder ideas. Global impact...
# 4  Job Summary:\n\nUnder minimal supervision, sup...
#
#                                              Job URL Keywords Present  \
# 0  https://www.indeed.com/viewjob?jk=9fef1c79148f...  [data, science]
# 1  https://www.indeed.com/viewjob?jk=1489facad7d0...  [data, science]
# 2  https://www.indeed.com/viewjob?jk=6f750b0761e3...  [data, science]
# 3  https://www.indeed.com/viewjob?jk=5f89afd9020e...  [data, science]
# 4  https://www.indeed.com/viewjob?jk=508970a4e047...  [data, science]
#
#   Title Keywords  Page Found
# 0             []          14
# 1             []           6
# 2             []          15
# 3             []          12
# 4             []           7

# %%
# Save to csv
df2.to_csv("19-12-03-indeed_jobs_pg_1-15.csv", index=False)

# %% [markdown]
# ---
#
# ## The Full Monty (Python), Part 2
#
# That gave me 118 records. I didn't want to accidentally overshoot the results and have to start back from page 1 after scraping all of that. So I'm going to set the next one to start scraping near where that one left off.

# %%
# ====== Class for scraping Indeed ====== #
# ======  Without multiprocessing  ====== #

# The update to this version of the class is to start it at page 16

class Scrape:
    def __init__(self, parameters):
        self.output_frame = None
        self.loading = False
        
        # Retain parameter dict
        self.parameters = parameters

        # Create base Indeed URL for all further scraping
        self.what = parameters["search_query"]
        self.where = parameters["location"]
        self.miles = parameters["miles"]
        self.base_url = f"https://www.indeed.com/jobs?q={self.what}&l={self.where}"
        
        # Set other attributes
        self.keywords = parameters["ordered_keywords"]
        self.title_keywords = parameters["title_keywords"]
        self.exclude_keywords = parameters["exclude_keywords"]
        self.pages = parameters["pages"]

        self.total_keywords = len(self.keywords) + len(self.title_keywords)

    def rate_job(self, j_title, j_soup):
        """Rate job based on input parameters."""

        description = j_soup.find(id="jobDescriptionText").get_text()

        # Reset the params
        keywords_present = []
        title_keywords_present = []
        rating = 0

        # Check for keyword, add value to rating depending on ranking
        for index, keyword in enumerate(self.keywords):
            if keyword in description:
                rating += len(self.keywords) - index
                keywords_present.append(keyword)

        # Check for title keywords
        for index, keyword in enumerate(self.title_keywords):
            if keyword in j_title:
                rating += self.total_keywords - index
                title_keywords_present.append(keyword)

        # Normalise rating
        rating = rating / sum(range(1, self.total_keywords + 1))

        # Check for excluded keywords
        for keyword in self.exclude_keywords:
            if keyword in j_title:
                rating = 0
                break

        return description, rating, keywords_present, title_keywords_present


    def get_job_details(self, job):
        """Obtain details of the job (company, title, description etc.)"""

        # Get link and title
        job_url = job.find(class_="title").a["href"]

        job_url = ( # Correct for truncated URLs
            "https://www.indeed.com" + job_url if (job_url.startswith("/")) else job_url
        )
        job_page = requests.get(job_url)
        job_soup = BeautifulSoup(job_page.content, "html.parser")

        # Give URL after redirect (ads/analytics etc.)
        job_url = job_page.url

        # Get job title and company name
        try:
            title = job.find(class_="title").a["title"]
        except:
            title = "No title found"
        
        try:
            company = job_soup.find(class_="icl-u-lg-mr--sm").get_text()
        except:
            company = "No company found."
            

        # Get description, rating and present keywords
        description, rating, keywords_present, title_keywords_present = self.rate_job(
            title, job_soup
        )

        return (
            title,
            company,
            job_url,
            description,
            rating,
            keywords_present,
            title_keywords_present,
        )

    def get_scrape(self):
        """Primary method for obtaining scraped jobs."""

        # Reset output and progress
        self.loading = True

        # Output list and frame
        output = []

        # This time, start at page 15
        for x in range(15, self.pages + 15):
            print(f"Processing page {x + 1}...")
            
            if x == 0:
                page_append = ""
            else:
                page_append = "&start=" + str(x * 10)

            # get page
            current_page = requests.get(self.base_url + page_append, timeout=5)
            page_soup = BeautifulSoup(current_page.content, "html.parser")

            for job in page_soup.select(".jobsearch-SerpJobCard"):
                (
                    title,
                    company,
                    url,
                    description,
                    rating,
                    keywords_present,
                    title_keywords_present,
                ) = self.get_job_details(job)
                output.append(
                    [
                        rating,
                        title,
                        company,
                        description,
                        url,
                        keywords_present,
                        title_keywords_present,
                        x + 1,
                    ]
                )

            print(f"Page {x+1} completed", end="\r")

        # Create dataframe from list of jobs
        df_output_frame = (
            pd.DataFrame(
                output,
                columns=[
                    "Rating",
                    "Job Title",
                    "Company",
                    "Description",
                    "Job URL",
                    "Keywords Present",
                    "Title Keywords",
                    "Page Found",
                ],
            )
            .sort_values(by="Rating", ascending=False)
            .reset_index(drop=True)
        )

        # Sort df by rating
        df_output_frame["Rating"] = df_output_frame["Rating"].round(decimals=3)
        df_output_frame = df_output_frame.drop_duplicates(
            subset=["Rating", "Job Title", "Company"]
        )
        self.loading = False

        return df_output_frame

    # For outputting to csv locally
    def output_csv(self, df):
        df.to_csv("indeed_job_scraper.csv", index=False)

# %%
# ====== Scraping parameters ====== #
parameters3 = {
    "search_query": "data science",
    "location": "Denver, CO",
    "miles": 50,
    "ordered_keywords": ["data", "science"],
    "exclude_keywords": "",
    "title_keywords": "",
    "pages": 10,
}

# %%
# First, instantiate a scraper object with the parameters
scraper3 = Scrape(parameters3)

# %%
# Then, use the `.get_scrape()` method to use the instance of the scraper
df3 = scraper3.get_scrape()
# Out:
# Processing page 16...
# Processing page 17...
# Processing page 18...
# Processing page 19...
# Processing page 20...
# Processing page 21...
# Processing page 22...
# Processing page 23...
# Processing page 24...
# Processing page 25...
# Page 25 completed

# %%
print(df3.shape)
df3.head()
# Out:
# (88, 8)
#    Rating                                          Job Title  \
# 0     1.0                                      Data Engineer
# 1     1.0                                     Data Scientist
# 2     1.0                                      Data Engineer
# 3     1.0                                     Data Scientist
# 4     1.0  Comcast Busines Analyst 3, Enterprise Data & A...
#
#                       Company  \
# 0             Valen Analytics
# 1  Aegis Premier Technologies
# 2                      Code42
# 3           Fluid Truck Share
# 4                     Comcast
#
#                                          Description  \
# 0  Join a high performing and rapidly growing tea...
# 1  About Us We are a group of passionate technolo...
# 2  WHAT YOU’LL BE DOING:\nCode42 is looking for a...
# 3  Fluid is a peer-to-peer community truck sharin...
# 4  Comcast Business offers technology solutions r...
#
#                                              Job URL Keywords Present  \
# 0  https://www.indeed.com/viewjob?jk=1489facad7d0...  [data, science]
# 1  https://www.indeed.com/viewjob?cmp=Aegis-Premi...  [data, science]
# 2  https://www.indeed.com/viewjob?jk=95e4b406998a...  [data, science]
# 3  https://www.indeed.com/viewjob?jk=7c409ecd5a55...  [data, science]
# 4  https://www.indeed.com/viewjob?jk=b4048e3b393a...  [data, science]
#
#   Title Keywords  Page Found
# 0             []          24
# 1             []          22
# 2             []          20
# 3             []          22
# 4             []          20

# %%
# For comparison
df2.head()
# Out:
#    Rating                                 Job Title           Company  \
# 0     1.0            Lead Geospatial Data Scientist  Cloud Agronomics
# 1     1.0                             Data Engineer   Valen Analytics
# 2     1.0  US Contractor - Data Engineer (Big Data)               GHX
# 3     1.0                  Financial Analyst Intern            ViaSat
# 4     1.0        Data Scientist - Behavioral Health     Denver Health
#
#                                          Description  \
# 0  About Us:\nCloud Ag is an AgTech startup apply...
# 1  Join a high performing and rapidly growing tea...
# 2  We work to solve deep technical problems that ...
# 3  Bigger challenges. Bolder ideas. Global impact...
# 4  Job Summary:\n\nUnder minimal supervision, sup...
#
#                                              Job URL Keywords Present  \
# 0  https://www.indeed.com/viewjob?jk=9fef1c79148f...  [data, science]
# 1  https://www.indeed.com/viewjob?jk=1489facad7d0...  [data, science]
# 2  https://www.indeed.com/viewjob?jk=6f750b0761e3...  [data, science]
# 3  https://www.indeed.com/viewjob?jk=5f89afd9020e...  [data, science]
# 4  https://www.indeed.com/viewjob?jk=508970a4e047...  [data, science]
#
#   Title Keywords  Page Found
# 0             []          14
# 1             []           6
# 2             []          15
# 3             []          12
# 4             []           7

# %%
# Save to csv
df3.to_csv("19-12-03-indeed_jobs_pg_16-25.csv", index=False)

# %% [markdown]
# ---
#
# ## Concatenation
#
# It looks like there were some repeats. We shall see how many once I concatenate the dataframes and remove the duplicates.

# %%
# Might as well concatenate all three, in case they all have some uniques
# Put dfs into list and run concat on the list
frames = [df1, df2, df3]

df4 = pd.concat(frames)

# %%
# Look at the results
print(df4.shape)
df4.head()
# Out:
# (222, 8)
#    Rating                Job Title                     Company  \
# 0     1.0            Data Engineer              Seen by Indeed
# 1     1.0           Data Scientist  Aegis Premier Technologies
# 2     1.0  Data Warehouse Engineer              Seen by Indeed
# 3     1.0           Data Scientist                 Merkle Inc.
# 4     1.0           Data Scientist                    Deloitte
#
#                                          Description  \
# 0  Seen by Indeed is a free service that connects...
# 1  About Us We are a group of passionate technolo...
# 2  Seen by Indeed is a free service that connects...
# 3  Job Description\n\nDesign, develop, test, depl...
# 4  Deloitte Services LP includes internal support...
#
#                                              Job URL Keywords Present  \
# 0  https://www.indeed.com/viewjob?jk=790e2b4b32f9...     [d, a, t, a]
# 1  https://www.indeed.com/viewjob?cmp=Aegis-Premi...     [d, a, t, a]
# 2  https://www.indeed.com/viewjob?jk=2246c6b11155...     [d, a, t, a]
# 3  https://www.indeed.com/viewjob?jk=9c9be388d642...     [d, a, t, a]
# 4  https://www.indeed.com/viewjob?jk=1f37f96bae2b...     [d, a, t, a]
#
#   Title Keywords  Page Found
# 0             []           1
# 1             []           1
# 2             []           1
# 3             []           1
# 4             []           1

# %%
# Clean it up using pyjanitor
import janitor
df5 = (df4
       .clean_names()  # Fixes capitalization, whitespace, extra characters
       .remove_columns(column_names=["rating", "title_keywords"])  # Remove useless columns
       # I'll leave "keywords_present in for now"
      )

df5.head()
# Out:
#                  job_title                     company  \
# 0            Data Engineer              Seen by Indeed
# 1           Data Scientist  Aegis Premier Technologies
# 2  Data Warehouse Engineer              Seen by Indeed
# 3           Data Scientist                 Merkle Inc.
# 4           Data Scientist                    Deloitte
#
#                                          description  \
# 0  Seen by Indeed is a free service that connects...
# 1  About Us We are a group of passionate technolo...
# 2  Seen by Indeed is a free service that connects...
# 3  Job Description\n\nDesign, develop, test, depl...
# 4  Deloitte Services LP includes internal support...
#
#                                              job_url keywords_present  \
# 0  https://www.indeed.com/viewjob?jk=790e2b4b32f9...     [d, a, t, a]
# 1  https://www.indeed.com/viewjob?cmp=Aegis-Premi...     [d, a, t, a]
# 2  https://www.indeed.com/viewjob?jk=2246c6b11155...     [d, a, t, a]
# 3  https://www.indeed.com/viewjob?jk=9c9be388d642...     [d, a, t, a]
# 4  https://www.indeed.com/viewjob?jk=1f37f96bae2b...     [d, a, t, a]
#
#    page_found
# 0           1
# 1           1
# 2           1
# 3           1
# 4           1

# %%
# Now let's find out how many duplicates there are
# If they are duplicates, the Description should be exactly the same
df6 = df5.drop_duplicates(subset=["description"])
df6.shape
# Out:
# (177, 6)

# %%
# Looks like there were 45 duplicates
df5.shape[0] - df6.shape[0]
# Out:
# 45

# %%
# Save it again
df6.to_csv("19-12-03-indeed_jobs_pg_1-25.csv", index=False)

# %% [markdown]
# ---
#
# ### "Seen by Indeed"
#
# I noticed there are some where the company name didn't get scraped correctly, and the record says "Seen by Indeed".
#
# Before I do anything about those, I just want to see how many of these records exist.

# %%
df6.select_dtypes(exclude="number").describe().T.sort_values(by="unique")
# Out:
#                  count unique  \
# keywords_present   177      5
# company            177    113
# job_title          177    123
# description        177    177
# job_url            177    177
#
#                                                                 top freq
# keywords_present                                    [data, science]   88
# company                                           No company found.    9
# job_title                                            Data Scientist   26
# description       CLEARANCE IS REQUIRED!\n\nRelocation is not a ...    1
# job_url           https://www.indeed.com/viewjob?jk=a4abb701f0d9...    1

# %%
df6["company"].value_counts()
# Out:
# No company found.                       9
# Deloitte                                6
# CenturyLink                             5
# Booz Allen Hamilton                     5
# xentity corporation                     4
# LOCKHEED MARTIN CORPORATION             4
# Ball Aerospace                          3
# Aegon                                   3
# Pearson                                 3
# University of Colorado Boulder          3
# CBRE                                    3
# Comcast                                 3
# University of Colorado                  2
# Decentrix                               2
# Fluid Truck Share                       2
# ViaSat                                  2
# Transamerica                            2
# CitiusTech                              2
# JumpCloud                               2
# Dataiku                                 2
# Cloud Agronomics                        2
# Recurly                                 2
# DISH                                    2
# Horizontal                              2
# Charles Schwab                          2
# National Renewable Energy Laboratory    2
# Workday                                 2
# Valen Analytics                         2
# CACI                                    2
# Amazon.com Services, Inc.               2
#                                        ..
# Tax Guard                               1
# Amazon Web Services, Inc.               1
# Vadata, Inc.                            1
# Inscripta                               1
# Aegis Premier Technologies              1
# SpotX                                   1
# HERE Technologies                       1
# Empower Retirement                      1
# Viola AI                                1
# J.D. Power                              1
# BCS Data Center Operations              1
# Flexential                              1
# Takeoffs, Inc.                          1
# BPMLinks                                1
# Rentokil Steritech                      1
# Denver Health and Hospital Authority    1
# Neya Systems LLC                        1
# Honey                                   1
# NASDAQ                                  1
# Hyperia                                 1
# EXFO inc.                               1
# Merkle Inc.                             1
# RE/MAX, LLC                             1
# JP Morgan Chase                         1
# Wikimedia Foundation                    1
# TENERE Inc                              1
# KPMG                                    1
# Pinnacol Assurance                      1
# ArcherDX, INC.                          1
# Amazon Data Services, Inc.              1
# Name: company, Length: 113, dtype: int64

# %%
# Actually only 1 of them!
df6["company"].value_counts()["Seen by Indeed"]
# Out:
# 1

# %% [markdown]
# > That is actually much better than I thought.
#
# There are only 9 companies for which the name wasn't scraped correctly, and it looks like 1 that is "Seen by Indeed".
#
# The incorrectly scraped names can be dropped, then the dataset will be ready to go for NLP!

# %%
df7 = df6[df6["company"] != "Seen by Indeed"]
df7.shape
# Out:
# (176, 6)

# %%
df7.dtypes
# Out:
# job_title            object
# company              object
# description          object
# job_url              object
# keywords_present    float64
# page_found            int64
# dtype: object

# %%
# Strip whitespace from all of the columns data
for col in df7.columns:
    if df7[col].dtype == "object":
        df7[col] = df7[col].str.strip()
# Out:
# /Users/Tobias/.vega/nlp-9igaqrSk/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
pd.options.display.max_colwidth = 200
df6[df6["company"] == "No company found."]
# Out:
#                                 job_title            company  \
# 28     Associate Research Science Analyst  No company found.
# 83         Data Engineer (Mid and Senior)  No company found.
# 122  Data Scientist for Materials Science  No company found.
# 135                               Analyst  No company found.
# 156                        Data Scientist  No company found.
# 169                  Python Data Engineer  No company found.
# 55                   Senior Data Engineer  No company found.
# 79             Data Scientist Snr Manager  No company found.
# 108  Data Intelligence/Analytics Engineer  No company found.
#
#                                                                                                                                                                                                  description  \
# 28   About GutCheck\n--------------\n\nAt GutCheck, we pioneered agile market research to provide our clients with actionable answers and insights, globally, at the speed of their business. We believe ...
# 83   Data Engineer, Mid to Senior Level\nDatalere team members lead by example, focus on customer needs and have a thirst to learn all they can about data analytics. Successful candidates are self-star...
# 122  Posting Title\nData Scientist for Materials Science\n.\nLocation\nCO - Golden\n.\nPosition Type\nLimited Term (Fixed Term)\n.\nHours Per Week\n40\n.\nJob Description\nThe Data, Analysis and Visual...
# 135  Reach Your Peak at Vail Resorts. You're someone who pushes boundaries and challenges the status quo. You're brave, ambitious and passionate in everything you do. And we want you on our team. Pursu...
# 156  (6605)\n\nData scientists use data and analytical ability to find and interpret rich data sources; manage large amounts of data despite hardware, software, and bandwidth constraints; merge data so...
# 169  As a data engineer, your general responsibilities will include bolting together the core components of our platform that allow us to interact with utility company data stores, helping build system...
# 55   Company Overview\n\nFanatics is the global leader in licensed sports merchandise and changing the way fans purchase their favorite team apparel and jerseys. Through an innovative, tech-infused app...
# 79   Data Scientist Snr Manager-19001924\n\n\nPreferred Qualifications\n\nJob Description:\n\nThe Oracle Data Cloud is on the cutting edge in development of measurement and targeting methodologies for ...
# 108  Job Title: Data Intelligence / Analytics Engineer Company Summary Logical Systems (LSI) LLC, is an established multi-disciplinary engineering company founded in Memphis, Tennessee in 1985. Today, ...
#
#                                                                                                                                                                                                job_url  \
# 28                                                                                                                                  https://www.indeed.com/viewjob?jk=9fcf95972fa1477c&from=serp&vjs=3
# 83                                                                                                                                  https://www.indeed.com/viewjob?jk=ab2f7b23069fe431&from=serp&vjs=3
# 122                                                                                                                                 https://www.indeed.com/viewjob?jk=d827816a6c40638f&from=serp&vjs=3
# 135                                                                                                                                 https://www.indeed.com/viewjob?jk=6d05ab5d579549e2&from=serp&vjs=3
# 156  https://www.indeed.com/viewjob?jk=6543e0fe2cc49c33&tk=1dr7il64533g4001&from=serp&vjs=3&advn=2509720981551603&adid=325531189&sjdu=i6xVERweJM_pVUvgf-Mzud2KHack-wE2Lb7KQz0L0LaB6A3rKzwVBeWWBkx9kBdQ
# 169                                                                                                                                 https://www.indeed.com/viewjob?jk=7d521d3b4c8d8915&from=serp&vjs=3
# 55                                                                                                                                  https://www.indeed.com/viewjob?jk=14d283ce293fc6eb&from=serp&vjs=3
# 79                                                                                                                                  https://www.indeed.com/viewjob?jk=0dc435180e844868&from=serp&vjs=3
# 108                                                                    https://www.indeed.com/viewjob?cmp=Logical-Systems-Incorporated&t=Data+Intelligence+Analytic+Engineer&jk=8a02e5b9dbc466ef&vjs=3
#
#      keywords_present  page_found
# 28                NaN           6
# 83                NaN          12
# 122               NaN           3
# 135               NaN           5
# 156               NaN          12
# 169               NaN          13
# 55                NaN          17
# 79                NaN          18
# 108               NaN          16

# %%
df7.iloc[28]["company"]
# Out:
# 'No company found.'

# %%
# Replace the missing values by hand
df7.at[28, "company"] = "GutCheck"

# %%
df7.iloc[28]["company"]
# Out:
# 'GutCheck'

# %%
def replace_value(df, index: int, column: str, value: str):
    """Replaces the value at index, column with value."""
    print(df.iloc[index][column])  # Before
    df.at[index, column] = value
    print(df.iloc[index][column])  # After

# %%
# The index numbers are off, so resetting them
df8 = df7.reset_index()
df8.head()
# Out:
#    index                          job_title                     company  \
# 0      1                     Data Scientist  Aegis Premier Technologies
# 1      3                     Data Scientist                 Merkle Inc.
# 2      4                     Data Scientist                    Deloitte
# 3      5  Data Scientist|| Machine Learning                Expedite LLC
# 4      6                     Data Scientist                       Honey
#
#                                                                                                                                                                                                description  \
# 0  About Us We are a group of passionate technology professionals who are committed to delivering best-in-class data, data science and software solutions for the non-profit space. We care deeply abou...
# 1  Job Description\n\nDesign, develop, test, deploy and maintain machine learning techniques for Merkle data products. The products include identify, feature generation, propensity models, look-alike...
# 2  Deloitte Services LP includes internal support areas such as Sales Excellence, Marketing and Communications, Human Resources/Talent, Information Technology, Facilities Management, and Financial Su...
# 3  Job SummaryJob Title: Data Scientist|| Machine learningWork Location: Bloomfield, CODuration: 12+monthsMust have skills (1-5):1. Understanding of Statistics2. Statistical Programming3. Statistical...
# 4  Honey is a fast-growing startup based in Los Angeles. Our online shopping platform offers users a smarter way to shop. Through a simple browser extension, we open up instant access to exclusive sa...
#
#                                                                                                                                                                                                    job_url  \
# 0  https://www.indeed.com/viewjob?cmp=Aegis-Premier-Technologies&t=Data+Scientist&jk=d8891916469e042c&sjdu=QwrRXKrqZ3CNX5W-O9jEveJgZ7DRbh_ySwPONsqRa9ZW4N-0leXNJ1nUuiJ-kR7vVSLM815TvZxPISFQtteDJw&adid=...
# 1                                                                                                                                       https://www.indeed.com/viewjob?jk=9c9be388d6427692&from=serp&vjs=3
# 2                                                                                                                                       https://www.indeed.com/viewjob?jk=1f37f96bae2be3f8&from=serp&vjs=3
# 3                                                                                              https://www.indeed.com/viewjob?cmp=Expedite-LLC&t=Data+Scientist+Machine+Learning&jk=8c6aa71b57967d9a&vjs=3
# 4                                                                                                                                       https://www.indeed.com/viewjob?jk=bad61334b2d1c88a&from=serp&vjs=3
#
#    keywords_present  page_found
# 0               NaN           1
# 1               NaN           1
# 2               NaN           1
# 3               NaN           1
# 4               NaN           1

# %%
# Look again for the correct indices
df8[df8["company"] == "No company found."]
# Out:
#      index                             job_title            company  \
# 54      83        Data Engineer (Mid and Senior)  No company found.
# 64     122  Data Scientist for Materials Science  No company found.
# 68     135                               Analyst  No company found.
# 77     156                        Data Scientist  No company found.
# 85     169                  Python Data Engineer  No company found.
# 135     55                  Senior Data Engineer  No company found.
# 139     79            Data Scientist Snr Manager  No company found.
# 155    108  Data Intelligence/Analytics Engineer  No company found.
#
#                                                                                                                                                                                                  description  \
# 54   Data Engineer, Mid to Senior Level\nDatalere team members lead by example, focus on customer needs and have a thirst to learn all they can about data analytics. Successful candidates are self-star...
# 64   Posting Title\nData Scientist for Materials Science\n.\nLocation\nCO - Golden\n.\nPosition Type\nLimited Term (Fixed Term)\n.\nHours Per Week\n40\n.\nJob Description\nThe Data, Analysis and Visual...
# 68   Reach Your Peak at Vail Resorts. You're someone who pushes boundaries and challenges the status quo. You're brave, ambitious and passionate in everything you do. And we want you on our team. Pursu...
# 77   (6605)\n\nData scientists use data and analytical ability to find and interpret rich data sources; manage large amounts of data despite hardware, software, and bandwidth constraints; merge data so...
# 85   As a data engineer, your general responsibilities will include bolting together the core components of our platform that allow us to interact with utility company data stores, helping build system...
# 135  Company Overview\n\nFanatics is the global leader in licensed sports merchandise and changing the way fans purchase their favorite team apparel and jerseys. Through an innovative, tech-infused app...
# 139  Data Scientist Snr Manager-19001924\n\n\nPreferred Qualifications\n\nJob Description:\n\nThe Oracle Data Cloud is on the cutting edge in development of measurement and targeting methodologies for ...
# 155  Job Title: Data Intelligence / Analytics Engineer Company Summary Logical Systems (LSI) LLC, is an established multi-disciplinary engineering company founded in Memphis, Tennessee in 1985. Today, ...
#
#                                                                                                                                                                                                job_url  \
# 54                                                                                                                                  https://www.indeed.com/viewjob?jk=ab2f7b23069fe431&from=serp&vjs=3
# 64                                                                                                                                  https://www.indeed.com/viewjob?jk=d827816a6c40638f&from=serp&vjs=3
# 68                                                                                                                                  https://www.indeed.com/viewjob?jk=6d05ab5d579549e2&from=serp&vjs=3
# 77   https://www.indeed.com/viewjob?jk=6543e0fe2cc49c33&tk=1dr7il64533g4001&from=serp&vjs=3&advn=2509720981551603&adid=325531189&sjdu=i6xVERweJM_pVUvgf-Mzud2KHack-wE2Lb7KQz0L0LaB6A3rKzwVBeWWBkx9kBdQ
# 85                                                                                                                                  https://www.indeed.com/viewjob?jk=7d521d3b4c8d8915&from=serp&vjs=3
# 135                                                                                                                                 https://www.indeed.com/viewjob?jk=14d283ce293fc6eb&from=serp&vjs=3
# 139                                                                                                                                 https://www.indeed.com/viewjob?jk=0dc435180e844868&from=serp&vjs=3
# 155                                                                    https://www.indeed.com/viewjob?cmp=Logical-Systems-Incorporated&t=Data+Intelligence+Analytic+Engineer&jk=8a02e5b9dbc466ef&vjs=3
#
#      keywords_present  page_found
# 54                NaN          12
# 64                NaN           3
# 68                NaN           5
# 77                NaN          12
# 85                NaN          13
# 135               NaN          17
# 139               NaN          18
# 155               NaN          16

# %%
# Datalere
df8.iloc[85]["company"]
# Out:
# 'No company found.'

# %%
replacements = {
    54: "Datalere",
    64: "National Renewable Energy Laboratory",
    68: "Vail Resorts",
    77: "Horizontal",
    85: "Horizontal",
    135: "Fanatics Inc",
    139: "Oracle",
    155: "Logical Systems Incorporated",
}

for co in replacements:
    replace_value(df8, co, "company", replacements[co])
# Out:
# No company found.
# Datalere
# No company found.
# National Renewable Energy Laboratory
# No company found.
# Vail Resorts
# No company found.
# Horizontal
# No company found.
# Horizontal
# No company found.
# Fanatics Inc
# No company found.
# Oracle
# No company found.
# Logical Systems Incorporated

# %%
# Confirm it worked as expected
df8[df8["company"] == "No company found."]
# Out:
# Empty DataFrame
# Columns: [index, job_title, company, description, job_url, keywords_present, page_found]
# Index: []

# %%
pd.options.display.max_rows = 200
df8["company"].value_counts()
# Out:
# Deloitte                                     6
# Booz Allen Hamilton                          5
# CenturyLink                                  5
# xentity corporation                          4
# Horizontal                                   4
# LOCKHEED MARTIN CORPORATION                  4
# Aegon                                        3
# Vail Resorts                                 3
# Ball Aerospace                               3
# Comcast                                      3
# CBRE                                         3
# Pearson                                      3
# University of Colorado Boulder               3
# National Renewable Energy Laboratory         3
# CitiusTech                                   2
# Oracle                                       2
# University of Colorado                       2
# DISH                                         2
# JumpCloud                                    2
# Dataiku                                      2
# Fluid Truck Share                            2
# Cloud Agronomics                             2
# Decentrix                                    2
# ViaSat                                       2
# Workday                                      2
# Transamerica                                 2
# Valen Analytics                              2
# Charles Schwab                               2
# Amazon.com Services, Inc.                    2
# CACI                                         2
# Accenture                                    2
# SoundHound Inc.                              2
# Kaiser Permanente                            2
# Apple                                        2
# Colorado Community Managed Care Network      2
# Alteryx, Inc.                                2
# Recurly                                      2
# Front Door                                   1
# Entercom Communications Corp.                1
# Starz Entertainment, LLC                     1
# Josh.ai                                      1
# SSB Consulting Group LLC                     1
# Wowza Media Systems                          1
# Code42                                       1
# Ria Financial                                1
# Amazon Services LLC                          1
# CSG                                          1
# DaVita                                       1
# Western Union                                1
# Cytoskeleton                                 1
# Havenly                                      1
# Fanatics Inc                                 1
# Proofpoint                                   1
# DarkOwl                                      1
# Quotient Technology Inc.                     1
# Denver Health                                1
# Astra LLC                                    1
# SonderMind                                   1
# Ibotta                                       1
# BryterCX                                     1
# ThoughtWorks                                 1
# Bank of America                              1
# Terumo BCT, Inc.                             1
# Savantis Solutions LLC                       1
# ServiceSource                                1
# Betsol                                       1
# Flexential                                   1
# General Assembly                             1
# ICF                                          1
# J.D. Power                                   1
# Hyperia                                      1
# Datalere                                     1
# Takeoffs, Inc.                               1
# CDW                                          1
# The Steritech Group, Inc.                    1
# Arrow Electronics, Inc.                      1
# BP                                           1
# Expedite LLC                                 1
# GutCheck                                     1
# GHX                                          1
# Insurity                                     1
# Gates Corporation                            1
# PHOENIX                                      1
# Pricesenz                                    1
# RingCentral                                  1
# Tax Guard                                    1
# Amazon Web Services, Inc.                    1
# Vadata, Inc.                                 1
# Inscripta                                    1
# Aegis Premier Technologies                   1
# SpotX                                        1
# HERE Technologies                            1
# InVision                                     1
# Empower Retirement                           1
# Dignity Health - Corporate Service Center    1
# RE/MAX, LLC                                  1
# BPMLinks                                     1
# Rentokil Steritech                           1
# Denver Health and Hospital Authority         1
# Neya Systems LLC                             1
# Honey                                        1
# NASDAQ                                       1
# FullContact                                  1
# Logical Systems Incorporated                 1
# Merkle Inc.                                  1
# Viola AI                                     1
# JP Morgan Chase                              1
# Wikimedia Foundation                         1
# TENERE Inc                                   1
# KPMG                                         1
# BCS Data Center Operations                   1
# Pinnacol Assurance                           1
# ArcherDX, INC.                               1
# EXFO inc.                                    1
# Amazon Data Services, Inc.                   1
# Name: company, dtype: int64

# %%
df8.head()
# Out:
#    index                          job_title                     company  \
# 0      1                     Data Scientist  Aegis Premier Technologies
# 1      3                     Data Scientist                 Merkle Inc.
# 2      4                     Data Scientist                    Deloitte
# 3      5  Data Scientist|| Machine Learning                Expedite LLC
# 4      6                     Data Scientist                       Honey
#
#                                                                                                                                                                                                description  \
# 0  About Us We are a group of passionate technology professionals who are committed to delivering best-in-class data, data science and software solutions for the non-profit space. We care deeply abou...
# 1  Job Description\n\nDesign, develop, test, deploy and maintain machine learning techniques for Merkle data products. The products include identify, feature generation, propensity models, look-alike...
# 2  Deloitte Services LP includes internal support areas such as Sales Excellence, Marketing and Communications, Human Resources/Talent, Information Technology, Facilities Management, and Financial Su...
# 3  Job SummaryJob Title: Data Scientist|| Machine learningWork Location: Bloomfield, CODuration: 12+monthsMust have skills (1-5):1. Understanding of Statistics2. Statistical Programming3. Statistical...
# 4  Honey is a fast-growing startup based in Los Angeles. Our online shopping platform offers users a smarter way to shop. Through a simple browser extension, we open up instant access to exclusive sa...
#
#                                                                                                                                                                                                    job_url  \
# 0  https://www.indeed.com/viewjob?cmp=Aegis-Premier-Technologies&t=Data+Scientist&jk=d8891916469e042c&sjdu=QwrRXKrqZ3CNX5W-O9jEveJgZ7DRbh_ySwPONsqRa9ZW4N-0leXNJ1nUuiJ-kR7vVSLM815TvZxPISFQtteDJw&adid=...
# 1                                                                                                                                       https://www.indeed.com/viewjob?jk=9c9be388d6427692&from=serp&vjs=3
# 2                                                                                                                                       https://www.indeed.com/viewjob?jk=1f37f96bae2be3f8&from=serp&vjs=3
# 3                                                                                              https://www.indeed.com/viewjob?cmp=Expedite-LLC&t=Data+Scientist+Machine+Learning&jk=8c6aa71b57967d9a&vjs=3
# 4                                                                                                                                       https://www.indeed.com/viewjob?jk=bad61334b2d1c88a&from=serp&vjs=3
#
#    keywords_present  page_found
# 0               NaN           1
# 1               NaN           1
# 2               NaN           1
# 3               NaN           1
# 4               NaN           1

# %%
df8 = df8.drop(columns=["index"])
df8.head()
# Out:
#                            job_title                     company  \
# 0                     Data Scientist  Aegis Premier Technologies
# 1                     Data Scientist                 Merkle Inc.
# 2                     Data Scientist                    Deloitte
# 3  Data Scientist|| Machine Learning                Expedite LLC
# 4                     Data Scientist                       Honey
#
#                                                                                                                                                                                                description  \
# 0  About Us We are a group of passionate technology professionals who are committed to delivering best-in-class data, data science and software solutions for the non-profit space. We care deeply abou...
# 1  Job Description\n\nDesign, develop, test, deploy and maintain machine learning techniques for Merkle data products. The products include identify, feature generation, propensity models, look-alike...
# 2  Deloitte Services LP includes internal support areas such as Sales Excellence, Marketing and Communications, Human Resources/Talent, Information Technology, Facilities Management, and Financial Su...
# 3  Job SummaryJob Title: Data Scientist|| Machine learningWork Location: Bloomfield, CODuration: 12+monthsMust have skills (1-5):1. Understanding of Statistics2. Statistical Programming3. Statistical...
# 4  Honey is a fast-growing startup based in Los Angeles. Our online shopping platform offers users a smarter way to shop. Through a simple browser extension, we open up instant access to exclusive sa...
#
#                                                                                                                                                                                                    job_url  \
# 0  https://www.indeed.com/viewjob?cmp=Aegis-Premier-Technologies&t=Data+Scientist&jk=d8891916469e042c&sjdu=QwrRXKrqZ3CNX5W-O9jEveJgZ7DRbh_ySwPONsqRa9ZW4N-0leXNJ1nUuiJ-kR7vVSLM815TvZxPISFQtteDJw&adid=...
# 1                                                                                                                                       https://www.indeed.com/viewjob?jk=9c9be388d6427692&from=serp&vjs=3
# 2                                                                                                                                       https://www.indeed.com/viewjob?jk=1f37f96bae2be3f8&from=serp&vjs=3
# 3                                                                                              https://www.indeed.com/viewjob?cmp=Expedite-LLC&t=Data+Scientist+Machine+Learning&jk=8c6aa71b57967d9a&vjs=3
# 4                                                                                                                                       https://www.indeed.com/viewjob?jk=bad61334b2d1c88a&from=serp&vjs=3
#
#    keywords_present  page_found
# 0               NaN           1
# 1               NaN           1
# 2               NaN           1
# 3               NaN           1
# 4               NaN           1

# %%
df8.shape
# Out:
# (176, 6)

# %% [markdown]
# ---
#
# ## The Final Export
#
# Now the dataset is all ready to go. Last export for this notebook.
#
# The final shape is `(176, 6)`.
#
# Not too shabby!

# %%
# Final csv before NLP
df8.to_csv("19-12-03-indeed_jobs.csv", index=False)

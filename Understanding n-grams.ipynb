# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Generating-text-from-probability" data-toc-modified-id="Generating-text-from-probability-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Generating text from probability</a></span><ul class="toc-item"><li><span><a href="#Understanding-n-grams" data-toc-modified-id="Understanding-n-grams-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Understanding n-grams</a></span><ul class="toc-item"><li><span><a href="#How-do-we-predict-words?" data-toc-modified-id="How-do-we-predict-words?-1.1.1"><span class="toc-item-num">1.1.1&nbsp;&nbsp;</span>How do we predict words?</a></span><ul class="toc-item"><li><span><a href="#Understanding-notation" data-toc-modified-id="Understanding-notation-1.1.1.1"><span class="toc-item-num">1.1.1.1&nbsp;&nbsp;</span>Understanding notation</a></span></li></ul></li><li><span><a href="#Predicting-joint-probablity" data-toc-modified-id="Predicting-joint-probablity-1.1.2"><span class="toc-item-num">1.1.2&nbsp;&nbsp;</span>Predicting joint probablity</a></span></li><li><span><a href="#Bi-gram-Example" data-toc-modified-id="Bi-gram-Example-1.1.3"><span class="toc-item-num">1.1.3&nbsp;&nbsp;</span>Bi-gram Example</a></span><ul class="toc-item"><li><span><a href="#A-bit-of-pre-processing" data-toc-modified-id="A-bit-of-pre-processing-1.1.3.1"><span class="toc-item-num">1.1.3.1&nbsp;&nbsp;</span>A bit of pre-processing</a></span></li><li><span><a href="#Normalize-the-tokens" data-toc-modified-id="Normalize-the-tokens-1.1.3.2"><span class="toc-item-num">1.1.3.2&nbsp;&nbsp;</span>Normalize the tokens</a></span></li><li><span><a href="#bi-gram-distribution-counts" data-toc-modified-id="bi-gram-distribution-counts-1.1.3.3"><span class="toc-item-num">1.1.3.3&nbsp;&nbsp;</span>bi-gram distribution counts</a></span></li><li><span><a href="#bi-gram-probability" data-toc-modified-id="bi-gram-probability-1.1.3.4"><span class="toc-item-num">1.1.3.4&nbsp;&nbsp;</span>bi-gram probability</a></span></li></ul></li><li><span><a href="#Generating-text" data-toc-modified-id="Generating-text-1.1.4"><span class="toc-item-num">1.1.4&nbsp;&nbsp;</span>Generating text</a></span><ul class="toc-item"><li><span><a href="#Try-again-with-tokenized-sentences" data-toc-modified-id="Try-again-with-tokenized-sentences-1.1.4.1"><span class="toc-item-num">1.1.4.1&nbsp;&nbsp;</span>Try again with tokenized sentences</a></span></li></ul></li></ul></li></ul></li></ul></div>

# %% [markdown]
# # Generating text from probability

# %% [markdown]
# ## Understanding n-grams
# A n-gram is a predctive word model, where n represents the count of word sequences.
#     1. For example a 2-gram would be a bigram like "I ate"
#     2. A 3-gram would be a trigram, like "I ate chicken"
#
#     A. We use n-gram models to estimate the probability of the last word of an n-gram
#     given the previous words.
#     B. We also assign probability to the entire sequence of words.

# %% [markdown]
# ### How do we predict words?
#    ![image](https://static.independent.co.uk/s3fs-public/thumbnails/image/2017/05/14/13/brain.jpg?w968h681)
#
#     1. First we take P(w|h). Or in English the probability of a word given some history
#         A. We can think of history as a string, or document, or collection of documents.
#            It is merely a reference to our current "working space".
#
#         B. Example: Let's say we have a string "its steam is so hot that"and
#         we find ourselves wanting to predict the proability that the next word would be
#         "the".
#
#            We would set up on equation like so
#            P(the|its steam is so hot that)
#
#                B.2. There are a few ways we could try to predict this.
#
#                    A. One way would be to predict relative frequency counts.
#                    We would take a very large collection of documents ( a corpus ).
#                    For example all written text on the world wide web,
#                    take the count of times we see a match for our string s,
#                    and a count of how many times it's followed by the word "the".
#
#                        A.2. Our probability now looks like this
#                           P(the|its steam is so hot that) =
#
#                             C(its steam is so hot that)
#                             ---------------------------
#                             C(its steam is so hot that the)
#
#                    B. Like the first problem, if we wanted to know the combined
#                    probability of the entire sentence we could answer such a question by
#                    asking out of all possible sequences of five words, how many of them
#                    are "its steam is so hot"
#
#                B.3 The problem with both of these methods is that they are
#
#                    1. Likely to be extremely ineffecient
#
#                    2. Likely to have an incredibly hard time finding matching cases,
#                    even amongst enourmous sources of data.
#
#                    3. Language is one of the most creative and inventive things
#                    humans have, and new sentences are made daily. Such methods cannot
#                    hope to keep up with an ever evolving corpus.

# %% [markdown]
# #### Understanding notation
# Let the following represent our values in our system of predictions
#
#   > N = a sequence of words | w<sub>1</sub>, w<sub>2</sub> ... w<sub>n</sub> | w<sup>n - 1</sup><sub>1</sub> = w<sub>1</sub>, w<sub>2</sub> ... w<sub>n - 1</sub>
#   w = word
#   W = the entire word sequence
#   h = history
#   joint probablity = P(X = w<sub>1</sub>, Y = w<sub>2</sub>, ..., W = w<sub>n</sub> | P(w<sub>1</sub>, w<sub>2</sub>, ..., w<sub>n</sub>)

# %% [markdown]
# ### Predicting joint probablity
# 1. One method of predicting joint probability for word sequences would be to decompose their probablity by using the chain rule of probability.  https://en.wikipedia.org/wiki/Chain_rule_(probability)
#
#     * If we apply the chain rule to our words, we get something that looks like this
#     > P(w<sup>n</sup><sub>1</sub>) = P(w<sub>1</sub>)P(w<sub>2</sub>|w<sub>1</sub>)P(w<sub>3</sub>|w<sup>2</sup><sub>1</sub>)
#
#     * What this essentially tells us is the formula for computing the combined probability of a word sequence and computing the conditional probablity of a specific word if we are given previous words.
#
#         A. There is a problem here though. We are back to the previous problem of not being able to predict the probablity of a given word, as it could quite literally be a brand new sentence.
#
#         * This is where the n-gram comes in to save us.
#             1. Instead of trying to compute the probablity of a word given it's entire history, we can approximate the history by using only the last few words.
#
#             2. For example, if we used a bigram model, we approximate that P(w<sub>n</sub>|w<sub>n-1</sub>)
#             Or in our case we have the string we used earlier.
#
#             P(the|its steam is so hot that)
#             This now becomes P(the|that)
#
#             We change our assumption so that the probability of a word depends only on the previous word/words given by the size of our specified n-gram.
#                 1. This type of assumption is called a Markov Assumption.
#                 Markov models are(from a birds eye view) a type of probablistic model that assumes we can predict the future without looking into the past. If you'd like a better overview, please give my blog a read. https://towardsdatascience.com/understanding-markov-decision-processes-b5862c192ddb
#
# -------------------------------------------------------------------------------------------------------
#  > By now you're probably asking, wait a second, how do we estimate an n-grams probabilities though?
# We can use a metric called the maximum likelihood estimation, or MLE. We get this metric by taking the counts of words from a corpus, and normalizing these counts so that they all fall between 0 and 1.
#        We can decribe this like so:
#        P(w<sub>n</sub>|w<sub>n−1</sub>) = C(w<sub>n−1</sub>w<sub>n</sub>) / C(w<sub>n−1</sub>)
#        This can be applied to every single word in a corpus

# %% [markdown]
# ### Bi-gram Example
# Using 2004 Blogger data from a massive collection of text parsed from xml files
# Let's explore the word "japanese"

# %%
import contractions
import pandas as pd 
import string

from bs4 import BeautifulSoup
from jupyterthemes import jtplot
from nltk import word_tokenize, sent_tokenize, pos_tag, bigrams, FreqDist, ConditionalFreqDist, ConditionalProbDist, MLEProbDist
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer

# %%
# !jt -t onedork -fs 95 -altp -tfs 11 -nfs 115 -cellw 88% -T
# currently installed theme will be used to
# set plot style if no arguments provided
jtplot.style()

# %%
# open and parse a single xml file, stripping it's tag metadata and returning only textual elements
with open(r"C:\Users\edwar\Downloads\blogs\blogs\5114.male.25.indUnk.Scorpio.xml") as file:
    soup = BeautifulSoup(file, 'lxml')
    xml_text = soup.find_all(text=True)
    processed_text_initial = ' '.join(xml_text)

# %% [markdown]
# #### A bit of pre-processing

# %%
# remove a few odd artifacts that are easier to manually extract, and one random word that represents links while we're at it. 
processed_text = processed_text_initial.replace('\n', '')
processed_text = processed_text.replace('\'', '')
processed_text = processed_text.replace('urlLink', '')
mapping = [ ('January', ''), ('February', ''), ('March', ''), ('April', ''), ('May', ''), ('June', ''), ('July', ''), ('August', ''), ('September', ''), 
           ('October', ''), ('November', ''), ('December', '') ]

# begin mapping
for k, v in mapping:
    processed_text = processed_text.replace(k, v)
    
# we split to remove duplicate whitespaces, of which they are many many cases, and rejoin to have nice formatting.
processed_text = processed_text.split()
processed_text = ' '.join(processed_text)

processed_text
# Out:
# '28,,2001 Slashdot raises lots of interesting thoughts about banner ads . The idea is to let users control the ad delivery, and even to allow users to comment on ads. 27,,2001 The Merchants of Cool , a Frontline documentary featuring Mindjack advisory board member Douglas Rushkoff, is on PBS tonight. Check your local listings for the time. 26,,2001 ATMs dispensing music? I dont quite see the logic in that. Im not entirely against paying a nominal fee for music, or any other media, but if I do have to pay for it Id be much more likely to buy stuff from my own PC. 22,,2001 My chair started squeaking a few days ago and its driving me nuts! 20,,2001 The New York Press has a lenghty article about the post dotcom crash scene thats worth reading. 18,,2001 Francis Collins 10 Most Surprising Things About the Human Genome . 18,,2001 FILMSPEED has great movies you can download for free. The Third Man, in particular, is one of my favorite films of all time. 17,,2001 For sale: An STB nVidia ZX 8MB 3D Accelerator (AGP) and a 40X NEC CD-ROM drive. Interesting trades considered. 16,,2001 Ive started uploading stuff to my live365.com radio station. Theres not much there yet but youre welcome to listen . (cable/dsl or higher required) 14,,2001 FEEDs latest special issue is an excellent examination of video games , with contributions from Carl Steadman, Steven Johnson, Justin Hall and others. Dont miss it. 14,,2001 New DVD! The Maltese Falcon . 14,,2001 I once had a personal homepage, long before weblogs came into fashion, but never managed to update more than a couple of times a year. Heres hoping Ill be a bit more successful with this. Big thanks to Bopjet for hosting this and Mindjack . 31,,2001 The Register reports on "war driving" - the wireless equivalent of war dialing. Instead of having your modem dial into thousands of networks until you get in, you just drive within range of a wireless net with your wireless-equipped laptop and hack away. related: The latest issue of CIO has a great feature on wireless. 30,,2001 Short documentary on digital filmmaking and Star Wars Episode II. 27,,2001 Rumour has it that the parent companies of Inside.com and Brills Content will be announcing a merger as early as next Monday. Apparently the two print magazines would fold into one called Brills Inside Content and the two websites would form Media Central Inside.com . Rolls right off the tongue, doesnt it? 27,,2001 Destroy All Monsters - Survivor: Monster Island . My moneys on Mothra. 26,,2001 I just spent some time playing with the beta version of Atmosphere , Adobes new 3D environment software, and thought Id give a couple of quick impressions. Ive always been interested in VR and spent quite a bit of time working in VRML, but I think the inherant problem with VRML was that not enough attention had been given to community. You could build all these really cool places but people couldnt interact in them. You also couldnt easily move from one 3D environment to another without going back and forth between 2D web pages. I was involved with a project that tried to solve some of these problems with VRML (anybody remember Terra Vista?) but it didnt as far as we would have liked. Atmosphere appears to have addressed these problems. Its not the first product to do so, but maybe Adobe has enough muscle for it to gain wide acceptance. 25,,2001 Thanks to Onebox.com I should now be able to receive faxes. Not suprisingly, they dont have local phone numbers for Fredericton so I chose a New York City area code. If anyone wants to give it a whirl, my number is: (212) 894-3748 x2690. 22,,2001 Well, I was supposed to be working. But, through a long trail of procrastination, I ended up redesigning this site. 21,,2001 Quotable Mindjack! From Mike Sugarbakers review of Lemon : "If you have no patience for the lengthy ruminations of brilliant madmen, Lemon isnt for you. But you read Mindjack, so youre probably into that sort of thing, right?" 13,,2001 Mindjack is featured in ...

# %%
# strip contractions
processed_text = contractions.fix(processed_text)

# %%
processed_text
# Out:
# '28,,2001 Slashdot raises lots of interesting thoughts about banner ads . The idea is to let users control the ad delivery, and even to allow users to comment on ads. 27,,2001 The Merchants of Cool , a Frontline documentary featuring Mindjack advisory board member Douglas Rushkoff, is on PBS tonight. Check your local listings for the time. 26,,2001 ATMs dispensing music? I do not quite see the logic in that. I am not entirely against paying a nominal fee for music, or any other media, but if I do have to pay for it Id be much more likely to buy stuff from my own PC. 22,,2001 My chair started squeaking a few days ago and its driving me nuts! 20,,2001 The New York Press has a lenghty article about the post dotcom crash scene that is worth reading. 18,,2001 Francis Collins 10 Most Surprising Things About the Human Genome . 18,,2001 FILMSPEED has great movies you can download for free. The Third Man, in particular, is one of my favorite films of all time. 17,,2001 For sale: An STB nVidia ZX 8MB 3D Accelerator (AGP) and a 40X NEC CD-ROM drive. Interesting trades considered. 16,,2001 I have started uploading stuff to my live365.com radio station. there is not much there yet but you are welcome to listen . (cable/dsl or higher required) 14,,2001 FEEDs latest special issue is an excellent examination of video games , with contributions from Carl Steadman, Steven Johnson, Justin Hall and others. do not miss it. 14,,2001 New DVD! The Maltese Falcon . 14,,2001 I once had a personal homepage, long before weblogs came into fashion, but never managed to update more than a couple of times a year. Heres hoping I will be a bit more successful with this. Big thanks to Bopjet for hosting this and Mindjack . 31,,2001 The Register reports on "war driving" - the wireless equivalent of war dialing. Instead of having your modem dial into thousands of networks until you get in, you just drive within range of a wireless net with your wireless-equipped laptop and hack away. related: The latest issue of CIO has a great feature on wireless. 30,,2001 Short documentary on digital filmmaking and Star Wars Episode II. 27,,2001 Rumour has it that the parent companies of Inside.com and Brills Content will be announcing a merger as early as next Monday. Apparently the two print magazines would fold into one called Brills Inside Content and the two websites would form Media Central Inside.com . Rolls right off the tongue, does not it? 27,,2001 Destroy All Monsters - Survivor: Monster Island . My moneys on Mothra. 26,,2001 I just spent some time playing with the beta version of Atmosphere , Adobes new 3D environment software, and thought Id give a couple of quick impressions. I have always been interested in VR and spent quite a bit of time working in VRML, but I think the inherant problem with VRML was that not enough attention had been given to community. You could build all these really cool places but people could not interact in them. You also could not easily move from one 3D environment to another without going back and forth between 2D web pages. I was involved with a project that tried to solve some of these problems with VRML (anybody remember Terra Vista?) but it did not as far as we would have liked. Atmosphere appears to have addressed these problems. Its not the first product to do so, but maybe Adobe has enough muscle for it to gain wide acceptance. 25,,2001 Thanks to Onebox.com I should now be able to receive faxes. Not suprisingly, they do not have local phone numbers for Fredericton so I chose a New York City area code. If anyone wants to give it a whirl, my number is: (212) 894-3748 x2690. 22,,2001 Well, I was supposed to be working. But, through a long trail of procrastination, I ended up redesigning this site. 21,,2001 Quotable Mindjack! From Mike Sugarbakers review of Lemon : "If you have no patience for the lengthy ruminations of brilliant madmen, Lemon is not for you. But you read Mindjack, so you are probably into that sort of thing, right ...

# %%
# lemmatize verb forms 
lemmatizer = WordNetLemmatizer()
lemon_lemmas = [lemmatizer.lemmatize(i) for i,j in pos_tag(word_tokenize(processed_text))]
lemon_lemmas
# Out:
# ['28',
#  ',',
#  ',2001',
#  'Slashdot',
#  'raise',
#  'lot',
#  'of',
#  'interesting',
#  'thought',
#  'about',
#  'banner',
#  'ad',
#  '.',
#  'The',
#  'idea',
#  'is',
#  'to',
#  'let',
#  'user',
#  'control',
#  'the',
#  'ad',
#  'delivery',
#  ',',
#  'and',
#  'even',
#  'to',
#  'allow',
#  'user',
#  'to',
#  'comment',
#  'on',
#  'ad',
#  '.',
#  '27',
#  ',',
#  ',2001',
#  'The',
#  'Merchants',
#  'of',
#  'Cool',
#  ',',
#  'a',
#  'Frontline',
#  'documentary',
#  'featuring',
#  'Mindjack',
#  'advisory',
#  'board',
#  'member',
#  'Douglas',
#  'Rushkoff',
#  ',',
#  'is',
#  'on',
#  'PBS',
#  'tonight',
#  '.',
#  'Check',
#  'your',
#  'local',
#  'listing',
#  'for',
#  'the',
#  'time',
#  '.',
#  '26',
#  ',',
#  ',2001',
#  'ATMs',
#  'dispensing',
#  'music',
#  '?',
#  'I',
#  'do',
#  'not',
#  'quite',
#  'see',
#  'the',
#  'logic',
#  'in',
#  'that',
#  '.',
#  'I',
#  'am',
#  'not',
#  'entirely',
#  'against',
#  'paying',
#  'a',
#  'nominal',
#  'fee',
#  'for',
#  'music',
#  ',',
#  'or',
#  'any',
#  'other',
#  'medium',
#  ',',
#  'but',
#  'if',
#  'I',
#  'do',
#  'have',
#  'to',
#  'pay',
#  'for',
#  'it',
#  'Id',
#  'be',
#  'much',
#  'more',
#  'likely',
#  'to',
#  'buy',
#  'stuff',
#  'from',
#  'my',
#  'own',
#  'PC',
#  '.',
#  '22',
#  ',',
#  ',2001',
#  'My',
#  'chair',
#  'started',
#  'squeaking',
#  'a',
#  'few',
#  'day',
#  'ago',
#  'and',
#  'it',
#  'driving',
#  'me',
#  'nut',
#  '!',
#  '20',
#  ',',
#  ',2001',
#  'The',
#  'New',
#  'York',
#  'Press',
#  'ha',
#  'a',
#  'lenghty',
#  'article',
#  'about',
#  'the',
#  'post',
#  'dotcom',
#  'crash',
#  'scene',
#  'that',
#  'is',
#  'worth',
#  'reading',
#  '.',
#  '18',
#  ',',
#  ',2001',
#  'Francis',
#  'Collins',
#  '10',
#  'Most',
#  'Surprising',
#  'Things',
#  'About',
#  'the',
#  'Human',
#  'Genome',
#  '.',
#  '18',
#  ',',
#  ',2001',
#  'FILMSPEED',
#  'ha',
#  'great',
#  'movie',
#  'you',
#  'can',
#  'download',
#  'for',
#  'free',
#  '.',
#  'The',
#  'Third',
#  'Man',
#  ',',
#  'in',
#  'particular',
#  ',',
#  'is',
#  'one',
#  'of',
#  'my',
#  'favorite',
#  'film',
#  'of',
#  'all',
#  'time',
#  '.',
#  '17',
#  ',',
#  ',2001',
#  'For',
#  'sale',
#  ':',
#  'An',
#  'STB',
#  'nVidia',
#  'ZX',
#  '8MB',
#  '3D',
#  'Accelerator',
#  '(',
#  'AGP',
#  ')',
#  'and',
#  'a',
#  '40X',
#  'NEC',
#  'CD-ROM',
#  'drive',
#  '.',
#  'Interesting',
#  'trade',
#  'considered',
#  '.',
#  '16',
#  ',',
#  ',2001',
#  'I',
#  'have',
#  'started',
#  'uploading',
#  'stuff',
#  'to',
#  'my',
#  'live365.com',
#  'radio',
#  'station',
#  '.',
#  'there',
#  'is',
#  'not',
#  'much',
#  'there',
#  'yet',
#  'but',
#  'you',
#  'are',
#  'welcome',
#  'to',
#  'listen',
#  '.',
#  '(',
#  'cable/dsl',
#  'or',
#  'higher',
#  'required',
#  ')',
#  '14',
#  ',',
#  ',2001',
#  'FEEDs',
#  'latest',
#  'special',
#  'issue',
#  'is',
#  'an',
#  'excellent',
#  'examination',
#  'of',
#  'video',
#  'game',
#  ',',
#  'with',
#  'contribution',
#  'from',
#  'Carl',
#  'Steadman',
#  ',',
#  'Steven',
#  'Johnson',
#  ',',
#  'Justin',
#  'Hall',
#  'and',
#  'others',
#  '.',
#  'do',
#  'not',
#  'miss',
#  'it',
#  '.',
#  '14',
#  ',',
#  ',2001',
#  'New',
#  'DVD',
#  '!',
#  'The',
#  'Maltese',
#  'Falcon',
#  '.',
#  '14',
#  ',',
#  ',2001',
#  'I',
#  'once',
#  'had',
#  'a',
#  'personal',
#  'homepage',
#  ',',
#  'long',
#  'before',
#  'weblogs',
#  'came',
#  'into',
#  'fashion',
#  ',',
#  'but',
#  'never',
#  'managed',
#  'to',
#  'update',
#  'more',
#  'than',
#  'a',
#  'couple',
#  'of',
#  'time',
#  'a',
#  'year',
#  '.',
#  'Heres',
#  'hoping',
#  'I',
#  'will',
#  'be',
#  'a',
#  'bit',
#  'more',
#  'successful',
#  'with',
#  'this',
#  '.',
#  'Big',
#  'thanks',
#  'to',
#  'Bopjet',
#  'for',
#  'hosting',
#  'this',
#  'and',
#  'Mindjack',
#  '.',
#  '31',
#  ',',
#  ',2001',
#  'The',
#  'Register',
#  'report',
#  'on',
#  '``',
#  'war',
#  'driving',
#  "''",
#  '-',
#  'the',
#  'wireless',
#  'equivalent',
#  'of',
#  'war',
#  'dialing',
#  '.',
#  'Instead',
#  'of',
#  'having',
#  'your',
#  'modem',
#  'dial',
#  'into',
#  'thousand',
#  'of',
#  'network',
#  'until',
#  'you',
#  'get',
#  'in',
#  ',',
#  'you',
#  'just',
#  'drive',
#  'within',
#  'range',
#  'of',
#  'a',
#  'wireless',
#  'net',
#  'with',
#  'your',
#  'wireless-equipped',
#  'laptop',
#  'and',
#  'hack',
#  'away',
#  '.',
#  'related',
#  ':',
#  'The',
#  'latest',
#  'issue',
#  'of',
#  'CIO',
#  'ha',
#  'a',
#  'great',
#  'feature',
#  'on',
#  'wireless',
#  '.',
#  '30',
#  ',',
#  ',2001',
#  'Short',
#  'documentary',
#  'on',
#  'digital',
#  'filmmaking',
#  'and',
#  'Star',
#  'Wars',
#  'Episode',
#  'II',
#  '.',
#  '27',
#  ',',
#  ',2001',
#  'Rumour',
#  'ha',
#  'it',
#  'that',
#  'the',
#  'parent',
#  'company',
#  'of',
#  'Inside.com',
#  'and',
#  'Brills',
#  'Content',
#  'will',
#  'be',
#  'announcing',
#  'a',
#  'merger',
#  'a',
#  'early',
#  'a',
#  'next',
#  'Monday',
#  '.',
#  'Apparently',
#  'the',
#  'two',
#  'print',
#  'magazine',
#  'would',
#  'fold',
#  'into',
#  'one',
#  'called',
#  'Brills',
#  'Inside',
#  'Content',
#  'and',
#  'the',
#  'two',
#  'website',
#  'would',
#  'form',
#  'Media',
#  'Central',
#  'Inside.com',
#  '.',
#  'Rolls',
#  'right',
#  'off',
#  'the',
#  'tongue',
#  ',',
#  'doe',
#  'not',
#  'it',
#  '?',
#  '27',
#  ',',
#  ',2001',
#  'Destroy',
#  'All',
#  'Monsters',
#  '-',
#  'Survivor',
#  ':',
#  'Monster',
#  'Island',
#  '.',
#  'My',
#  'money',
#  'on',
#  'Mothra',
#  '.',
#  '26',
#  ',',
#  ',2001',
#  'I',
#  'just',
#  'spent',
#  'some',
#  'time',
#  'playing',
#  'with',
#  'the',
#  'beta',
#  'version',
#  'of',
#  'Atmosphere',
#  ',',
#  'Adobes',
#  'new',
#  '3D',
#  'environment',
#  'software',
#  ',',
#  'and',
#  'thought',
#  'Id',
#  'give',
#  'a',
#  'couple',
#  'of',
#  'quick',
#  'impression',
#  '.',
#  'I',
#  'have',
#  'always',
#  'been',
#  'interested',
#  'in',
#  'VR',
#  'and',
#  'spent',
#  'quite',
#  'a',
#  'bit',
#  'of',
#  'time',
#  'working',
#  'in',
#  'VRML',
#  ',',
#  'but',
#  'I',
#  'think',
#  'the',
#  'inherant',
#  'problem',
#  'with',
#  'VRML',
#  'wa',
#  'that',
#  'not',
#  'enough',
#  'attention',
#  'had',
#  'been',
#  'given',
#  'to',
#  'community',
#  '.',
#  'You',
#  'could',
#  'build',
#  'all',
#  'these',
#  'really',
#  'cool',
#  'place',
#  'but',
#  'people',
#  'could',
#  'not',
#  'interact',
#  'in',
#  'them',
#  '.',
#  'You',
#  'also',
#  'could',
#  'not',
#  'easily',
#  'move',
#  'from',
#  'one',
#  '3D',
#  'environment',
#  'to',
#  'another',
#  'without',
#  'going',
#  'back',
#  'and',
#  'forth',
#  'between',
#  '2D',
#  'web',
#  'page',
#  '.',
#  'I',
#  'wa',
#  'involved',
#  'with',
#  'a',
#  'project',
#  'that',
#  'tried',
#  'to',
#  'solve',
#  'some',
#  'of',
#  'these',
#  'problem',
#  'with',
#  'VRML',
#  '(',
#  'anybody',
#  'remember',
#  'Terra',
#  'Vista',
#  '?',
#  ')',
#  'but',
#  'it',
#  'did',
#  'not',
#  'a',
#  'far',
#  'a',
#  'we',
#  'would',
#  'have',
#  'liked',
#  '.',
#  'Atmosphere',
#  'appears',
#  'to',
#  'have',
#  'addressed',
#  'these',
#  'problem',
#  '.',
#  'Its',
#  'not',
#  'the',
#  'first',
#  'product',
#  'to',
#  'do',
#  'so',
#  ',',
#  'but',
#  'maybe',
#  'Adobe',
#  'ha',
#  'enough',
#  'muscle',
#  'for',
#  'it',
#  'to',
#  'gain',
#  'wide',
#  'acceptance',
#  '.',
#  '25',
#  ',',
#  ',2001',
#  'Thanks',
#  'to',
#  'Onebox.com',
#  'I',
#  'should',
#  'now',
#  'be',
#  'able',
#  'to',
#  'receive',
#  'fax',
#  '.',
#  'Not',
#  'suprisingly',
#  ',',
#  'they',
#  'do',
#  'not',
#  'have',
#  'local',
#  'phone',
#  'number',
#  'for',
#  'Fredericton',
#  'so',
#  'I',
#  'chose',
#  'a',
#  'New',
#  'York',
#  'City',
#  'area',
#  'code',
#  '.',
#  'If',
#  'anyone',
#  'want',
#  'to',
#  'give',
#  'it',
#  'a',
#  'whirl',
#  ',',
#  'my',
#  'number',
#  'is',
#  ':',
#  '(',
#  '212',
#  ')',
#  '894-3748',
#  'x2690',
#  '.',
#  '22',
#  ',',
#  ',2001',
#  'Well',
#  ',',
#  'I',
#  'wa',
#  'supposed',
#  'to',
#  'be',
#  'working',
#  '.',
#  'But',
#  ',',
#  'through',
#  'a',
#  'long',
#  'trail',
#  'of',
#  'procrastination',
#  ',',
#  'I',
#  'ended',
#  'up',
#  'redesigning',
#  'this',
#  'site',
#  '.',
#  '21',
#  ',',
#  ',2001',
#  'Quotable',
#  'Mindjack',
#  '!',
#  'From',
#  'Mike',
#  'Sugarbakers',
#  'review',
#  'of',
#  'Lemon',
#  ':',
#  '``',
#  'If',
#  'you',
#  'have',
#  'no',
#  'patience',
#  'for',
#  'the',
#  'lengthy',
#  'rumination',
#  'of',
#  'brilliant',
#  'madman',
#  ',',
#  'Lemon',
#  'is',
#  'not',
#  'for',
#  'you',
#  '.',
#  'But',
#  'you',
#  'read',
#  'Mindjack',
#  ',',
#  'so',
#  'you',
#  'are',
#  'probably',
#  'into',
#  'that',
#  'sort',
#  'of',
#  'thing',
#  ',',
#  'right',
#  '?',
#  "''",
#  '13',
#  ',',
#  ',2001',
#  'Mindjack',
#  'is',
#  'featured',
#  'in',
#  'the',
#  'link',
#  'section',
#  'of',
#  'this',
#  'month',
#  'Netlife',
#  'magazine',
#  '.',
#  'It',
#  'doe',
#  'not',
#  'seem',
#  'to',
#  'be',
#  'online',
#  'yet',
#  'so',
#  'here',
#  'a',
#  'scan',
#  ':',
#  '08',
#  ',',
#  ',2001',
#  'Well',
#  ',',
#  'the',
#  'big',
#  'Yahoo',
#  'news',
#  'yesterday',
#  'wa',
#  'that',
#  'Tim',
#  'Koogle',
#  'is',
#  'stepping',
#  'down',
#  'a',
#  'CEO',
#  'and',
#  'that',
#  'they',
#  'will',
#  'miss',
#  'forecast',
#  'in',
#  'the',
#  'first',
#  'quarter',
#  '.',
#  'Today',
#  'the',
#  'stock',
#  'tumbled',
#  '.',
#  '07',
#  ',',
#  ',2001',
#  'The',
#  'Times',
#  'report',
#  'that',
#  'the',
#  'Trogan',
#  'Room',
#  'Coffee',
#  'Machine',
#  'webcam',
#  'is',
#  'going',
#  'offline',
#  'for',
#  'good',
#  'later',
#  'this',
#  'year',
#  '.',
#  'That',
#  'pot',
#  'should',
#  'go',
#  'in',
#  'a',
#  'museum',
#  '.',
#  '05',
#  ',',
#  ',2001',
#  'It',
#  'look',
#  'like',
#  'there',
#  'is',
#  'some',
#  'big',
#  'news',
#  'due',
#  'from',
#  'Yahoo',
#  'later',
#  'today',
#  '.',
#  '05',
#  ',',
#  ',2001',
#  'The',
#  'new',
#  'issue',
#  'of',
#  'Mindjack',
#  'Magazine',
#  'is',
#  'now',
#  'online',
#  ',',
#  'featuring',
#  'a',
#  'first',
#  'for',
#  'u',
#  '-',
#  'a',
#  'live',
#  'concert',
#  'review',
#  '.',
#  'With',
#  'original',
#  'photo',
#  'even',
#  '.',
#  '29',
#  ',',
#  ',2001',
#  'Its',
#  'not',
#  'good',
#  'when',
#  'a',
#  'box',
#  'of',
#  'Sinutab',
#  'describes',
#  'your',
#  'day',
#  '.',
#  'Sinus',
#  'pain',
#  ',',
#  'headache',
#  ',',
#  'congestion',
#  ',',
#  'itchy',
#  ',',
#  'watery',
#  'eye',
#  '.',
#  'Ugh',
#  '.',
#  '24',
#  ',',
#  ',2001',
#  'The',
#  'End',
#  'of',
#  'Free',
#  ...]

# %% [markdown]
# #### Normalize the tokens

# %%
# remove punctuation
punct_table = str.maketrans('', '', string.punctuation)
tokens = [w.translate(punct_table) for w in lemon_lemmas] 

# filter non-alpha and stop words
tokens = [word for word in tokens if word.isalpha()]
stop_words = set(stopwords.words('english'))
words = [w for w in tokens if not w in stop_words]

words
# Out:
# ['Slashdot',
#  'raise',
#  'lot',
#  'interesting',
#  'thought',
#  'banner',
#  'ad',
#  'The',
#  'idea',
#  'let',
#  'user',
#  'control',
#  'ad',
#  'delivery',
#  'even',
#  'allow',
#  'user',
#  'comment',
#  'ad',
#  'The',
#  'Merchants',
#  'Cool',
#  'Frontline',
#  'documentary',
#  'featuring',
#  'Mindjack',
#  'advisory',
#  'board',
#  'member',
#  'Douglas',
#  'Rushkoff',
#  'PBS',
#  'tonight',
#  'Check',
#  'local',
#  'listing',
#  'time',
#  'ATMs',
#  'dispensing',
#  'music',
#  'I',
#  'quite',
#  'see',
#  'logic',
#  'I',
#  'entirely',
#  'paying',
#  'nominal',
#  'fee',
#  'music',
#  'medium',
#  'I',
#  'pay',
#  'Id',
#  'much',
#  'likely',
#  'buy',
#  'stuff',
#  'PC',
#  'My',
#  'chair',
#  'started',
#  'squeaking',
#  'day',
#  'ago',
#  'driving',
#  'nut',
#  'The',
#  'New',
#  'York',
#  'Press',
#  'ha',
#  'lenghty',
#  'article',
#  'post',
#  'dotcom',
#  'crash',
#  'scene',
#  'worth',
#  'reading',
#  'Francis',
#  'Collins',
#  'Most',
#  'Surprising',
#  'Things',
#  'About',
#  'Human',
#  'Genome',
#  'FILMSPEED',
#  'ha',
#  'great',
#  'movie',
#  'download',
#  'free',
#  'The',
#  'Third',
#  'Man',
#  'particular',
#  'one',
#  'favorite',
#  'film',
#  'time',
#  'For',
#  'sale',
#  'An',
#  'STB',
#  'nVidia',
#  'ZX',
#  'Accelerator',
#  'AGP',
#  'NEC',
#  'CDROM',
#  'drive',
#  'Interesting',
#  'trade',
#  'considered',
#  'I',
#  'started',
#  'uploading',
#  'stuff',
#  'radio',
#  'station',
#  'much',
#  'yet',
#  'welcome',
#  'listen',
#  'cabledsl',
#  'higher',
#  'required',
#  'FEEDs',
#  'latest',
#  'special',
#  'issue',
#  'excellent',
#  'examination',
#  'video',
#  'game',
#  'contribution',
#  'Carl',
#  'Steadman',
#  'Steven',
#  'Johnson',
#  'Justin',
#  'Hall',
#  'others',
#  'miss',
#  'New',
#  'DVD',
#  'The',
#  'Maltese',
#  'Falcon',
#  'I',
#  'personal',
#  'homepage',
#  'long',
#  'weblogs',
#  'came',
#  'fashion',
#  'never',
#  'managed',
#  'update',
#  'couple',
#  'time',
#  'year',
#  'Heres',
#  'hoping',
#  'I',
#  'bit',
#  'successful',
#  'Big',
#  'thanks',
#  'Bopjet',
#  'hosting',
#  'Mindjack',
#  'The',
#  'Register',
#  'report',
#  'war',
#  'driving',
#  'wireless',
#  'equivalent',
#  'war',
#  'dialing',
#  'Instead',
#  'modem',
#  'dial',
#  'thousand',
#  'network',
#  'get',
#  'drive',
#  'within',
#  'range',
#  'wireless',
#  'net',
#  'wirelessequipped',
#  'laptop',
#  'hack',
#  'away',
#  'related',
#  'The',
#  'latest',
#  'issue',
#  'CIO',
#  'ha',
#  'great',
#  'feature',
#  'wireless',
#  'Short',
#  'documentary',
#  'digital',
#  'filmmaking',
#  'Star',
#  'Wars',
#  'Episode',
#  'II',
#  'Rumour',
#  'ha',
#  'parent',
#  'company',
#  'Insidecom',
#  'Brills',
#  'Content',
#  'announcing',
#  'merger',
#  'early',
#  'next',
#  'Monday',
#  'Apparently',
#  'two',
#  'print',
#  'magazine',
#  'would',
#  'fold',
#  'one',
#  'called',
#  'Brills',
#  'Inside',
#  'Content',
#  'two',
#  'website',
#  'would',
#  'form',
#  'Media',
#  'Central',
#  'Insidecom',
#  'Rolls',
#  'right',
#  'tongue',
#  'doe',
#  'Destroy',
#  'All',
#  'Monsters',
#  'Survivor',
#  'Monster',
#  'Island',
#  'My',
#  'money',
#  'Mothra',
#  'I',
#  'spent',
#  'time',
#  'playing',
#  'beta',
#  'version',
#  'Atmosphere',
#  'Adobes',
#  'new',
#  'environment',
#  'software',
#  'thought',
#  'Id',
#  'give',
#  'couple',
#  'quick',
#  'impression',
#  'I',
#  'always',
#  'interested',
#  'VR',
#  'spent',
#  'quite',
#  'bit',
#  'time',
#  'working',
#  'VRML',
#  'I',
#  'think',
#  'inherant',
#  'problem',
#  'VRML',
#  'wa',
#  'enough',
#  'attention',
#  'given',
#  'community',
#  'You',
#  'could',
#  'build',
#  'really',
#  'cool',
#  'place',
#  'people',
#  'could',
#  'interact',
#  'You',
#  'also',
#  'could',
#  'easily',
#  'move',
#  'one',
#  'environment',
#  'another',
#  'without',
#  'going',
#  'back',
#  'forth',
#  'web',
#  'page',
#  'I',
#  'wa',
#  'involved',
#  'project',
#  'tried',
#  'solve',
#  'problem',
#  'VRML',
#  'anybody',
#  'remember',
#  'Terra',
#  'Vista',
#  'far',
#  'would',
#  'liked',
#  'Atmosphere',
#  'appears',
#  'addressed',
#  'problem',
#  'Its',
#  'first',
#  'product',
#  'maybe',
#  'Adobe',
#  'ha',
#  'enough',
#  'muscle',
#  'gain',
#  'wide',
#  'acceptance',
#  'Thanks',
#  'Oneboxcom',
#  'I',
#  'able',
#  'receive',
#  'fax',
#  'Not',
#  'suprisingly',
#  'local',
#  'phone',
#  'number',
#  'Fredericton',
#  'I',
#  'chose',
#  'New',
#  'York',
#  'City',
#  'area',
#  'code',
#  'If',
#  'anyone',
#  'want',
#  'give',
#  'whirl',
#  'number',
#  'Well',
#  'I',
#  'wa',
#  'supposed',
#  'working',
#  'But',
#  'long',
#  'trail',
#  'procrastination',
#  'I',
#  'ended',
#  'redesigning',
#  'site',
#  'Quotable',
#  'Mindjack',
#  'From',
#  'Mike',
#  'Sugarbakers',
#  'review',
#  'Lemon',
#  'If',
#  'patience',
#  'lengthy',
#  'rumination',
#  'brilliant',
#  'madman',
#  'Lemon',
#  'But',
#  'read',
#  'Mindjack',
#  'probably',
#  'sort',
#  'thing',
#  'right',
#  'Mindjack',
#  'featured',
#  'link',
#  'section',
#  'month',
#  'Netlife',
#  'magazine',
#  'It',
#  'doe',
#  'seem',
#  'online',
#  'yet',
#  'scan',
#  'Well',
#  'big',
#  'Yahoo',
#  'news',
#  'yesterday',
#  'wa',
#  'Tim',
#  'Koogle',
#  'stepping',
#  'CEO',
#  'miss',
#  'forecast',
#  'first',
#  'quarter',
#  'Today',
#  'stock',
#  'tumbled',
#  'The',
#  'Times',
#  'report',
#  'Trogan',
#  'Room',
#  'Coffee',
#  'Machine',
#  'webcam',
#  'going',
#  'offline',
#  'good',
#  'later',
#  'year',
#  'That',
#  'pot',
#  'go',
#  'museum',
#  'It',
#  'look',
#  'like',
#  'big',
#  'news',
#  'due',
#  'Yahoo',
#  'later',
#  'today',
#  'The',
#  'new',
#  'issue',
#  'Mindjack',
#  'Magazine',
#  'online',
#  'featuring',
#  'first',
#  'u',
#  'live',
#  'concert',
#  'review',
#  'With',
#  'original',
#  'photo',
#  'even',
#  'Its',
#  'good',
#  'box',
#  'Sinutab',
#  'describes',
#  'day',
#  'Sinus',
#  'pain',
#  'headache',
#  'congestion',
#  'itchy',
#  'watery',
#  'eye',
#  'Ugh',
#  'The',
#  'End',
#  'Free',
#  'chronicling',
#  'demise',
#  'free',
#  'stuff',
#  'net',
#  'I',
#  'sure',
#  'I',
#  'like',
#  'direction',
#  'FEED',
#  'turned',
#  'The',
#  'filter',
#  'new',
#  'weblog',
#  'linking',
#  'outside',
#  'content',
#  'featured',
#  'prominently',
#  'FEEDs',
#  'original',
#  'content',
#  'Its',
#  'also',
#  'clear',
#  'difference',
#  'filter',
#  'Plastic',
#  'Hey',
#  'Jon',
#  'Lebkowsky',
#  'ha',
#  'started',
#  'blog',
#  'Coolness',
#  'wisdom',
#  'found',
#  'within',
#  'What',
#  'look',
#  'like',
#  'new',
#  'PalmOS',
#  'PDA',
#  'TRG',
#  'look',
#  'mighty',
#  'impressive',
#  'The',
#  'official',
#  'launch',
#  'rumored',
#  'Monday',
#  'If',
#  'priced',
#  'reasonably',
#  'enough',
#  'might',
#  'get',
#  'upgrade',
#  'PalmPilot',
#  'Personal',
#  'Stick',
#  'figure',
#  'fighting',
#  'action',
#  'like',
#  'never',
#  'seen',
#  'Evan',
#  'Williams',
#  'Blogger',
#  'ha',
#  'How',
#  'Trellix',
#  'Deal',
#  'Happened',
#  'What',
#  'It',
#  'Means',
#  'Need',
#  'logo',
#  'website',
#  'Email',
#  'I',
#  'work',
#  'toy',
#  'It',
#  'wa',
#  'announced',
#  'Trellix',
#  'licensing',
#  'Pyras',
#  'Blogger',
#  'technology',
#  'giving',
#  'Pyra',
#  'much',
#  'needed',
#  'cash',
#  'infusion',
#  'Dan',
#  'Bricklin',
#  'ha',
#  'fascinating',
#  'account',
#  'deal',
#  'happened',
#  'site',
#  'I',
#  'recently',
#  'got',
#  'Monkeys',
#  'DVD',
#  'excellent',
#  'Its',
#  'worth',
#  'picking',
#  'included',
#  'featurelength',
#  'documentary',
#  'The',
#  'Hamster',
#  'Factor',
#  'Other',
#  'Tales',
#  'Twelve',
#  'Monkeys',
#  'making',
#  'film',
#  'Redesigned',
#  'Insidecom',
#  'report',
#  'Economist',
#  'business',
#  'editor',
#  'Chris',
#  'Anderson',
#  'ha',
#  'named',
#  'editor',
#  'Wired',
#  'replacing',
#  'Katrina',
#  'Heron',
#  'The',
#  'new',
#  'issue',
#  'Digital',
#  'Web',
#  'Magazine',
#  'today',
#  'Lots',
#  'interesting',
#  'stuff',
#  'This',
#  'one',
#  'reason',
#  'I',
#  'vegetarian',
#  'washingtonpostcom',
#  'Justins',
#  'back',
#  'Japan',
#  'story',
#  'picture',
#  'Something',
#  'screwys',
#  'going',
#  'computer',
#  'Things',
#  'crashing',
#  'mouse',
#  'stuttering',
#  'skipping',
#  'sometimes',
#  'slows',
#  'crawl',
#  'I',
#  'got',
#  'nagging',
#  'feeling',
#  'I',
#  'going',
#  'complete',
#  'format',
#  'reinstall',
#  'Windows',
#  'I',
#  'really',
#  'want',
#  'Mikelorg',
#  'pointed',
#  'rumor',
#  'Automatic',
#  'Media',
#  'trouble',
#  'Automatic',
#  'company',
#  'consists',
#  'Feed',
#  'Suck',
#  'Plastic',
#  'Hopefully',
#  'rumour',
#  'Home',
#  'Underdogs',
#  'amazing',
#  'resource',
#  'anyone',
#  'love',
#  'computer',
#  'game',
#  'Not',
#  'hundred',
#  'game',
#  'download',
#  'longer',
#  'available',
#  'company',
#  'also',
#  'wealth',
#  'information',
#  'many',
#  'game',
#  'Its',
#  'entirely',
#  'legal',
#  'I',
#  'think',
#  'great',
#  'public',
#  'service',
#  'Its',
#  'even',
#  'better',
#  'one',
#  'favorite',
#  'game',
#  'Gabriel',
#  'Knight',
#  'great',
#  'article',
#  'William',
#  'Gibson',
#  'The',
#  'Observers',
#  'Special',
#  'Japan',
#  'Issue',
#  'We',
#  'reinvented',
#  'culture',
#  'way',
#  'wanted',
#  'great',
#  'big',
#  'shoe',
#  'David',
#  'Bowie',
#  'writes',
#  'glam',
#  'today',
#  'Guardian',
#  'Its',
#  'since',
#  'I',
#  'played',
#  'around',
#  'customizing',
#  'My',
#  'Yahoo',
#  'I',
#  'know',
#  'new',
#  'use',
#  'theme',
#  'additoin',
#  'plain',
#  'color',
#  'Streaming',
#  'video',
#  'Reboot',
#  'conference',
#  'featuring',
#  'Justin',
#  'Hall',
#  'Dave',
#  'Winer',
#  'Evan',
#  'Williams',
#  'Douglas',
#  'Rushkoff',
#  'others',
#  'make',
#  'ya',
#  'think',
#  'Mindjack',
#  'deep',
#  'development',
#  'mode',
#  'magic',
#  'blog',
#  'follow',
#  'action',
#  'happens',
#  'Shift',
#  'back',
#  'design',
#  'look',
#  'vaguely',
#  'familar',
#  'It',
#  'look',
#  'good',
#  'javascript',
#  'scroll',
#  'box',
#  'slooooow',
#  'If',
#  'I',
#  'heard',
#  'Doves',
#  'Lost',
#  'Souls',
#  'album',
#  'last',
#  'year',
#  'I',
#  'would',
#  'included',
#  'best',
#  'list',
#  'Hawksley',
#  'Workmans',
#  'Last',
#  'Night',
#  'We',
#  'Were',
#  'The',
#  'Delicious',
#  'Wolves',
#  'probably',
#  'year',
#  'list',
#  'CNET',
#  'ha',
#  'video',
#  'Steve',
#  'Jobs',
#  'tour',
#  'Apples',
#  'new',
#  'retail',
#  'store',
#  'It',
#  'Cool',
#  'News',
#  'ha',
#  'great',
#  'clip',
#  'picture',
#  'new',
#  'Coen',
#  'Brothers',
#  'film',
#  'The',
#  'Man',
#  'Who',
#  'Was',
#  'Not',
#  'There',
#  'I',
#  'excited',
#  'Yet',
#  'another',
#  'redesign',
#  'I',
#  'think',
#  'I',
#  'stick',
#  'one',
#  'Sure',
#  'advertising',
#  'But',
#  'damn',
#  'good',
#  'advertising',
#  'DSL',
#  'Feed',
#  'ha',
#  'great',
#  'interview',
#  'Cory',
#  'Doctorow',
#  'today',
#  'The',
#  'overlap',
#  'Doctorows',
#  'day',
#  'job',
#  'OpenCola',
#  'night',
#  'job',
#  'writing',
#  'fiction',
#  'make',
#  'unique',
#  'combination',
#  'Its',
#  'almost',
#  'like',
#  'William',
#  'Gibson',
#  'launching',
#  'company',
#  'sell',
#  'neural',
#  'plug',
#  'stimsims',
#  'Douglas',
#  'Rushkoffs',
#  'Frontline',
#  'documentary',
#  'The',
#  'Merchants',
#  'Cool',
#  'rebroadcast',
#  'tonight',
#  'PBS',
#  'check',
#  'local',
#  'listing',
#  'Set',
#  'Tivo',
#  'VCR',
#  'watch',
#  'even',
#  'I',
#  'DSLless',
#  'day',
#  'I',
#  'suppose',
#  'compared',
#  'company',
#  'pretty',
#  'snappy',
#  'service',
#  'still',
#  'day',
#  'without',
#  'DSL',
#  'FEED',
#  'gave',
#  'official',
#  'word',
#  'today',
#  'sutting',
#  'least',
#  'foreseeable',
#  'future',
#  'The',
#  'go',
#  'Suck',
#  'although',
#  'look',
#  'like',
#  'Plastic',
#  'continuing',
#  'Both',
#  'FEED',
#  'Suck',
#  'online',
#  'six',
#  'year',
#  'excellent',
#  'throughout',
#  'Hopefully',
#  'pull',
#  'funk',
#  'come',
#  'back',
#  'one',
#  'form',
#  'another',
#  'month',
#  'Jason',
#  'Kottke',
#  'ha',
#  'great',
#  'picture',
#  'Louvre',
#  'today',
#  'Great',
#  'roadtrip',
#  'article',
#  'Mark',
#  'Frauenfelder',
#  'One',
#  'magazine',
#  'A',
#  'halfcentury',
#  ...]

# %%
bigram = list(bigrams(words))

# %%
bigram
# Out:
# [('Slashdot', 'raise'),
#  ('raise', 'lot'),
#  ('lot', 'interesting'),
#  ('interesting', 'thought'),
#  ('thought', 'banner'),
#  ('banner', 'ad'),
#  ('ad', 'The'),
#  ('The', 'idea'),
#  ('idea', 'let'),
#  ('let', 'user'),
#  ('user', 'control'),
#  ('control', 'ad'),
#  ('ad', 'delivery'),
#  ('delivery', 'even'),
#  ('even', 'allow'),
#  ('allow', 'user'),
#  ('user', 'comment'),
#  ('comment', 'ad'),
#  ('ad', 'The'),
#  ('The', 'Merchants'),
#  ('Merchants', 'Cool'),
#  ('Cool', 'Frontline'),
#  ('Frontline', 'documentary'),
#  ('documentary', 'featuring'),
#  ('featuring', 'Mindjack'),
#  ('Mindjack', 'advisory'),
#  ('advisory', 'board'),
#  ('board', 'member'),
#  ('member', 'Douglas'),
#  ('Douglas', 'Rushkoff'),
#  ('Rushkoff', 'PBS'),
#  ('PBS', 'tonight'),
#  ('tonight', 'Check'),
#  ('Check', 'local'),
#  ('local', 'listing'),
#  ('listing', 'time'),
#  ('time', 'ATMs'),
#  ('ATMs', 'dispensing'),
#  ('dispensing', 'music'),
#  ('music', 'I'),
#  ('I', 'quite'),
#  ('quite', 'see'),
#  ('see', 'logic'),
#  ('logic', 'I'),
#  ('I', 'entirely'),
#  ('entirely', 'paying'),
#  ('paying', 'nominal'),
#  ('nominal', 'fee'),
#  ('fee', 'music'),
#  ('music', 'medium'),
#  ('medium', 'I'),
#  ('I', 'pay'),
#  ('pay', 'Id'),
#  ('Id', 'much'),
#  ('much', 'likely'),
#  ('likely', 'buy'),
#  ('buy', 'stuff'),
#  ('stuff', 'PC'),
#  ('PC', 'My'),
#  ('My', 'chair'),
#  ('chair', 'started'),
#  ('started', 'squeaking'),
#  ('squeaking', 'day'),
#  ('day', 'ago'),
#  ('ago', 'driving'),
#  ('driving', 'nut'),
#  ('nut', 'The'),
#  ('The', 'New'),
#  ('New', 'York'),
#  ('York', 'Press'),
#  ('Press', 'ha'),
#  ('ha', 'lenghty'),
#  ('lenghty', 'article'),
#  ('article', 'post'),
#  ('post', 'dotcom'),
#  ('dotcom', 'crash'),
#  ('crash', 'scene'),
#  ('scene', 'worth'),
#  ('worth', 'reading'),
#  ('reading', 'Francis'),
#  ('Francis', 'Collins'),
#  ('Collins', 'Most'),
#  ('Most', 'Surprising'),
#  ('Surprising', 'Things'),
#  ('Things', 'About'),
#  ('About', 'Human'),
#  ('Human', 'Genome'),
#  ('Genome', 'FILMSPEED'),
#  ('FILMSPEED', 'ha'),
#  ('ha', 'great'),
#  ('great', 'movie'),
#  ('movie', 'download'),
#  ('download', 'free'),
#  ('free', 'The'),
#  ('The', 'Third'),
#  ('Third', 'Man'),
#  ('Man', 'particular'),
#  ('particular', 'one'),
#  ('one', 'favorite'),
#  ('favorite', 'film'),
#  ('film', 'time'),
#  ('time', 'For'),
#  ('For', 'sale'),
#  ('sale', 'An'),
#  ('An', 'STB'),
#  ('STB', 'nVidia'),
#  ('nVidia', 'ZX'),
#  ('ZX', 'Accelerator'),
#  ('Accelerator', 'AGP'),
#  ('AGP', 'NEC'),
#  ('NEC', 'CDROM'),
#  ('CDROM', 'drive'),
#  ('drive', 'Interesting'),
#  ('Interesting', 'trade'),
#  ('trade', 'considered'),
#  ('considered', 'I'),
#  ('I', 'started'),
#  ('started', 'uploading'),
#  ('uploading', 'stuff'),
#  ('stuff', 'radio'),
#  ('radio', 'station'),
#  ('station', 'much'),
#  ('much', 'yet'),
#  ('yet', 'welcome'),
#  ('welcome', 'listen'),
#  ('listen', 'cabledsl'),
#  ('cabledsl', 'higher'),
#  ('higher', 'required'),
#  ('required', 'FEEDs'),
#  ('FEEDs', 'latest'),
#  ('latest', 'special'),
#  ('special', 'issue'),
#  ('issue', 'excellent'),
#  ('excellent', 'examination'),
#  ('examination', 'video'),
#  ('video', 'game'),
#  ('game', 'contribution'),
#  ('contribution', 'Carl'),
#  ('Carl', 'Steadman'),
#  ('Steadman', 'Steven'),
#  ('Steven', 'Johnson'),
#  ('Johnson', 'Justin'),
#  ('Justin', 'Hall'),
#  ('Hall', 'others'),
#  ('others', 'miss'),
#  ('miss', 'New'),
#  ('New', 'DVD'),
#  ('DVD', 'The'),
#  ('The', 'Maltese'),
#  ('Maltese', 'Falcon'),
#  ('Falcon', 'I'),
#  ('I', 'personal'),
#  ('personal', 'homepage'),
#  ('homepage', 'long'),
#  ('long', 'weblogs'),
#  ('weblogs', 'came'),
#  ('came', 'fashion'),
#  ('fashion', 'never'),
#  ('never', 'managed'),
#  ('managed', 'update'),
#  ('update', 'couple'),
#  ('couple', 'time'),
#  ('time', 'year'),
#  ('year', 'Heres'),
#  ('Heres', 'hoping'),
#  ('hoping', 'I'),
#  ('I', 'bit'),
#  ('bit', 'successful'),
#  ('successful', 'Big'),
#  ('Big', 'thanks'),
#  ('thanks', 'Bopjet'),
#  ('Bopjet', 'hosting'),
#  ('hosting', 'Mindjack'),
#  ('Mindjack', 'The'),
#  ('The', 'Register'),
#  ('Register', 'report'),
#  ('report', 'war'),
#  ('war', 'driving'),
#  ('driving', 'wireless'),
#  ('wireless', 'equivalent'),
#  ('equivalent', 'war'),
#  ('war', 'dialing'),
#  ('dialing', 'Instead'),
#  ('Instead', 'modem'),
#  ('modem', 'dial'),
#  ('dial', 'thousand'),
#  ('thousand', 'network'),
#  ('network', 'get'),
#  ('get', 'drive'),
#  ('drive', 'within'),
#  ('within', 'range'),
#  ('range', 'wireless'),
#  ('wireless', 'net'),
#  ('net', 'wirelessequipped'),
#  ('wirelessequipped', 'laptop'),
#  ('laptop', 'hack'),
#  ('hack', 'away'),
#  ('away', 'related'),
#  ('related', 'The'),
#  ('The', 'latest'),
#  ('latest', 'issue'),
#  ('issue', 'CIO'),
#  ('CIO', 'ha'),
#  ('ha', 'great'),
#  ('great', 'feature'),
#  ('feature', 'wireless'),
#  ('wireless', 'Short'),
#  ('Short', 'documentary'),
#  ('documentary', 'digital'),
#  ('digital', 'filmmaking'),
#  ('filmmaking', 'Star'),
#  ('Star', 'Wars'),
#  ('Wars', 'Episode'),
#  ('Episode', 'II'),
#  ('II', 'Rumour'),
#  ('Rumour', 'ha'),
#  ('ha', 'parent'),
#  ('parent', 'company'),
#  ('company', 'Insidecom'),
#  ('Insidecom', 'Brills'),
#  ('Brills', 'Content'),
#  ('Content', 'announcing'),
#  ('announcing', 'merger'),
#  ('merger', 'early'),
#  ('early', 'next'),
#  ('next', 'Monday'),
#  ('Monday', 'Apparently'),
#  ('Apparently', 'two'),
#  ('two', 'print'),
#  ('print', 'magazine'),
#  ('magazine', 'would'),
#  ('would', 'fold'),
#  ('fold', 'one'),
#  ('one', 'called'),
#  ('called', 'Brills'),
#  ('Brills', 'Inside'),
#  ('Inside', 'Content'),
#  ('Content', 'two'),
#  ('two', 'website'),
#  ('website', 'would'),
#  ('would', 'form'),
#  ('form', 'Media'),
#  ('Media', 'Central'),
#  ('Central', 'Insidecom'),
#  ('Insidecom', 'Rolls'),
#  ('Rolls', 'right'),
#  ('right', 'tongue'),
#  ('tongue', 'doe'),
#  ('doe', 'Destroy'),
#  ('Destroy', 'All'),
#  ('All', 'Monsters'),
#  ('Monsters', 'Survivor'),
#  ('Survivor', 'Monster'),
#  ('Monster', 'Island'),
#  ('Island', 'My'),
#  ('My', 'money'),
#  ('money', 'Mothra'),
#  ('Mothra', 'I'),
#  ('I', 'spent'),
#  ('spent', 'time'),
#  ('time', 'playing'),
#  ('playing', 'beta'),
#  ('beta', 'version'),
#  ('version', 'Atmosphere'),
#  ('Atmosphere', 'Adobes'),
#  ('Adobes', 'new'),
#  ('new', 'environment'),
#  ('environment', 'software'),
#  ('software', 'thought'),
#  ('thought', 'Id'),
#  ('Id', 'give'),
#  ('give', 'couple'),
#  ('couple', 'quick'),
#  ('quick', 'impression'),
#  ('impression', 'I'),
#  ('I', 'always'),
#  ('always', 'interested'),
#  ('interested', 'VR'),
#  ('VR', 'spent'),
#  ('spent', 'quite'),
#  ('quite', 'bit'),
#  ('bit', 'time'),
#  ('time', 'working'),
#  ('working', 'VRML'),
#  ('VRML', 'I'),
#  ('I', 'think'),
#  ('think', 'inherant'),
#  ('inherant', 'problem'),
#  ('problem', 'VRML'),
#  ('VRML', 'wa'),
#  ('wa', 'enough'),
#  ('enough', 'attention'),
#  ('attention', 'given'),
#  ('given', 'community'),
#  ('community', 'You'),
#  ('You', 'could'),
#  ('could', 'build'),
#  ('build', 'really'),
#  ('really', 'cool'),
#  ('cool', 'place'),
#  ('place', 'people'),
#  ('people', 'could'),
#  ('could', 'interact'),
#  ('interact', 'You'),
#  ('You', 'also'),
#  ('also', 'could'),
#  ('could', 'easily'),
#  ('easily', 'move'),
#  ('move', 'one'),
#  ('one', 'environment'),
#  ('environment', 'another'),
#  ('another', 'without'),
#  ('without', 'going'),
#  ('going', 'back'),
#  ('back', 'forth'),
#  ('forth', 'web'),
#  ('web', 'page'),
#  ('page', 'I'),
#  ('I', 'wa'),
#  ('wa', 'involved'),
#  ('involved', 'project'),
#  ('project', 'tried'),
#  ('tried', 'solve'),
#  ('solve', 'problem'),
#  ('problem', 'VRML'),
#  ('VRML', 'anybody'),
#  ('anybody', 'remember'),
#  ('remember', 'Terra'),
#  ('Terra', 'Vista'),
#  ('Vista', 'far'),
#  ('far', 'would'),
#  ('would', 'liked'),
#  ('liked', 'Atmosphere'),
#  ('Atmosphere', 'appears'),
#  ('appears', 'addressed'),
#  ('addressed', 'problem'),
#  ('problem', 'Its'),
#  ('Its', 'first'),
#  ('first', 'product'),
#  ('product', 'maybe'),
#  ('maybe', 'Adobe'),
#  ('Adobe', 'ha'),
#  ('ha', 'enough'),
#  ('enough', 'muscle'),
#  ('muscle', 'gain'),
#  ('gain', 'wide'),
#  ('wide', 'acceptance'),
#  ('acceptance', 'Thanks'),
#  ('Thanks', 'Oneboxcom'),
#  ('Oneboxcom', 'I'),
#  ('I', 'able'),
#  ('able', 'receive'),
#  ('receive', 'fax'),
#  ('fax', 'Not'),
#  ('Not', 'suprisingly'),
#  ('suprisingly', 'local'),
#  ('local', 'phone'),
#  ('phone', 'number'),
#  ('number', 'Fredericton'),
#  ('Fredericton', 'I'),
#  ('I', 'chose'),
#  ('chose', 'New'),
#  ('New', 'York'),
#  ('York', 'City'),
#  ('City', 'area'),
#  ('area', 'code'),
#  ('code', 'If'),
#  ('If', 'anyone'),
#  ('anyone', 'want'),
#  ('want', 'give'),
#  ('give', 'whirl'),
#  ('whirl', 'number'),
#  ('number', 'Well'),
#  ('Well', 'I'),
#  ('I', 'wa'),
#  ('wa', 'supposed'),
#  ('supposed', 'working'),
#  ('working', 'But'),
#  ('But', 'long'),
#  ('long', 'trail'),
#  ('trail', 'procrastination'),
#  ('procrastination', 'I'),
#  ('I', 'ended'),
#  ('ended', 'redesigning'),
#  ('redesigning', 'site'),
#  ('site', 'Quotable'),
#  ('Quotable', 'Mindjack'),
#  ('Mindjack', 'From'),
#  ('From', 'Mike'),
#  ('Mike', 'Sugarbakers'),
#  ('Sugarbakers', 'review'),
#  ('review', 'Lemon'),
#  ('Lemon', 'If'),
#  ('If', 'patience'),
#  ('patience', 'lengthy'),
#  ('lengthy', 'rumination'),
#  ('rumination', 'brilliant'),
#  ('brilliant', 'madman'),
#  ('madman', 'Lemon'),
#  ('Lemon', 'But'),
#  ('But', 'read'),
#  ('read', 'Mindjack'),
#  ('Mindjack', 'probably'),
#  ('probably', 'sort'),
#  ('sort', 'thing'),
#  ('thing', 'right'),
#  ('right', 'Mindjack'),
#  ('Mindjack', 'featured'),
#  ('featured', 'link'),
#  ('link', 'section'),
#  ('section', 'month'),
#  ('month', 'Netlife'),
#  ('Netlife', 'magazine'),
#  ('magazine', 'It'),
#  ('It', 'doe'),
#  ('doe', 'seem'),
#  ('seem', 'online'),
#  ('online', 'yet'),
#  ('yet', 'scan'),
#  ('scan', 'Well'),
#  ('Well', 'big'),
#  ('big', 'Yahoo'),
#  ('Yahoo', 'news'),
#  ('news', 'yesterday'),
#  ('yesterday', 'wa'),
#  ('wa', 'Tim'),
#  ('Tim', 'Koogle'),
#  ('Koogle', 'stepping'),
#  ('stepping', 'CEO'),
#  ('CEO', 'miss'),
#  ('miss', 'forecast'),
#  ('forecast', 'first'),
#  ('first', 'quarter'),
#  ('quarter', 'Today'),
#  ('Today', 'stock'),
#  ('stock', 'tumbled'),
#  ('tumbled', 'The'),
#  ('The', 'Times'),
#  ('Times', 'report'),
#  ('report', 'Trogan'),
#  ('Trogan', 'Room'),
#  ('Room', 'Coffee'),
#  ('Coffee', 'Machine'),
#  ('Machine', 'webcam'),
#  ('webcam', 'going'),
#  ('going', 'offline'),
#  ('offline', 'good'),
#  ('good', 'later'),
#  ('later', 'year'),
#  ('year', 'That'),
#  ('That', 'pot'),
#  ('pot', 'go'),
#  ('go', 'museum'),
#  ('museum', 'It'),
#  ('It', 'look'),
#  ('look', 'like'),
#  ('like', 'big'),
#  ('big', 'news'),
#  ('news', 'due'),
#  ('due', 'Yahoo'),
#  ('Yahoo', 'later'),
#  ('later', 'today'),
#  ('today', 'The'),
#  ('The', 'new'),
#  ('new', 'issue'),
#  ('issue', 'Mindjack'),
#  ('Mindjack', 'Magazine'),
#  ('Magazine', 'online'),
#  ('online', 'featuring'),
#  ('featuring', 'first'),
#  ('first', 'u'),
#  ('u', 'live'),
#  ('live', 'concert'),
#  ('concert', 'review'),
#  ('review', 'With'),
#  ('With', 'original'),
#  ('original', 'photo'),
#  ('photo', 'even'),
#  ('even', 'Its'),
#  ('Its', 'good'),
#  ('good', 'box'),
#  ('box', 'Sinutab'),
#  ('Sinutab', 'describes'),
#  ('describes', 'day'),
#  ('day', 'Sinus'),
#  ('Sinus', 'pain'),
#  ('pain', 'headache'),
#  ('headache', 'congestion'),
#  ('congestion', 'itchy'),
#  ('itchy', 'watery'),
#  ('watery', 'eye'),
#  ('eye', 'Ugh'),
#  ('Ugh', 'The'),
#  ('The', 'End'),
#  ('End', 'Free'),
#  ('Free', 'chronicling'),
#  ('chronicling', 'demise'),
#  ('demise', 'free'),
#  ('free', 'stuff'),
#  ('stuff', 'net'),
#  ('net', 'I'),
#  ('I', 'sure'),
#  ('sure', 'I'),
#  ('I', 'like'),
#  ('like', 'direction'),
#  ('direction', 'FEED'),
#  ('FEED', 'turned'),
#  ('turned', 'The'),
#  ('The', 'filter'),
#  ('filter', 'new'),
#  ('new', 'weblog'),
#  ('weblog', 'linking'),
#  ('linking', 'outside'),
#  ('outside', 'content'),
#  ('content', 'featured'),
#  ('featured', 'prominently'),
#  ('prominently', 'FEEDs'),
#  ('FEEDs', 'original'),
#  ('original', 'content'),
#  ('content', 'Its'),
#  ('Its', 'also'),
#  ('also', 'clear'),
#  ('clear', 'difference'),
#  ('difference', 'filter'),
#  ('filter', 'Plastic'),
#  ('Plastic', 'Hey'),
#  ('Hey', 'Jon'),
#  ('Jon', 'Lebkowsky'),
#  ('Lebkowsky', 'ha'),
#  ('ha', 'started'),
#  ('started', 'blog'),
#  ('blog', 'Coolness'),
#  ('Coolness', 'wisdom'),
#  ('wisdom', 'found'),
#  ('found', 'within'),
#  ('within', 'What'),
#  ('What', 'look'),
#  ('look', 'like'),
#  ('like', 'new'),
#  ('new', 'PalmOS'),
#  ('PalmOS', 'PDA'),
#  ('PDA', 'TRG'),
#  ('TRG', 'look'),
#  ('look', 'mighty'),
#  ('mighty', 'impressive'),
#  ('impressive', 'The'),
#  ('The', 'official'),
#  ('official', 'launch'),
#  ('launch', 'rumored'),
#  ('rumored', 'Monday'),
#  ('Monday', 'If'),
#  ('If', 'priced'),
#  ('priced', 'reasonably'),
#  ('reasonably', 'enough'),
#  ('enough', 'might'),
#  ('might', 'get'),
#  ('get', 'upgrade'),
#  ('upgrade', 'PalmPilot'),
#  ('PalmPilot', 'Personal'),
#  ('Personal', 'Stick'),
#  ('Stick', 'figure'),
#  ('figure', 'fighting'),
#  ('fighting', 'action'),
#  ('action', 'like'),
#  ('like', 'never'),
#  ('never', 'seen'),
#  ('seen', 'Evan'),
#  ('Evan', 'Williams'),
#  ('Williams', 'Blogger'),
#  ('Blogger', 'ha'),
#  ('ha', 'How'),
#  ('How', 'Trellix'),
#  ('Trellix', 'Deal'),
#  ('Deal', 'Happened'),
#  ('Happened', 'What'),
#  ('What', 'It'),
#  ('It', 'Means'),
#  ('Means', 'Need'),
#  ('Need', 'logo'),
#  ('logo', 'website'),
#  ('website', 'Email'),
#  ('Email', 'I'),
#  ('I', 'work'),
#  ('work', 'toy'),
#  ('toy', 'It'),
#  ('It', 'wa'),
#  ('wa', 'announced'),
#  ('announced', 'Trellix'),
#  ('Trellix', 'licensing'),
#  ('licensing', 'Pyras'),
#  ('Pyras', 'Blogger'),
#  ('Blogger', 'technology'),
#  ('technology', 'giving'),
#  ('giving', 'Pyra'),
#  ('Pyra', 'much'),
#  ('much', 'needed'),
#  ('needed', 'cash'),
#  ('cash', 'infusion'),
#  ('infusion', 'Dan'),
#  ('Dan', 'Bricklin'),
#  ('Bricklin', 'ha'),
#  ('ha', 'fascinating'),
#  ('fascinating', 'account'),
#  ('account', 'deal'),
#  ('deal', 'happened'),
#  ('happened', 'site'),
#  ('site', 'I'),
#  ('I', 'recently'),
#  ('recently', 'got'),
#  ('got', 'Monkeys'),
#  ('Monkeys', 'DVD'),
#  ('DVD', 'excellent'),
#  ('excellent', 'Its'),
#  ('Its', 'worth'),
#  ('worth', 'picking'),
#  ('picking', 'included'),
#  ('included', 'featurelength'),
#  ('featurelength', 'documentary'),
#  ('documentary', 'The'),
#  ('The', 'Hamster'),
#  ('Hamster', 'Factor'),
#  ('Factor', 'Other'),
#  ('Other', 'Tales'),
#  ('Tales', 'Twelve'),
#  ('Twelve', 'Monkeys'),
#  ('Monkeys', 'making'),
#  ('making', 'film'),
#  ('film', 'Redesigned'),
#  ('Redesigned', 'Insidecom'),
#  ('Insidecom', 'report'),
#  ('report', 'Economist'),
#  ('Economist', 'business'),
#  ('business', 'editor'),
#  ('editor', 'Chris'),
#  ('Chris', 'Anderson'),
#  ('Anderson', 'ha'),
#  ('ha', 'named'),
#  ('named', 'editor'),
#  ('editor', 'Wired'),
#  ('Wired', 'replacing'),
#  ('replacing', 'Katrina'),
#  ('Katrina', 'Heron'),
#  ('Heron', 'The'),
#  ('The', 'new'),
#  ('new', 'issue'),
#  ('issue', 'Digital'),
#  ('Digital', 'Web'),
#  ('Web', 'Magazine'),
#  ('Magazine', 'today'),
#  ('today', 'Lots'),
#  ('Lots', 'interesting'),
#  ('interesting', 'stuff'),
#  ('stuff', 'This'),
#  ('This', 'one'),
#  ('one', 'reason'),
#  ('reason', 'I'),
#  ('I', 'vegetarian'),
#  ('vegetarian', 'washingtonpostcom'),
#  ('washingtonpostcom', 'Justins'),
#  ('Justins', 'back'),
#  ('back', 'Japan'),
#  ('Japan', 'story'),
#  ('story', 'picture'),
#  ('picture', 'Something'),
#  ('Something', 'screwys'),
#  ('screwys', 'going'),
#  ('going', 'computer'),
#  ('computer', 'Things'),
#  ('Things', 'crashing'),
#  ('crashing', 'mouse'),
#  ('mouse', 'stuttering'),
#  ('stuttering', 'skipping'),
#  ('skipping', 'sometimes'),
#  ('sometimes', 'slows'),
#  ('slows', 'crawl'),
#  ('crawl', 'I'),
#  ('I', 'got'),
#  ('got', 'nagging'),
#  ('nagging', 'feeling'),
#  ('feeling', 'I'),
#  ('I', 'going'),
#  ('going', 'complete'),
#  ('complete', 'format'),
#  ('format', 'reinstall'),
#  ('reinstall', 'Windows'),
#  ('Windows', 'I'),
#  ('I', 'really'),
#  ('really', 'want'),
#  ('want', 'Mikelorg'),
#  ('Mikelorg', 'pointed'),
#  ('pointed', 'rumor'),
#  ('rumor', 'Automatic'),
#  ('Automatic', 'Media'),
#  ('Media', 'trouble'),
#  ('trouble', 'Automatic'),
#  ('Automatic', 'company'),
#  ('company', 'consists'),
#  ('consists', 'Feed'),
#  ('Feed', 'Suck'),
#  ('Suck', 'Plastic'),
#  ('Plastic', 'Hopefully'),
#  ('Hopefully', 'rumour'),
#  ('rumour', 'Home'),
#  ('Home', 'Underdogs'),
#  ('Underdogs', 'amazing'),
#  ('amazing', 'resource'),
#  ('resource', 'anyone'),
#  ('anyone', 'love'),
#  ('love', 'computer'),
#  ('computer', 'game'),
#  ('game', 'Not'),
#  ('Not', 'hundred'),
#  ('hundred', 'game'),
#  ('game', 'download'),
#  ('download', 'longer'),
#  ('longer', 'available'),
#  ('available', 'company'),
#  ('company', 'also'),
#  ('also', 'wealth'),
#  ('wealth', 'information'),
#  ('information', 'many'),
#  ('many', 'game'),
#  ('game', 'Its'),
#  ('Its', 'entirely'),
#  ('entirely', 'legal'),
#  ('legal', 'I'),
#  ('I', 'think'),
#  ('think', 'great'),
#  ('great', 'public'),
#  ('public', 'service'),
#  ('service', 'Its'),
#  ('Its', 'even'),
#  ('even', 'better'),
#  ('better', 'one'),
#  ('one', 'favorite'),
#  ('favorite', 'game'),
#  ('game', 'Gabriel'),
#  ('Gabriel', 'Knight'),
#  ('Knight', 'great'),
#  ('great', 'article'),
#  ('article', 'William'),
#  ('William', 'Gibson'),
#  ('Gibson', 'The'),
#  ('The', 'Observers'),
#  ('Observers', 'Special'),
#  ('Special', 'Japan'),
#  ('Japan', 'Issue'),
#  ('Issue', 'We'),
#  ('We', 'reinvented'),
#  ('reinvented', 'culture'),
#  ('culture', 'way'),
#  ('way', 'wanted'),
#  ('wanted', 'great'),
#  ('great', 'big'),
#  ('big', 'shoe'),
#  ('shoe', 'David'),
#  ('David', 'Bowie'),
#  ('Bowie', 'writes'),
#  ('writes', 'glam'),
#  ('glam', 'today'),
#  ('today', 'Guardian'),
#  ('Guardian', 'Its'),
#  ('Its', 'since'),
#  ('since', 'I'),
#  ('I', 'played'),
#  ('played', 'around'),
#  ('around', 'customizing'),
#  ('customizing', 'My'),
#  ('My', 'Yahoo'),
#  ('Yahoo', 'I'),
#  ('I', 'know'),
#  ('know', 'new'),
#  ('new', 'use'),
#  ('use', 'theme'),
#  ('theme', 'additoin'),
#  ('additoin', 'plain'),
#  ('plain', 'color'),
#  ('color', 'Streaming'),
#  ('Streaming', 'video'),
#  ('video', 'Reboot'),
#  ('Reboot', 'conference'),
#  ('conference', 'featuring'),
#  ('featuring', 'Justin'),
#  ('Justin', 'Hall'),
#  ('Hall', 'Dave'),
#  ('Dave', 'Winer'),
#  ('Winer', 'Evan'),
#  ('Evan', 'Williams'),
#  ('Williams', 'Douglas'),
#  ('Douglas', 'Rushkoff'),
#  ('Rushkoff', 'others'),
#  ('others', 'make'),
#  ('make', 'ya'),
#  ('ya', 'think'),
#  ('think', 'Mindjack'),
#  ('Mindjack', 'deep'),
#  ('deep', 'development'),
#  ('development', 'mode'),
#  ('mode', 'magic'),
#  ('magic', 'blog'),
#  ('blog', 'follow'),
#  ('follow', 'action'),
#  ('action', 'happens'),
#  ('happens', 'Shift'),
#  ('Shift', 'back'),
#  ('back', 'design'),
#  ('design', 'look'),
#  ('look', 'vaguely'),
#  ('vaguely', 'familar'),
#  ('familar', 'It'),
#  ('It', 'look'),
#  ('look', 'good'),
#  ('good', 'javascript'),
#  ('javascript', 'scroll'),
#  ('scroll', 'box'),
#  ('box', 'slooooow'),
#  ('slooooow', 'If'),
#  ('If', 'I'),
#  ('I', 'heard'),
#  ('heard', 'Doves'),
#  ('Doves', 'Lost'),
#  ('Lost', 'Souls'),
#  ('Souls', 'album'),
#  ('album', 'last'),
#  ('last', 'year'),
#  ('year', 'I'),
#  ('I', 'would'),
#  ('would', 'included'),
#  ('included', 'best'),
#  ('best', 'list'),
#  ('list', 'Hawksley'),
#  ('Hawksley', 'Workmans'),
#  ('Workmans', 'Last'),
#  ('Last', 'Night'),
#  ('Night', 'We'),
#  ('We', 'Were'),
#  ('Were', 'The'),
#  ('The', 'Delicious'),
#  ('Delicious', 'Wolves'),
#  ('Wolves', 'probably'),
#  ('probably', 'year'),
#  ('year', 'list'),
#  ('list', 'CNET'),
#  ('CNET', 'ha'),
#  ('ha', 'video'),
#  ('video', 'Steve'),
#  ('Steve', 'Jobs'),
#  ('Jobs', 'tour'),
#  ('tour', 'Apples'),
#  ('Apples', 'new'),
#  ('new', 'retail'),
#  ('retail', 'store'),
#  ('store', 'It'),
#  ('It', 'Cool'),
#  ('Cool', 'News'),
#  ('News', 'ha'),
#  ('ha', 'great'),
#  ('great', 'clip'),
#  ('clip', 'picture'),
#  ('picture', 'new'),
#  ('new', 'Coen'),
#  ('Coen', 'Brothers'),
#  ('Brothers', 'film'),
#  ('film', 'The'),
#  ('The', 'Man'),
#  ('Man', 'Who'),
#  ('Who', 'Was'),
#  ('Was', 'Not'),
#  ('Not', 'There'),
#  ('There', 'I'),
#  ('I', 'excited'),
#  ('excited', 'Yet'),
#  ('Yet', 'another'),
#  ('another', 'redesign'),
#  ('redesign', 'I'),
#  ('I', 'think'),
#  ('think', 'I'),
#  ('I', 'stick'),
#  ('stick', 'one'),
#  ('one', 'Sure'),
#  ('Sure', 'advertising'),
#  ('advertising', 'But'),
#  ('But', 'damn'),
#  ('damn', 'good'),
#  ('good', 'advertising'),
#  ('advertising', 'DSL'),
#  ('DSL', 'Feed'),
#  ('Feed', 'ha'),
#  ('ha', 'great'),
#  ('great', 'interview'),
#  ('interview', 'Cory'),
#  ('Cory', 'Doctorow'),
#  ('Doctorow', 'today'),
#  ('today', 'The'),
#  ('The', 'overlap'),
#  ('overlap', 'Doctorows'),
#  ('Doctorows', 'day'),
#  ('day', 'job'),
#  ('job', 'OpenCola'),
#  ('OpenCola', 'night'),
#  ('night', 'job'),
#  ('job', 'writing'),
#  ('writing', 'fiction'),
#  ('fiction', 'make'),
#  ('make', 'unique'),
#  ('unique', 'combination'),
#  ('combination', 'Its'),
#  ('Its', 'almost'),
#  ('almost', 'like'),
#  ('like', 'William'),
#  ('William', 'Gibson'),
#  ('Gibson', 'launching'),
#  ('launching', 'company'),
#  ('company', 'sell'),
#  ('sell', 'neural'),
#  ('neural', 'plug'),
#  ('plug', 'stimsims'),
#  ('stimsims', 'Douglas'),
#  ('Douglas', 'Rushkoffs'),
#  ('Rushkoffs', 'Frontline'),
#  ('Frontline', 'documentary'),
#  ('documentary', 'The'),
#  ('The', 'Merchants'),
#  ('Merchants', 'Cool'),
#  ('Cool', 'rebroadcast'),
#  ('rebroadcast', 'tonight'),
#  ('tonight', 'PBS'),
#  ('PBS', 'check'),
#  ('check', 'local'),
#  ('local', 'listing'),
#  ('listing', 'Set'),
#  ('Set', 'Tivo'),
#  ('Tivo', 'VCR'),
#  ('VCR', 'watch'),
#  ('watch', 'even'),
#  ('even', 'I'),
#  ('I', 'DSLless'),
#  ('DSLless', 'day'),
#  ('day', 'I'),
#  ('I', 'suppose'),
#  ('suppose', 'compared'),
#  ('compared', 'company'),
#  ('company', 'pretty'),
#  ('pretty', 'snappy'),
#  ('snappy', 'service'),
#  ('service', 'still'),
#  ('still', 'day'),
#  ('day', 'without'),
#  ('without', 'DSL'),
#  ('DSL', 'FEED'),
#  ('FEED', 'gave'),
#  ('gave', 'official'),
#  ('official', 'word'),
#  ('word', 'today'),
#  ('today', 'sutting'),
#  ('sutting', 'least'),
#  ('least', 'foreseeable'),
#  ('foreseeable', 'future'),
#  ('future', 'The'),
#  ('The', 'go'),
#  ('go', 'Suck'),
#  ('Suck', 'although'),
#  ('although', 'look'),
#  ('look', 'like'),
#  ('like', 'Plastic'),
#  ('Plastic', 'continuing'),
#  ('continuing', 'Both'),
#  ('Both', 'FEED'),
#  ('FEED', 'Suck'),
#  ('Suck', 'online'),
#  ('online', 'six'),
#  ('six', 'year'),
#  ('year', 'excellent'),
#  ('excellent', 'throughout'),
#  ('throughout', 'Hopefully'),
#  ('Hopefully', 'pull'),
#  ('pull', 'funk'),
#  ('funk', 'come'),
#  ('come', 'back'),
#  ('back', 'one'),
#  ('one', 'form'),
#  ('form', 'another'),
#  ('another', 'month'),
#  ('month', 'Jason'),
#  ('Jason', 'Kottke'),
#  ('Kottke', 'ha'),
#  ('ha', 'great'),
#  ('great', 'picture'),
#  ('picture', 'Louvre'),
#  ('Louvre', 'today'),
#  ('today', 'Great'),
#  ('Great', 'roadtrip'),
#  ('roadtrip', 'article'),
#  ('article', 'Mark'),
#  ('Mark', 'Frauenfelder'),
#  ('Frauenfelder', 'One'),
#  ('One', 'magazine'),
#  ('magazine', 'A'),
#  ('A', 'halfcentury'),
#  ('halfcentury', 'ago'),
#  ...]

# %% [markdown]
# #### bi-gram distribution counts

# %%
#compute frequency distribution for all the bigrams in the text
fdist = FreqDist(bigram)
bigram_df = pd.DataFrame(list(fdist.items()), columns = ["Bigrams","Frequency"])
bigram_df = bigram_df.sort_values('Frequency', ascending=False)
bigram_df
# Out:
#                                   Bigrams  Frequency
# 874                      (Cory, Doctorow)          8
# 459                          (new, issue)          8
# 668                              (I, got)          8
# 460                     (issue, Mindjack)          7
# 316                               (I, wa)          7
# 458                            (The, new)          6
# 450                          (look, like)          6
# 141                        (Justin, Hall)          6
# 2477                      (new, Mindjack)          6
# 2059                       (Daily, Relay)          6
# 88                            (ha, great)          5
# 731                     (William, Gibson)          5
# 28                    (Douglas, Rushkoff)          5
# 1442                      (Now, Mindjack)          5
# 283                            (I, think)          4
# 1103                     (Mindjack, back)          4
# 914                              (day, I)          4
# 1320                             (I, get)          4
# 1162                       (Words, Words)          4
# 1784                     (Matt, Hinrichs)          3
# 134                         (video, game)          3
# 3027                    (adventure, game)          3
# 2825                      (Warren, Ellis)          3
# 3491                          (I, review)          3
# 67                            (New, York)          3
# 1445                    (Cory, Doctorows)          3
# 97                        (one, favorite)          3
# 115                          (I, started)          3
# 2491                     (conference, wa)          3
# 1291                      (I, discovered)          3
# ...                                   ...        ...
# 1458                      (skip, reading)          1
# 1457                          (You, skip)          1
# 1427                  (ADDRESS, RONGSHAN)          1
# 1428                     (RONGSHAN, ROAD)          1
# 1429                       (ROAD, LINGUI)          1
# 1430                     (LINGUI, GUILIN)          1
# 1431                      (GUILIN, GUANG)          1
# 1432                       (GUANG, CHINA)          1
# 1433                         (CHINA, TEL)          1
# 1434                           (TEL, FAX)          1
# 1435                         (FAX, EMAIL)          1
# 1436                     (EMAIL, chunpai)          1
# 1437           (chunpai, publicglpttgxcn)          1
# 1438               (publicglpttgxcn, WEB)          1
# 1439                          (WEB, SITE)          1
# 1440                         (SITE, http)          1
# 1441  (wwwchunpaicomfirstenglishhtm, Now)          1
# 1443                  (Mindjack, excerpt)          1
# 1446         (Doctorows, novelinprogress)          1
# 1447           (novelinprogress, Eastern)          1
# 1448                  (Eastern, Standard)          1
# 1449                    (Standard, Tribe)          1
# 1450                       (Tribe, Corys)          1
# 1451                        (Corys, also)          1
# 1452                       (also, taking)          1
# 1453                       (taking, part)          1
# 1454                   (part, discussion)          1
# 1455                (discussion, Synapse)          1
# 1456                       (Synapse, You)          1
# 4208                     (blog, Mindjack)          1
#
# [4209 rows x 2 columns]

# %% [markdown]
# #### bi-gram probability

# %%
# we calculate conditional frequency
conditional_freq = ConditionalFreqDist(bigrams(tokens))
# calculate conditional probability with MLE
conditional_prob = ConditionalProbDist(conditional_freq, MLEProbDist)
df = pd.DataFrame(columns = ['Term', 'HighestProbWord', 'Probability'])

# %%
keys = []
prob_max = []
prob_value = []
samples = []

for k, v in conditional_prob.items():
    keys.append(k) 
    prob_max.append(v.max())
    prob_value.append(v.prob(v.max()))
    samples.append(v.samples())

# %%
df['Term'] = keys
df['HighestProbWord'] = prob_max
df['Probability'] = prob_value
df['Samples'] = samples
df.head()
# Out:
#           Term HighestProbWord  Probability  \
# 0     Slashdot          effect     0.500000
# 1        raise             lot     1.000000
# 2          lot              of     0.500000
# 3           of             the     0.164103
# 4  interesting         thought     0.200000
#
#                                              Samples
# 0                            (raise, effect, launch)
# 1                                              (lot)
# 2                                  (of, about, more)
# 3  (interesting, Cool, my, all, video, time, war,...
# 4                 (thought, stuff, Four, vibe, that)

# %% [markdown]
# Now we can see here the most likely word to be generated, but based on the conditional frequency, any of our sample terms could be generated given the Term column

# %% [markdown]
# ### Generating text
#
# >We supply the initial terminology and then our model will start making predictions based on the chosen sample word.
# It will continue to chain these words for as long as we set them to generate. For example, we can see raise only is paired with lot, so if we set our initial word
# to raise we will always start with lot, but lot will pick 1 of it's three samples, and then that sample will choose from it's sample, and so on

# %%
# example showing that every six words lot will be generated from setting the word to raise
for show_me_lot_first in range(4):
    # set first term
    word = "raise"
    # generate six words from initial term
    for generate_word in range(6):
        word = conditional_prob[word].generate()
        print(word, end=" ",)
    
    print('\n')
# Out:
# lot of time in Synapse is
#
# lot of I interview Warren Ellis
#
# lot about the most amazing thing
#
# lot of connectivity community wireless equivalent

# %%
# now let's see a much more chaotic ngram example with a high variance sample
for high_variance_term in range(10):
    # set first term
    word = "of"
    # generate six words from initial term
    for generate_words in range(6):
        word = conditional_prob[word].generate()
        print(word, end=" ",)
    
    print('\n')
# Out:
# your Tivo or no patience for
#
# an excellent Its not pay you
#
# Lemon is now online we were
#
# Feed Suck and start writing more
#
# my own PC My money ourselves
#
# work that have started a the
#
# Words arrived in the absence of
#
# America by Bill Vol reviewed by
#
# their support and What It work
#
# the state and depth of Cool

# %% [markdown]
# Wew. That's a hot mess. As word variance increases this model falls apart hardcore.
# Pass one is complete. Was a very hard week, and much to learn.
#
#     Next time I need to start tagging all the parts of speech, use those tags to serve as probalistic sentence structure for synthesis of more
#     realistc sentences.
#     We need to handle more than a single document, pass one was purely to see if my idea was feasible, now that it's "working" i can scale it out.
#     Also, another way to handle the high variance is to increase the n-gram length, so that we have more human like thought than simple two word
#     pairs.
# Me caveman. Like NLP. : )

# %% [markdown]
# #### Try again with tokenized sentences

# %%
import re
# remove numberic values and weird double commas
processed_text_strip = re.sub('[0-9]+', '', processed_text)
processed_text_strip = processed_text_strip.replace(',,', '')

processed_text_strip
# Out:
# ' Slashdot raises lots of interesting thoughts about banner ads . The idea is to let users control the ad delivery, and even to allow users to comment on ads.  The Merchants of Cool , a Frontline documentary featuring Mindjack advisory board member Douglas Rushkoff, is on PBS tonight. Check your local listings for the time.  ATMs dispensing music? I do not quite see the logic in that. I am not entirely against paying a nominal fee for music, or any other media, but if I do have to pay for it Id be much more likely to buy stuff from my own PC.  My chair started squeaking a few days ago and its driving me nuts!  The New York Press has a lenghty article about the post dotcom crash scene that is worth reading.  Francis Collins  Most Surprising Things About the Human Genome .  FILMSPEED has great movies you can download for free. The Third Man, in particular, is one of my favorite films of all time.  For sale: An STB nVidia ZX MB D Accelerator (AGP) and a X NEC CD-ROM drive. Interesting trades considered.  I have started uploading stuff to my live.com radio station. there is not much there yet but you are welcome to listen . (cable/dsl or higher required)  FEEDs latest special issue is an excellent examination of video games , with contributions from Carl Steadman, Steven Johnson, Justin Hall and others. do not miss it.  New DVD! The Maltese Falcon .  I once had a personal homepage, long before weblogs came into fashion, but never managed to update more than a couple of times a year. Heres hoping I will be a bit more successful with this. Big thanks to Bopjet for hosting this and Mindjack .  The Register reports on "war driving" - the wireless equivalent of war dialing. Instead of having your modem dial into thousands of networks until you get in, you just drive within range of a wireless net with your wireless-equipped laptop and hack away. related: The latest issue of CIO has a great feature on wireless.  Short documentary on digital filmmaking and Star Wars Episode II.  Rumour has it that the parent companies of Inside.com and Brills Content will be announcing a merger as early as next Monday. Apparently the two print magazines would fold into one called Brills Inside Content and the two websites would form Media Central Inside.com . Rolls right off the tongue, does not it?  Destroy All Monsters - Survivor: Monster Island . My moneys on Mothra.  I just spent some time playing with the beta version of Atmosphere , Adobes new D environment software, and thought Id give a couple of quick impressions. I have always been interested in VR and spent quite a bit of time working in VRML, but I think the inherant problem with VRML was that not enough attention had been given to community. You could build all these really cool places but people could not interact in them. You also could not easily move from one D environment to another without going back and forth between D web pages. I was involved with a project that tried to solve some of these problems with VRML (anybody remember Terra Vista?) but it did not as far as we would have liked. Atmosphere appears to have addressed these problems. Its not the first product to do so, but maybe Adobe has enough muscle for it to gain wide acceptance.  Thanks to Onebox.com I should now be able to receive faxes. Not suprisingly, they do not have local phone numbers for Fredericton so I chose a New York City area code. If anyone wants to give it a whirl, my number is: () - x.  Well, I was supposed to be working. But, through a long trail of procrastination, I ended up redesigning this site.  Quotable Mindjack! From Mike Sugarbakers review of Lemon : "If you have no patience for the lengthy ruminations of brilliant madmen, Lemon is not for you. But you read Mindjack, so you are probably into that sort of thing, right?"  Mindjack is featured in the links section of this months Netlife magazine . It does not seem to be online yet so heres a scan:  Well, the big Yahoo news yesterday was that Tim Koogle ...

# %%
sent_tokens = sent_tokenize(processed_text_strip)
sent_tokens
# Out:
# [' Slashdot raises lots of interesting thoughts about banner ads .',
#  'The idea is to let users control the ad delivery, and even to allow users to comment on ads.',
#  'The Merchants of Cool , a Frontline documentary featuring Mindjack advisory board member Douglas Rushkoff, is on PBS tonight.',
#  'Check your local listings for the time.',
#  'ATMs dispensing music?',
#  'I do not quite see the logic in that.',
#  'I am not entirely against paying a nominal fee for music, or any other media, but if I do have to pay for it Id be much more likely to buy stuff from my own PC.',
#  'My chair started squeaking a few days ago and its driving me nuts!',
#  'The New York Press has a lenghty article about the post dotcom crash scene that is worth reading.',
#  'Francis Collins  Most Surprising Things About the Human Genome .',
#  'FILMSPEED has great movies you can download for free.',
#  'The Third Man, in particular, is one of my favorite films of all time.',
#  'For sale: An STB nVidia ZX MB D Accelerator (AGP) and a X NEC CD-ROM drive.',
#  'Interesting trades considered.',
#  'I have started uploading stuff to my live.com radio station.',
#  'there is not much there yet but you are welcome to listen .',
#  '(cable/dsl or higher required)  FEEDs latest special issue is an excellent examination of video games , with contributions from Carl Steadman, Steven Johnson, Justin Hall and others.',
#  'do not miss it.',
#  'New DVD!',
#  'The Maltese Falcon .',
#  'I once had a personal homepage, long before weblogs came into fashion, but never managed to update more than a couple of times a year.',
#  'Heres hoping I will be a bit more successful with this.',
#  'Big thanks to Bopjet for hosting this and Mindjack .',
#  'The Register reports on "war driving" - the wireless equivalent of war dialing.',
#  'Instead of having your modem dial into thousands of networks until you get in, you just drive within range of a wireless net with your wireless-equipped laptop and hack away.',
#  'related: The latest issue of CIO has a great feature on wireless.',
#  'Short documentary on digital filmmaking and Star Wars Episode II.',
#  'Rumour has it that the parent companies of Inside.com and Brills Content will be announcing a merger as early as next Monday.',
#  'Apparently the two print magazines would fold into one called Brills Inside Content and the two websites would form Media Central Inside.com .',
#  'Rolls right off the tongue, does not it?',
#  'Destroy All Monsters - Survivor: Monster Island .',
#  'My moneys on Mothra.',
#  'I just spent some time playing with the beta version of Atmosphere , Adobes new D environment software, and thought Id give a couple of quick impressions.',
#  'I have always been interested in VR and spent quite a bit of time working in VRML, but I think the inherant problem with VRML was that not enough attention had been given to community.',
#  'You could build all these really cool places but people could not interact in them.',
#  'You also could not easily move from one D environment to another without going back and forth between D web pages.',
#  'I was involved with a project that tried to solve some of these problems with VRML (anybody remember Terra Vista?)',
#  'but it did not as far as we would have liked.',
#  'Atmosphere appears to have addressed these problems.',
#  'Its not the first product to do so, but maybe Adobe has enough muscle for it to gain wide acceptance.',
#  'Thanks to Onebox.com I should now be able to receive faxes.',
#  'Not suprisingly, they do not have local phone numbers for Fredericton so I chose a New York City area code.',
#  'If anyone wants to give it a whirl, my number is: () - x.',
#  'Well, I was supposed to be working.',
#  'But, through a long trail of procrastination, I ended up redesigning this site.',
#  'Quotable Mindjack!',
#  'From Mike Sugarbakers review of Lemon : "If you have no patience for the lengthy ruminations of brilliant madmen, Lemon is not for you.',
#  'But you read Mindjack, so you are probably into that sort of thing, right?"',
#  'Mindjack is featured in the links section of this months Netlife magazine .',
#  'It does not seem to be online yet so heres a scan:  Well, the big Yahoo news yesterday was that Tim Koogle is stepping down as CEO and that they will miss forecasts in the first quarter.',
#  'Today the stock tumbled .',
#  'The Times reports that the Trogan Room Coffee Machine webcam is going offline for good later this year.',
#  'That pot should go in a museum.',
#  'It looks like there is some big news due from Yahoo later today.',
#  'The new issue of Mindjack Magazine is now online, featuring a first for us - a live concert review.',
#  'With original photos even.',
#  'Its not good when a box of Sinutab describes your day.',
#  'Sinus pain, headache, congestion, itchy, watery eyes.',
#  'Ugh.',
#  'The End of Free - chronicling the demise of free stuff on the net.',
#  'I am not sure I like the direction FEED just turned .',
#  '"The filter", a new weblog linking to outside content is now featured more prominently than FEEDs original content.',
#  'Its also not clear what the difference is between the filter and Plastic .',
#  'Hey now.',
#  'Jon Lebkowsky has started a blog.',
#  'Coolness and wisdom is to be found within.',
#  'What looks like the new PalmOS PDA from TRG looks mighty impressive.',
#  'The official launch is rumored to be on Monday.',
#  'If its priced reasonably enough it might get me to upgrade from my k PalmPilot Personal.',
#  'Stick figure fighting action like you have never seen before.',
#  'Evan Williams of Blogger has more on How the Trellix Deal Happened -- and What It Means .',
#  'Need a logo ?',
#  'be a website ?',
#  'Email me .',
#  'I will work for toys .',
#  'It was just announced that Trellix is licensing Pyras Blogger technology , giving Pyra a much needed cash infusion.',
#  'Dan Bricklin has a fascinating account of how the deal happened on his site.',
#  'I recently got the  Monkeys DVD , which is excellent.',
#  'Its worth picking up just for the included feature-length documentary, The Hamster Factor and Other Tales of Twelve Monkeys , about the making of the film.',
#  'Redesigned again.',
#  'Inside.com reports that Economist business editor Chris Anderson has been named editor of Wired, replacing Katrina Heron.',
#  'The new issue of Digital Web Magazine is out today.',
#  'Lots of interesting stuff.',
#  'This is one of the reasons I am a vegetarian.',
#  '(washingtonpost.com)  Justins back from Japan with stories and pictures.',
#  'Something screwys going on with my computer.',
#  'Things are crashing, my mouse is stuttering, MPs are skipping when they did not before, and sometimes it just slows to a crawl.',
#  'I have got a nagging feeling that I am going to have to do a complete format and reinstall Windows but I really do not want to do that.',
#  'Mikel.org pointed me to this rumor that Automatic Media is in trouble .',
#  'Automatic is the company that consists of Feed, Suck and Plastic.',
#  'Hopefully it is just a rumour.',
#  'Home of the Underdogs is an amazing resource for anyone that loves computer games.',
#  'Not only do they have hundreds of games you can download which are no longer available from the companies, they also have a wealth of information about many of the games.',
#  'Its not entirely legal, but I think its a great public service.',
#  'Its even better now that they have one of my favorite games, Gabriel Knight .',
#  'there is a great article by William Gibson in the The Observers Special Japan Issue .',
#  'We reinvented culture the way we wanted it - with great big shoes .',
#  'David Bowie writes about glam in todays Guardian.',
#  'Its been a while since I played around with customizing My Yahoo!',
#  'so I do not know how new this is, but you can now use themes in additoin to plain colors.',
#  'Streaming video from the Reboot conference , featuring Justin Hall, Dave Winer, Evan Williams, Douglas Rushkoff and others.',
#  'it will make ya think.',
#  'Mindjack is now in deep development mode and, through the magic of blogs, you can follow the action as it happens .',
#  'Shift is back with a design that looks vaguely familar .',
#  'It looks good but those javascript scroll boxes are slooooow.',
#  'If I had heard Doves Lost Souls album last year, I would have included on my best of  list .',
#  'Hawksley Workmans (Last Night We Were) The Delicious Wolves will probably be on this years list.',
#  'CNET has video of Steve Jobs tour of Apples new retail stores.',
#  'are not It Cool News has some great clips and pictures from the new Coen Brothers film, The Man Who Was Not There.',
#  'I am excited.',
#  'Yet another redesign.',
#  'I think I will stick with this one for a while.',
#  'Sure, its advertising.',
#  'But its damn good advertising.',
#  'DSL!',
#  'Feed has a great interview with Cory Doctorow today.',
#  'The overlap between Doctorows day job at OpenCola and his night job writing fiction makes for a unique combination: Its almost like William Gibson launching a company that sells neural plugs and stim-sims.',
#  'Douglas Rushkoffs Frontline documentary, The Merchants of Cool is being rebroadcast tonight on PBS (check your local listings).',
#  'Set your Tivo or VCR, or watch it as its on even.',
#  'I am DSLless for  days.',
#  'I suppose compared to most other companies that is pretty snappy service, but its still  days without DSL.',
#  'FEED gave the official word today that they are sutting down, at least for the foreseeable future.',
#  'The same goes for Suck , although it looks like Plastic will be continuing for now.',
#  'Both FEED and Suck have been online for six years, and have been excellent throughout.',
#  'Hopefully they can pull out this funk and come back in one form or another in a few months.',
#  'Jason Kottke has some great pictures from the Louvre today.',
#  'Great roadtrip article by Mark Frauenfelder in One magazine.',
#  '"A half-century ago, the streets of Southern California were filled with flamboyant towers of consumerism -- spires and obelisks and beacons -- transmitting neon-fortified messages of optimism to families riding in cars with space-age tailfins.',
#  'Life was good, and the marvels of modern science were making a world as new as tomorrow."',
#  'Bill Frisells latest album Blues Dream arrived in the mail today and it only confirmed what I suspected.',
#  'I have got to get more Frisell.',
#  'blogdex is a spider that crawls blogs and generates a list of the most linked to sites.',
#  'Ten bucks says blogdex itself is number one by tomorrow.',
#  'living dangerously I have not hotsynced my PalmPilot in a couple of months.',
#  'How long can it go before craping out?',
#  'Stay tuned.',
#  'This years Webzine conference in NYC looks like it went over well.',
#  'We have coverage in the current issue of Mindjack .',
#  'Looking for some summer reading?',
#  'Canadian Media Theorists: Canadian Media Resources .',
#  'found via mikel.org  I have been reading Boing Boing since before it was a weblog but I just noticed the links to Mark and Corys garage and flea market finds today.',
#  'Man.',
#  'I uninstalled McAfee Viruscan and my computer seems twice as fast.',
#  'Now, to find a virus scanner with less of a memory appetite.',
#  'Mindjack is back and there is more to come.',
#  'They do not make keyboards like this anymore.',
#  'This is the Underwood Portable I mentioned the other day.',
#  'StarOffice  looks like it will be a big improvement over the current version.',
#  'I have been using StarOffice as an alternative to PowerPoint, but the sluggishness mentioned in this article has stopped me from using it regularly for much else.',
#  'Synapse is now offiicially open.',
#  'Come and stop by.',
#  'Synapse is live!',
#  'Almost.',
#  'It will publicly launch late tonight, but were looking to get some conversations going before that.',
#  'If you would like to help out go to synapse.mindjack.com and join now.',
#  'My copy of Words!',
#  'Words!',
#  'Words!',
#  'arrived the other day.',
#  'It is good.',
#  'I seem to have unintentionally started a typewriter collection.',
#  'I was given an Underwood Portable Typewriter in near perfect condition yesterday.',
#  'More cool stuff.',
#  'I picked up this Egyptian painting on papyrus at an estate auction the other day.',
#  'Its actually in better condition than this picture makes it look.',
#  'Heres an image I found of it online.',
#  'we have finally set a definite launch date for Synapse, Mindjacks long in development online community.',
#  'Monday, next week.',
#  'Stay tuned.',
#  'it will be good.',
#  'APOD:   - The Lagoon Nebula in Three Colors .',
#  'My new wallpaper.',
#  'I went to Atlantic Canadas largest flea market in Sussex, New Brunswick yesterday and got a sun burn and this: For  bucks.',
#  'According to this site its a  model.',
#  'It works great apart from a few sticking keys.',
#  'Now to find some ribbon for it.',
#  'Staples was selling Kensington Videocams for $cdn yesterday.',
#  'The result?',
#  'This are not a webcam.',
#  'Reload if you want to, but it are not changin.',
#  'Holy shit.',
#  'According to Advertising Age, the Industry Standard is ceasing publication .',
#  'blogBuddy looks useful.',
#  'Its a Windows-based Blogger interface.- via Evhead  Via Doc Searls Weblog I discovered a great weblog all about .b .',
#  'The Village Voice: Features: High Speed, Freed by Peter Meyers - Good article on .b wireless networks in NYC.',
#  'New!',
#  'In the mini-blog over there you can take a peek at some of my recent media consumption.',
#  'Even better, if you buy it too I will get $$.',
#  'Which may be some added incentive for me to keep this thing updated.',
#  'Todays DaveNet is a great explanation of Blogger API and what it means.',
#  'My copy of Words!',
#  'Words!',
#  'Words!',
#  'Magazine is on its way to me from New Zealand.',
#  'Is yours?',
#  'todays best spam DEAR SIR / MADAM : HOW DO YOU DO !',
#  'WE CAN SUPPLY HIGH QUALITY FLYING SHOES, SUCH FLYING SHOES LET YOU BOTH CAN WALK NORMALLY, AND CAN SLIDE AS FLYING.',
#  'IT IS A SORT OF FASHIONABLE PRODUCT.',
#  'THE FOB PRICE IS USD .',
#  'PER PAIR, WELCOME ORDER !',
#  'PLEASE LOOK THE DETAILS WITH PHOTOS FROM : http://www.chunpai.com/flyingshoe.htm ALSO WE HAVE WOOD SHOES, BAMOO MATS, WOOD FLOORING, ALUMINU PLASTIC DECORATE PANELS, ETC, LOOK THEM FROM : http://www.chunpai.com/first-english.htm BEST REGARDS !',
#  'MR.TAN LONG ( SATRAP ) GUILIN LINGUI SHENGPING XIAOXUE BAMBOO & WOOD MANUFACTORY ADDRESS: No.',
#  'RONGSHAN ROAD,LINGUI,GUILIN,GUANG,CHINA TEL / FAX: +-- E-MAIL: chunpai@public.glptt.gx.cn WEB SITE: http://www.chunpai.com/first-english.htm  Now in Mindjack is an excerpt from Cory Doctorows novel-in-progress, Eastern Standard Tribe.',
#  'Corys also taking part in a discussion in Synapse .',
#  'You skip reading a few issues of Wired and you miss something really great: My Own Private Tokyo by William Gibson  Coltrane at : the Man and the Myths - New York Times  Photgraphicas been down for a while , but in its absence I have discovered two other great photologs (when they started being called that I am not sure).',
#  'PixelPile and Common Threads .',
#  'Now, if only I had a digital camera.',
#  'It Came From British Columbia!',
#  'Great space art made with found objects.',
#  '- via robots.net  Mindjacks been slashdotted .',
#  'And BoingBoinged .',
#  'prolific has David Bowies excellent cover of America by Paul Simon in real audio.',
#  'Novemember is National Novel Writing Month .',
#  'The goal is to write a  page, , word novel by th.',
#  'I think I might start by trying to write a short story in a month.',
#  'A great gallery of low-res pictures taken with a PenCam.',
#  'Not to mention a very cool interface.',
#  'via boingboing  Thanks to the very cool BlogBack , comments are back.',
#  'Odyssey made it .',
#  'Yes, I am a space geek.',
#  'Watch as Odyssey enters Mars orbit .',
#  'Cross your fingers.',
#  'Mindjack is looking for writers, preferably ones that can commit to writing at least one article per month.',
#  'We cannot pay anything right now, but I can promise that well pay you as soon as we make any money ourselves.',
#  'If you are interested, drop me an email: editor@mindjack.com .',
#  'Include a few samples of your writing if you can, and I will get back to you real soon.',
#  'Feel free to pass this along to anyone you think might be interested.',
#  'Special features on the new Monty Python and the Holy Grail DVD : • Region  encoding (US and Canada only) • Color, Closed-captioned, Widescreen • Commentary by Terry Gilliam & Terry Jones, plus general complaints and back-biting by John Cleese, Eric Idle & Michael Palin • Theatrical trailer(s) • High definition widescreen presentation with pink frilly edges • Subtitles for People Who do not Like the Film (taken from Shakespeares Henry IV, part II) On-Screen Screenplay: read the screenplay while you watch the film • Exciting "Follow The Killer Rabbit" Feature!',
#  '• A special version for the Hard of Hearing • A glorious extra  seconds absolutely free • Three Mindless Sing-Alongs • Join Michael Palin and Terry Jones in their special documentary: The Quest for the Holy Grail Locations • How To Use Your Coconuts (an educational film) • Monty Python and the Holy Grail In Lego • "On Location with The Pythons".',
#  'Genuine  min.',
#  'location report made in  by BBC Film Night.',
#  '(broadcast , ) • An Interactive Cast Directory - discover just how many roles Michael Palin plays • Tons of Terry Gilliams original sketches plus posters • Behind-the-Scenes Photos - hitherto unseen by human eyes • A Load of Old Rubbish - a surprise package of mystery items specially included for the mentally challenged • How the directors recce used up the budget • Widescreen letterbox format I cannot wait.',
#  'Cory Doctorow has started recording audio versions of all his stories , starting with To Market, to Market, The Branding of Billy Bailey , which I am downloading now.',
#  'Where do you find the time, man?',
#  'Matt Hinrichs (a.k.a scrubbles ) has done some great illustrations for Synapse .',
#  'Join now to see them all.',
#  'Redesigned.',
#  'Again.',
#  'Crap.',
#  'I ordered the new Citizen Kane DVD from one place the other day, and today found it ten bucks cheaper somewhere else .',
#  'The Infinite Matrix is back.',
#  'Whoohoo!',
#  'Now in Mindjack: Marketing The X , an examination of Microsofts marketing of the Xbox and Windows XP, and the first of hopefully many articles by Jane umami tsunami Pinckard.',
#  'Justins site is turning into a wonderful resource on all things cool and Japanese.',
#  'I have got to start writing more.',
#  'Anybody want to pay me to do it?',
#  'I watched No Maps For These Territories the other night, a great documentary that director Mark Neale was kind enough to send me (running a magazine has its perks).',
#  'The whole thing consists of William Gibson sitting in the back of a limo musing on everything from cyberspace to religion.',
#  'I will be doing a full review in Mindjack within the next couple of weeks.',
#  'Heres what the Slashdot effect looks like.',
#  'New Mindjack today.',
#  'Twenty Twenty : Astronomical Vision by Chris McKinstry "Very early on a cold morning in  I looked with one of my highly astigmatic eyes through my first professional telescope at a setting Jupiter.',
#  'Even with my flawed vision, the long white metal tube so finely manufactured it could have been a piece of sophisticated medical equipment, let the cloud bands of our solar system’s largest planet and the bright points of a handful of its moons into my mind, making me feel a shadow of the shock that Galileo must have felt when he saw the same sight before any of us. "',
#  'I redesigned Mindjack a bit.',
#  'It should load quite a bit faster now, and look better at lower resolutions.',
#  'New this week, Design for Community reviewed by David Brake.',
#  'Next week, an interview with Derek Powazek.',
#  'The new Infinite Matrix is up with a long excerpt of Cory Doctorows new novel, Down And Out In The Magic Kingdom .',
#  'The Liberty Square ad-hocs were the staunchest conservatives in the Magic Kingdom, preserving the wheezing technology in the face of a Park that changed almost daily.',
#  'The newcomer/old-timers were on-side with the rest of the Park, had their support, and looked like they might make a successful go of it.',
#  'I am the top left corner on Cory Doctorows Four blogs on one page , which is one excuse why I have not been posting to this blog very much lately.',
#  'I will try to give myself a kick in the pants over the x-mas break and get this thing going again.',
#  'Wonderful gallery of Atari concept illustrations.',
#  'via BoingBoing  I redesigned the Mindjack front page a bit to include the entire Daily Relay blog , rather than just excerpts.',
#  'denizen is a new weblog about classic gaming from the creator of Home of the Underdogs .',
#  'Now in Mindjack, a review of the Xircom Wireless LAN Module for Palm m handhelds.',
#  'A subject that only Cory Doctorow could make this interesting.',
#  'Four or five years ago, I had a sea-change in my computing experience.',
#  'One day, I realized that I had started to view any computer not connected to the Internet as just a fancy game-console-cum-jumped-up-typewriter.',
#  'Working on an airplane or from a café just felt wrong.',
#  'This feeling deepened and magnified a thousandfold the day I got my first iBook and Airport Base Station.',
#  'If you have used wireless networking on a laptop, you know what I am talking about -- snatching the Internet out of the very air is an experience you will not go back from willingly (another one is TiVo -- I have stopped watching TV in hotel rooms because I cannot choose among thirty hours of custom-recorded programming and skip commercials).',
#  'Just as TiVo ruined me for dumb TV, .',
#  'ruined me for wired networking or no networking at all.',
#  'And it keeps on getting better.',
#  '.',
#  'is not just a technology, its a movement, an ad-hoc world of open base-stations around the world.',
#  'Just haul out your .-equipped device and start hunting about for a network.',
#  'If you are in a major city, chances are you will find one before you go a block.',
#  'Forget G and Blackberry and all those other pale imitations of connectivity: community wireless is the real shit: fast, unmetered, insecure and out of control.',
#  'Mindjack T-shirts are now available .',
#  'These are high-quality, genuine screenprinted shirts, not the Cafe Press stuff.',
#  'Thanks Brunetto !',
#  'If you are looking to get some shirts printed I highly recommend them.',
#  'Also available are Mindjack coffee mugs , featuring an illustration by Matt Hinrichs .',
#  'These are Cafe Press ones.',
#  'Please buy some.',
#  'Build your own robot!',
#  'CAM- – The Perpetual Humanoid Model .',
#  'I want one.',
#  'Especially if it comes with the sound effects in this video .',
#  'needs at least five more days.',
#  'I still have loads of work that was supposed to be done by now.',
#  'Well, this blog is back and oranger than ever.',
#  'Now just to get Daily Relay back up and running.',
#  'My mindjack.com email should be working now.',
#  'Let me know if you still have problems.',
#  'Crap.',
#  'All my @mindjack.com email addresses are messed up.',
#  'If you need to reach me please use donald@melanson.ca.',
#  'Whod have thought Mattel is still making classic electronic football games .',
#  'I used to think these were the most amazing things ever.',
#  'Then I got an Atari .',
#  'there is a great little Chinese grocery down the street from my apartment where I always find something I have never tried before.',
#  'Today: Iron Buddha Tea.',
#  'Its really good tea.',
#  'Try it.',
#  'Jim Lai reports on Digifest  in the new issue of Mindjack.',
#  'I did not have much in the way of expectations going in to Digifest ; pretty pictures, glitzy art/advertising pieces, and possibly some cool tech.',
#  'I was pleasantly surprised by the breadth and depth of the presentations.',
#  'Wednesday night.',
#  'Hit the media session and got to see some graphics on a really big screen.',
#  'The theme of this international digital media festival was the "-D challenge", to go beyond the third dimension.',
#  'I would deem this festival to be a success overall, as by the end of the festival it would be apparent that there was much speculation on what constitutes this fourth dimension.',
#  'Now that I have spoiled the ending and gotten that out of the way, on with the festival itself.',
#  'The original vision was for local (Toronto) participation, but it quickly expanded in scope with the arrival of international submissions.',
#  'There was a soirée before the keynote where attendees could snack on catered food and mingle.',
#  'Quite a few people were there, many of them either dressed hip or stylishly.',
#  'I almost felt that I was underdressed, but I just put on my best casual face and it was all cool.',
#  'Business cards flowed like water.',
#  'I got an iBook!',
#  'OSX sure takes some ajusting to but I am really impressed with it so far.',
#  'Neil Gaiman on whether someone should or should not be a writer: And in answer to your question, if you worry about job security as a writer, that is a very good indication that you are not a writer.',
#  'Hating writing is another good one, although I know writers who hate writing.',
#  '(They are miserable.)',
#  'In the new Mindjack: a report on SXSW Interactive by Jon Lebkowksy, with photos by Paul Bausch .',
#  'This years South by Southwest Interactive conference was lean and mean - attended mainly by the core group of edgy net whackadistas, the conference had an interesting vibe, like "Wow, glad the goddam dotcom splurge is over, let us get back to what we were doing…" And what we were doing had real depth, it was way more compelling than ecommerce or net.publishing, the kinds of projects MBAs brought to the table when they started calling the Internet an industry and creating the concept of the IPO casino.',
#  'Mindjack is back from a short break with a great article by Douglas Rushkoff: Conforming to the Machine .',
#  'If you are not reading futurefeedforward , you should be.',
#  'NEW YORK--ABC news magazine "/" reporter John Stossel, accidentally decapitated late last month while shooting a segment "debunking the myth of wind power," returns to the air Wednesday in a special interview with / anchor Barbara Walters.',
#  '"Its really an amazing story," explains Walters.',
#  '"Most people would not even survive decapitation, let alone have the guts, the determination, to keep doing their jobs.',
#  'Its a real triumph of the human spirit."',
#  'Everyones favorite Cory Doctorow, Cory Doctorow, has gotten a new gig at the EFF, which reminds me that I have not suported them nearly enough.',
#  'So, for the rest of I have decided to donate $ from each Mindjack t-shirt sold to EFF .',
#  'Daily Relay is finally back up.',
#  'Were using Blogger as an interim solution and will probably switch to Blogger Pro if I cannot get the Moveable Type problems sorted out.',
#  'This weeks Mindjack: Reading McLuhan by Melanie McBride.',
#  'If there is a message of the for dummies age its that nothing is beyond our grasp.',
#  'And our desire to believe this is reinforced by trends like usability, which privilege economy over elucidation.',
#  'No one anticipated it all better than Marshall McLuhan, who whittled big insights into sound bites in order to engage an audience beyond the lecture halls of the University of Toronto.',
#  'With the help of Tom Wolfe and others, the scholarly McLuhan became a cool media prophet.',
#  'It was, and still is, a practical strategy in anti-intellectual times.',
#  'But in the process, much of McLuhans meaning has been reduced to a one-liner.',
#  'This has as much to do with the absence of commentary on McLuhans literary, philosophical and cultural influences as it does with the way his work is taught.',
#  'The new issue of Mindjack deals with one of my favorite topics: Robots!',
#  'My submission to the Burn Baby Burn mix CD swap, with dispraportionate amounts of Bowie and Reed, of course.',
#  '(click to read tracklist)  Mindjack advisory board member Douglas Rushkoff has started a blog .',
#  'Expect good things.',
#  'Not that you would expect anything less, but the Criterion Collection website is really excellent.',
#  'Its similar the old Criterion Goes To The Movies CD-ROM, which is also worth checking out.',
#  'Although it takes some work to get it to run on any computer made in the last six or seven years.',
#  'Both are filled with great essays on some of the best moves ever.',
#  'we have got a great interview with Simon Singh , author of The Code Book , in the new issue of Mindjack.',
#  'Gadzooks, its been a long time since I last posted.',
#  'Sorry.',
#  'I interview Derek Powazek in the new Mindjack, in which he talks about online community, his book and weblogs as journalism.',
#  'Mindjack is trying out a new guerrila advertising campaign.',
#  'Feel free to use either of this ads on your weblog or website.',
#  'More to come soon.',
#  'Mindjack is back!',
#  'Now to get back to work on this site.',
#  'Mindjack interviews Warren Ellis!',
#  'So why are not you reading comics these days?',
#  'Really, it does not seem to me that there are many comics being written for me.',
#  'I want something with a little more muscle and bite than standard-issue power fantasies, whimsical romance, the autobiographies of people who never do anything and things with elves.',
#  'The Western medium has cycles, and its currently in a creative downturn.',
#  'That does not mean there is not excellent work being done.',
#  'That simply means there is not much of it.',
#  'And, on a personal level, little of it is talking to me.',
#  'Not many comics reflect the fact that I live in a multicultural society fitted with a global communications net, nor do they reflect the fact that I do not own a pair of Superman underpants.',
#  'Howard Rheingold interviewed on NPR (RealAudio link).',
#  'I still have not gotten my copy of Smart Mobs yet, but hope to soon.',
#  'Mindjacks Jim Lai checks out an art exhibit in the form of a billboard: Transmedia s  Seconds of Fame.',
#  'Now in Mindjack: Cybersecurity Nosebleed by Sarah Granger "Security is the newest over-hyped commodity in the United States.',
#  'I keep visualizing driving down highway  past billboards that read: "Big government wants big security" along with a picture of an ape beating on its chest.',
#  'Somehow as seriously as they say they are, I am not convinced."',
#  'Mindjacks back , with a proper relaunch this time after a bit of a slow start last month.',
#  'we have got a lengthy article on Lawrence Lessig by Bryan Alexander this issue, plus my review of the neat little lespion digital camera.',
#  'Spread the word!',
#  'I am kicking myself for missing the David Bowie concert on BBC Radio  today.',
#  'But at least I was able to find a couple of the songs somewhere else .',
#  'Bewlay Brothers is amazing.',
#  'In case anyones sitting on the edge of their site, rest assured the Mindjack relaunch is still on track for Monday.',
#  'Get the word out.',
#  'I cannot get enough of CBCs th anniversary specials.',
#  'I wish they would start a cable channel and show nothing but stuff from the s and s (and s and s too).',
#  'I just got Syberia and Post Mortem , two promising new adventure games from Montreal-based developer Microids .',
#  'As you might be able to judge from some of my posts here, I am a big fan of adventure games.',
#  'The traditional kind, where you can carry an enormous inventory in your pants, and explore the game at your own pace.',
#  'I have been thinking a lot about the genre lately and plan to write something about it soon, aside from reviews of the aforementioned games.',
#  'I am interested in hearing your thoughts on adventure games.',
#  'Do you think there is a place for them today?',
#  'What are your favorite games?',
#  'src="http://www.quicktopic.com//iaMjuWreTAS.js"> Comments document.write("(" + ct__iaMj + ")");  This does not bode well for me getting much work done this weekend.',
#  'The Adrenaline Vaults Best Shareware of   Justin Hall on South Korea: korea will be televised .',
#  'TVs in cabs, TVs in subways, and stacks and stacks of tiny, tiny televisions to take with you.',
#  'But I was still able to enjoy more television, this time in the Seoul subway.',
#  'Televisions up in the subways, instead of static ad bulletin boards!',
#  'This is the future!',
#  'Its fun to see and fun to watch now.',
#  'Soon it might be annoying or normal.',
#  'But this first brush with more constant televisual stimulation was definitely exciting.',
#  'Id like to comment on Movielink , the new studio-approved online movie rental service, but unfortunately this is all I am able to see:  Sign # CNN needs some sense slapped into them: its the day after an election, Republicans have taken control the Senate, Dick Gephardt is stepping down as House minority leader and right now, on Larry King, they are talking about the Winona Ryder verdict.',
#  'At least they took down the BREAKING NEWS graphic.',
#  'there is a new trailer for Steven Soderberghs Solaris up today -- one of the movies I am most looking forward this fall.',
#  'I got a copy of the great DVD release of Tarkovskys original film from The Russian Cinema Council a short while ago.',
#  'Which I hope to review for Mindjack before the new films released.',
#  'Cory Doctorow reviews Smart Mobs in the new Mindjack: Smart Mobs are the Slashdot effect applied to the meatspace zeitgeist.',
#  'A squillion like-minded souls who do not know each other and will never meet pop out of the transmetropolitan brickface and break the white-noise balance of atomic viewpoints to speak with one voice, roaring a righteous YES or an adamant NO without organizers, without leaders, without manifestoes or forethought.',
#  'Also this issue, an in-depth look at the Internet Archive by Doug Roberts.',
#  'Tucked away in one of the seediest neighborhoods of San Francisco is a roomful of over two hundred computers with a terabyte of data stored on every three.',
#  'Stairs from the street lead up an intimidating hallway that opens into a room with -foot ceilings and just-this-side of hip ductwork in the ceiling.',
#  'To the right is a storage area with a single desk, to the left are Bakers racks tightly packed with off-the-shelf HP desktop machines, each turned on its side to maximize the space.',
#  'Somewhere in all that ductwork, a fan is squeaking painfully.',
#  'Walking into this echoey, over-warm warehouse space, its easy to be underwhelmed until you realize what you are looking at: spinning away on these computers is nothing less than a copy of the Internet from  until today.',
#  'Mindjack is back after a short break.',
#  'The new issue has a report on the Supernova conference by Doug Roberts.',
#  'Supernova  was an ambitious conference and Kevin Warbach, the organizer along with pulver.com, acknowledged that from the outset when he said that he had crammed a three day conference into two days.',
#  'The conference was touted as a glimpse into the decentralized future.',
#  'Decentralized systems, as may be obvious, are systems that have no single point of control - the Internet is a perfect example.',
#  'No one entity or agency controls it, no single server provides the service, and no single point of failure will bring down the system.',
#  'Warbach sees these types of systems as the fundamental issue in computing for the next decade.',
#  'By then end of day one, however, it became clear that the conference was going to be about one thing: blogging.',
#  'I just discovered through Smartmobs.com that Clive Thompson has a blog .',
#  'Its great.',
#  'Which reminds me, I really need to update the blogroll on this site.',
#  'Doug Roberts is covering Supernova for Mindjack and blogging it live .',
#  'Sometimes Amazon.com is just plain eerie.',
#  'If you are going to be in Los Angeles on , do not miss Live from the Blogosphere , a panel discussion to be put on by Rhizome.LA and moderated by Xeni Jardin.',
#  '"Live from the Blogosphere!"',
#  'brings together six innovators in blogging: Mark Frauenfelder, Heather Havrilesky, Evan Williams, Susannah Breslin, Doc Searls, and Tony Pierce.',
#  'The panel will discuss the birth of blogging, the emergent tension between blogs and traditional journalism, innovations in blogging such as video-blogging, audio-blogging, and mobile-blogging, the shifting roles of race and gender in the Blogosphere, the state of the blog economy, and the way blogs may be reshaping contemporary media.',
#  '(cross-posted from Daily Relay )  I review a cool laptop bag today in Daily Relay .',
#  'Douglas Rushkoff meets Al Gore and is suitably impressed .',
#  'He was a much brighter, open-minded, and - if I might add - cosmic thinker than I gave him credit for, before.',
#  'I felt like he was really one of "us," if you know what I mean: the kids in college who got those wild thoughts about how everything in the world, and even beyond, is connected somehow.',
#  'And evolving.',
#  'Only Gore found this organic view of reality reflected in the Constitution of the United States, and sought to enable the extension of this Enlightenment thinking into practical reality.',
#  'New Mindjack up today!',
#  'Cory Doctorow on William Gibson .',
#  'Justin Hall on Super Monkey Ball  .',
#  'Check out this preview of Warren Ellis and Colleen Dorans new graphic novel, Orbiter .',
#  'Ah crap.',
#  'Shift magazine publishes its last issue .',
#  'Shift has pulled out from dire situations before, but this looks to be the end, which is a real shame.',
#  'they have been a consistently great magazine and an important voice in the ever-changing sphere of digital culture.',
#  'The final issue is due out in two weeks, I urge everyone to pick up a copy.',
#  'Mindjacks been slashdotted .',
#  'The Fray redesigned for the first time in over six years.',
#  'Blog coming soon.',
#  'Deepsky have posted their remix of David Bowies "I Took a Trip an a Gemini Spaceship" on their website.',
#  'Not as good as the original, but worth a listen.',
#  'RealAudio link  This post by Warren Ellis to his blog is not just cool because he linked to Mindjack: At Bruce Sterlings house in Austin, Texas, Howard Waldrop beams Cory Doctorow an mp of some swampy old rocknroll from the dawn of time.',
#  'The next day, across town, his powerbook scorching the flesh off his legs, he beams it over to me in England.',
#  'I put it up on a private server for Fraction in Kansas City and Laurenn in San Francisco, while reading the first few chapters of Corys new book, which he sent to me from an airport a few days before, squatting by the power outlet next to the public toilets.',
#  'continued...  Slashdot launches games.slashdot.org and, holy cow, its ugly.',
#  'Mindjack contributor and game reviewer, Justin Hall, has written a great article on ethics in video game journalism for the Online Journalism Review.',
#  'The first print magazine covering video games Electronic Games was co-founded by Bill Kunkel in .',
#  'Kunkel describes those early days in a recent interview: “To an extent, we were cheerleaders for the industry -- we loved these games, we wanted to see more of them, we wanted to keep writing about them.” Not much has changed in the past  years.',
#  'Game publications and Web sites still mostly employ low-paid hobbyists who are easy targets of lavish marketing events that encourage inappropriate ties between game makers and game critics.',
#  'This is incredible.',
#  'Scientists have discovered a "Colossal" squid in the Antartic, much bigger than the previous biggest giant squid found.',
#  'And its not even fully grown.',
#  'Deep sea exploration is nearly as fascinating to me as space exploration.',
#  'Just imagine that there is something like this that no one has ever seen alive.',
#  'Its interesting that the article notes the funding for the research is from the Discovery Channel.',
#  'While its great there is some funding available, just as with space exploration, there should be much more.',
#  'Googling for sites that mention Mindjack, other than mindjack.com, suprisingly results in , links.',
#  'I like the description on this one .',
#  'Mindjack Magazine.',
#  'One pusle showing the osmotic swelling of Digital culture as the norm.',
#  'New Mindjack up today.',
#  'Josh examines the online, interconnected groups of people that you turn to for advice on music, art, fashion, books, etc., and the broader implications of these taste tribes.',
#  'Also, Justin Hall reviews Panzer Dragoon Orta for Xbox.',
#  'The illustration, btw, is by Matt Hinrichs , who will hopefully be doing semi-regular ones for us.',
#  'I review Soul Calibur , Syberia, and Post Mortem in the new Mindjack.',
#  'Via scrubbles.net : a (nearly) complete index of Alfred Hitchcocks cameos .',
#  'My article, Reunderstanding Movies , about how DVDs and the Internet are changing the way we watch movies, is in the new Mindjack .',
#  'I have started a film blog: melanson.ca/movies .',
#  'No promises on how often I will post to it, but I try to do as many reviews as I can.',
#  'For your linking pleasure, a new Mindjack ad.',
#  'More sizes coming soon.',
#  'I have been blogging more at Mindjacks Daily Relay lately and hope to be able to keep it up.',
#  'we have got lots of good stuff coming up in Mindjack in the next few months, so keep your eye on the blog for further updates.',
#  'Apparently from a sidewalk in Austin.',
#  'Derek Powazeks comment over in this entry at Blackbeltjones reminded me of Amazon.coms incredibly good Friends & Favorites area.',
#  'Mr. Bezos, if you are reading this, please add this to Amazon.ca .',
#  'Canadians have friends too.',
#  'I have been playing around with Flickr lately, the latest toy from the mad geniuses at Ludicorp .',
#  'You can find my Flickr profile here .',
#  'I have also started a Mindjack group as a bit of an experiment.',
#  'If it works out I may try to integrate it into the site.',
#  'Now in Mindjack: Is Nothing Sacred?',
#  'Digital Music for a Digital Age by Ian Dawe.',
#  'Antero Allis Hysteria reviewed on DVD by Jesse Walker.',
#  '_img Originally uploaded by QuizMaster .',
#  'Posted by Don Melanson from Flickr .',
#  'The new issue of Mindjack is now online .',
#  'In this issue: Linked Out: blogging, equality and the future by Melanie McBride.',
#  'Plus Kill Bill Vol.',
#  'reviewed by Jesse Walker.',
#  'there is a new issue of Mindjack now online.',
#  'In it, the first article from Mindjacks newest contributor J.D.',
#  'Lasica; he writes about copyright law in "The Killing Fields" .',
#  'Also, I review DVDs of Breathless, Russian Ark, and Z .',
#  'Spread the word.',
#  '"An idea is a funny thing.',
#  'It does nothing unless you do."',
#  'I am looking for someone to be Advertising Director for Mindjack.',
#  'Must have advertising sales experience and be willing to work on commission.',
#  'This is a contract job that can be done from home.',
#  'If you are interested, please email: donald@mindjack.com (no attachments).',
#  'Also, were constantly looking for great new writers.',
#  'If you want to write for us, drop an email.',
#  'I am pleased to announce that VRML creator and all-around visionary Mark Pesce has joined Mindjacks ever-growing stable of writers.',
#  'His first article, Redefining Television , is an insightful examination of the state and future of the medium.',
#  'Heres a snippet: In the earliest days of television, writers like George Orwell in  and Ray Bradbury in Fahrenheit  projected television as the instrumentality of a totalitarian future - a monolithic entity dispensing propaganda.',
#  'And, if any of you occasionally watch Fox News, you can see they were not that far off the mark.',
#  'But heres the thing: the monolithic days of television are numbered.',
#  'Actually, they have already passed - though, as yet, very few people realize this.',
#  'To understand why, we need to go back to first principles.',
#  'What is television?',
#  'Heres a functional definition: Television is the capture, encoding, transmission, reception, decoding and display of moving images.',
#  'This definition applies to the Golden Age of television, and to the present era.',
#  'Yet the definition of every word in the definition of television has changed, because of the introduction of digital production, encoding, transmission, reception, decoding and display technologies.',
#  'I am using this blog to play around with Bloggers new features .',
#  'It will return to normal shortly.',
#  'I am blogging a lot more on my film blog than I am here.',
#  'If you like movies, check it out.',
#  'And, of course, I continue to write and blog at Mindjack .']

# %%
conditional_freq_sent = ConditionalFreqDist(bigrams(sent_tokens))
conditional_prob_sent = ConditionalProbDist(conditional_freq_sent, MLEProbDist)

# %%
df_sentences = pd.DataFrame(columns = ['Sentence', 'HighestProb', 'Probability'])

# %%
sent_keys = []
sent_prob_max = []
sent_prob_value = []

for k, v in conditional_prob_sent.items():
    sent_keys.append(k) 
    sent_prob_max.append(v.max())
    sent_prob_value.append(v.prob(v.max()))

# %%
df_sentences['Sentence'] = sent_keys
df_sentences['HighestProb'] = sent_prob_max
df_sentences['Probability'] = sent_prob_value
df_sentences.head()
# Out:
#                                             Sentence  \
# 0   Slashdot raises lots of interesting thoughts ...
# 1  The idea is to let users control the ad delive...
# 2  The Merchants of Cool , a Frontline documentar...
# 3            Check your local listings for the time.
# 4                             ATMs dispensing music?
#
#                                          HighestProb  Probability
# 0  The idea is to let users control the ad delive...          1.0
# 1  The Merchants of Cool , a Frontline documentar...          1.0
# 2            Check your local listings for the time.          1.0
# 3                             ATMs dispensing music?          1.0
# 4              I do not quite see the logic in that.          1.0

# %%
word = df_sentences['Sentence'][3]
for index in range(2):
    word = conditional_prob_sent[word].generate()
    print(word, '\n', end=" ")
# Out:
# ATMs dispensing music?
#  I do not quite see the logic in that.

# %% [markdown]
# Well, at least we have working sentences now. But this is misleading. The probablility of each sentence occuring with it's bigram 'friend' is exactly 1, because all the sentences are unique, so it manages to make decievingly convincing contextual information. And it will continue to string the next sentence exactly as it was written because the probablity of each generated sentence is still 1 for every new 'state' or link in the markov chain. We've created a parrot :)

# %%
word = df_sentences['Sentence'][3]
for index in range(5):
    word = conditional_prob_sent[word].generate()
    print(word, '\n', end=" ")
# Out:
# ATMs dispensing music?
#  I do not quite see the logic in that.
#  I am not entirely against paying a nominal fee for music, or any other media, but if I do have to pay for it Id be much more likely to buy stuff from my own PC.
#  My chair started squeaking a few days ago and its driving me nuts!
#  The New York Press has a lenghty article about the post dotcom crash scene that is worth reading.

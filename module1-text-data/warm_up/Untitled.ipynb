# %%
import pandas as pd

# %%
df1 = pd.read_csv('iftsgay_2018.csv')
df2 = pd.read_csv('aughtynay_roay_icenay_2018.csv')

# %%
df1.shape
# Out:
# (17, 4)

# %%
df1
# Out:
#                                                Things  Favorite?  \
# 0                            aindropsray noay osesray          1
# 1                           hiskersway noay ittenskay          1
# 2                         rightbay oppercay ettleskay          1
# 3                           armway oolenway ittensmay          1
# 4   rownbay aperpay ackagespay iedtay puay ithway ...          1
# 5                          reamcay oloredcay oniespay          1
# 6                            rispcay ppleay trudelsay          1
# 7                                         oorbellsday          1
# 8                                    leighsay ellsbay          1
# 9                        chnitzelsay ithway oodlesnay          1
# 10  ildway eesegay hattay lyfay ithway hetay oonma...          1
# 11  irlsgay niay hiteway ressesday ithway luebay a...          1
# 12  nowflakessay hattay taysay noay ymay osenay nd...          1
# ...

# %%
df2
# Out:
#           Name              Location  Behavior  Other Gifts
# 0        Lamar    51.91599, 17.05723 -0.144877            7
# 1        Chloe  -47.99358, 128.19181  0.105298            3
# 2      Delilah  -56.54483, -68.75454 -0.510874            6
# 3       Melvin  -33.05493, 163.54943 -0.154494            9
# 4    Christine   67.91621, -20.02474 -0.285024            8
# ..         ...                   ...       ...          ...
# 195        Ima   87.52603, -32.41723  0.400474            1
# 196   McKenzie   -67.08306, 54.40609 -0.027827            6
# 197      Elvis    9.83005, -47.10676  0.198350           10
# 198   Chiquita   62.0751, -125.00066 -0.681055            4
# 199       Myra   -46.20978, 18.66986 -0.527743            1
#
# [200 rows x 4 columns]

# %%
consonants = ['b','c','d','f','g','h','j','k','l','m','n','p','q','r','s','t','v','w','x','z']
df1['Naughty or Nice?'] = df1['Naughty or Nice?'].fillna('aughtynay')

# %%
def 
    if ob.endswith('ay'):
        ob = ob[-3] + ob[:-3]
    print(ob)
# Out:
# nice
# naughty
# nice
# nice
# nice
# nice
# nice
# nice
# nice
# nice
# naughty
# naughty
# nice
# nice
# naughty
# naughty
# naughty

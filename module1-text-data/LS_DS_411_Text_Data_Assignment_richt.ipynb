# %% [markdown]
# <img align="left" src="https://lever-client-logos.s3.amazonaws.com/864372b1-534c-480e-acd5-9711f850815c-1524247202159.png" width=200>
# <br></br>
# <br></br>
#
# # Natural Language Processing (NLP)
# ## *Data Science Unit 4 Sprint 1 Assignment 1*
#
# Your goal in assignment: find the attributes of the best & worst coffee shops in the dataset. The text is fairly raw: dates in the review, extra words in the `star_rating` column, etc. You'll probably want to clean that stuff up for a better analysis.
#
# Analyze the corpus of text using text visualizations of token frequency. Try cleaning the data as much as possible. Try the following techniques:
# - Lemmatization
# - Custom stopword removal
#
# Keep in mind the attributes of good tokens. Once you have a solid baseline, layer in the star rating in your visualization(s). Keep part in this assignment - produce a write-up of the attributes of the best and worst coffee shops. Based on your analysis, what makes the best the best and the worst the worst. Use graphs and numbesr from your analysis to support your conclusions. There should be plenty of markdown cells! :coffee:

# %%
# from IPython.display import YouTubeVideo

# YouTubeVideo('Jml7NVYm8cs')

# %%
# Importing and reading in the CSV
import pandas as pd

shops = pd.read_csv('./data/yelp_coffeeshop_review_data.csv')
shops.head()
# Out:
#                   coffee_shop_name  \
# 0  The Factory - Cafe With a Soul
# 1  The Factory - Cafe With a Soul
# 2  The Factory - Cafe With a Soul
# 3  The Factory - Cafe With a Soul
# 4  The Factory - Cafe With a Soul
#
#                                     full_review_text        star_rating
# 0   11/25/2016 1 check-in Love love loved the atm...   5.0 star rating
# 1   12/2/2016 Listed in Date Night: Austin, Ambia...   4.0 star rating
# 2   11/30/2016 1 check-in Listed in Brunch Spots ...   4.0 star rating
# 3   11/25/2016 Very cool decor! Good drinks Nice ...   2.0 star rating
# 4   12/3/2016 1 check-in They are located within ...   4.0 star rating

# %%
# Creating rating feature from star_rating using only numericals
shops['rating'] = shops['star_rating'].apply(lambda x: x[:4]).astype('float')
del shops['star_rating']

# %%
# Creating date feature from date stripped from full_review_text
shops['date'] = shops['full_review_text'].apply(lambda x: x.split()[0])

# %%
# Dropping date from 'full_review_text' by splitting and indexing past the date and re-joining with space
shops['full_review_text'] =  shops['full_review_text'].apply(lambda x: " ".join(x.split()[1:]))

# %%
shops['full_review_text'] = shops['full_review_text'].apply(lambda x: x.lower())

# %%
shops.head()
# Out:
#                   coffee_shop_name  \
# 0  The Factory - Cafe With a Soul
# 1  The Factory - Cafe With a Soul
# 2  The Factory - Cafe With a Soul
# 3  The Factory - Cafe With a Soul
# 4  The Factory - Cafe With a Soul
#
#                                     full_review_text  rating        date
# 0  1 check-in love love loved the atmosphere! eve...     5.0  11/25/2016
# 1  listed in date night: austin, ambiance in aust...     4.0   12/2/2016
# 2  1 check-in listed in brunch spots i loved the ...     4.0  11/30/2016
# 3  very cool decor! good drinks nice seating howe...     2.0  11/25/2016
# 4  1 check-in they are located within the northcr...     4.0   12/3/2016

# %%
# Import spacy and load the model
import spacy

nlp = spacy.load('en_core_web_lg')

# %%
def get_lemmas(text):

    lemmas = []
    
    doc = nlp(text)
    

    for token in doc: 
        if ((token.is_stop == False) and (token.is_punct == False)) and (token.pos_!= 'PRON'):
            lemmas.append(token.lemma_)
    
    return lemmas

# %%
shops['tokens'] = shops['full_review_text'].apply(get_lemmas)

# %%
shops['tokens']
# Out:
# 0       [1, check, love, love, love, atmosphere, corne...
# 1       [list, date, night, austin, ambiance, austin, ...
# 2       [1, check, list, brunch, spot, love, eclectic,...
# 3       [cool, decor, good, drink, nice, seating, over...
# 4       [1, check, locate, northcross, mall, shopping,...
# 5       [1, check, cute, cafe, think, moment, step, fi...
# 6       [2, check, in, list, nuptial, coffee, bliss, a...
# 7       [2, check, in, love, place, 5, star, cleanline...
# 8       [1, check, ok, let, try, approach, pro, music,...
# 9       [3, check, in, place, show, social, medium, da...
# 10      [1, check, list, americano, average, cute, stu...
# 11      [store, a+, decoration, honestly, coffee, good...
# 12      [1, check, list, 2016, time, charm, factory, a...
# 13      [cute, little, cafe, drive, place, time, notic...
# 14      [beautiful, eccentric, coffee, shop, library, ...
# 15      [1, check, list, search, fantastic, coffee, wa...
# 16      [love, atmosphere, frequent, coffee, shop, def...
# 17      [1, check, check, video, review, youtube.com/w...
# 18      [1, check, note, come, look, place, work, remo...
# 19      [aesthetic, place, love, corner, coffee, shop,...
# 20      [1, check, check, factory, past, sunday, husba...
# 21      [place, cute, new, favorite, coffee, spot, bur...
# 22      [try, new, cafe, spot, burnet, friend, unassum...
# 23      [greeting, atmosphere, feel, create, place, sp...
# 24      [craft, coffee, drink, tea, beer, wine, friend...
# 25      [okay, visit, friend, la, try, mint, mojito, i...
# 26      [1, check, guy, place, amazing, limited, food,...
# 27      [fantastic, atmosphere, drop, catch, work, fin...
# 28      [place, amazing, wifi, fine, mean, place, hang...
# 29      [write, yelp, review, walk, feel, like, hipste...
#                               ...
# 7586    [list, wanna, eat, north, central, austin, tea...
# 7587    [2, check, in, list, 100, yelp, review, challe...
# 7588    [6, check, in, let, start, say, introduce, sal...
# 7589    [great, restaurant, think, disservice, appear,...
# 7590    [today, try, place, austin, september, list, l...
# 7591    [good, place, eat, austin, celiac, clean, prep...
# 7592    [good, service, good, food, price, expensive, ...
# 7593    [1, check, favorite, tea, jasmine, blueberry, ...
# 7594    [1, check, favorite, tea, place, austin, vegan...
# 7595    [4, check, in, list, vegan, beast, time, frien...
# 7596    [good, experience, restaurant, jordan, waitres...
# 7597    [1, check, list, 2014, yelp, 100, challenge, h...
# 7598    [go, steep, room, today, early, lunch, employe...
# 7599    [1, check, hate, go, food, bc, lot, time, feel...
# 7600    [great, service, unimaginative, uneventful, fo...
# 7601    [1, check, great, selection, tea, purchase, ho...
# 7602    [2, check, in, week, masala, chai, fix, wait, ...
# 7603    [1, check, go, lunch, today, lauren, h., baby,...
# 7604    [complaint, wonderful, little, restaurant, tbl...
# 7605    [get, chipotle, chocolate, chai, tea, amazing,...
# 7606    [great, tea, food, domain, location, roomy, cl...
# 7607    [place, amazing, favorite, austin, spot, hit, ...
# 7608    [come, visit, friend, austin, fun, place, lot,...
# 7609    [1, check, notice, friend, come, enjoy, decide...
# 7610    [great, food, meal, enjoy, clean, great, peopl...
# 7611    [actually, step, restaurant, chance, favorite,...
# 7612    [ok, steeping, room, awesome, great, menu, ite...
# 7613    [love, come, tea, atmosphere, pretty, fresh, o...
# 7614    [food, average, booth, feel, clean, waitstaff,...
# 7615    [finally, stop, lunch, colleague, glad, delici...
# Name: tokens, Length: 7616, dtype: object

# %%
from collections import Counter
def count(docs):

        word_counts = Counter()
        appears_in = Counter()
        
        total_docs = len(docs)

        for doc in docs:
            word_counts.update(doc)
            appears_in.update(set(doc))

        temp = zip(word_counts.keys(), word_counts.values())
        
        wc = pd.DataFrame(temp, columns = ['word', 'count'])

        wc['rank'] = wc['count'].rank(method='first', ascending=False)
        total = wc['count'].sum()

        wc['pct_total'] = wc['count'].apply(lambda x: x / total)
        
        wc = wc.sort_values(by='rank')
        wc['cul_pct_total'] = wc['pct_total'].cumsum()

        t2 = zip(appears_in.keys(), appears_in.values())
        ac = pd.DataFrame(t2, columns=['word', 'appears_in'])
        wc = ac.merge(wc, on='word')

        wc['appears_in_pct'] = wc['appears_in'].apply(lambda x: x / total_docs)
        
        return wc.sort_values(by='rank')

# %%
wc = count(shops['tokens'])

# %%
wc.head()
# Out:
#        word  appears_in  count  rank  pct_total  cul_pct_total  appears_in_pct
# 2    coffee        4953  10763   1.0   0.029758       0.029758        0.650341
# 131   place        3892   6059   2.0   0.016752       0.046510        0.511029
# 154    good        3614   5437   3.0   0.015032       0.061542        0.474527
# 123   great        2860   3959   4.0   0.010946       0.072488        0.375525
# 38    check        3175   3469   5.0   0.009591       0.082079        0.416886

# %%
import squarify
import matplotlib.pyplot as plt

wc_top20 = wc[wc['rank'] <= 20]

squarify.plot(sizes=wc_top20['pct_total'], label=wc_top20['word'], alpha=.8 )
plt.axis('off')
plt.show()

# %%
import seaborn as sns
sns.distplot(shops['rating']);
# Out:
# /anaconda3/envs/U4-S1-NLP/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
wc_bad = count(shops[shops['rating'] < 4]['tokens'])

# %%
wc_top20_bad = wc_bad[wc_bad['rank'] <= 20]

squarify.plot(sizes=wc_top20_bad['pct_total'], label=wc_top20_bad['word'], alpha=.8 )
plt.axis('off')
plt.show()

# %%
wc_good = count(shops[shops['rating'] <= 4]['tokens'])

# %%
wc_top20_good = wc_good[wc_good['rank'] <= 20]

squarify.plot(sizes=wc_top20_good['pct_total'], label=wc_top20_good['word'], alpha=.8 )
plt.axis('off')
plt.show()

# %%
diff = wc_good[['word', 'appears_in_pct']].merge(wc_bad[['word', 'appears_in_pct']], on='word', how='outer', suffixes=('', '_bad'))

# %%
diff.head()
# Out:
#      word  appears_in_pct  appears_in_pct_bad
# 0  coffee        0.666840            0.644309
# 1   place        0.528154            0.512195
# 2    good        0.491919            0.439024
# 3    like        0.358968            0.403794
# 4   check        0.445777            0.331301

# %%
diff['diff'] = diff['appears_in_pct'] - diff['appears_in_pct_bad']

# %%
diff.sort_values(by='diff')
# Out:
#               word  appears_in_pct  appears_in_pct_bad      diff
# 25         service        0.175443            0.235095 -0.059652
# 69             ask        0.089416            0.149051 -0.059635
# 7            order        0.235141            0.294715 -0.059575
# 85        customer        0.073775            0.126016 -0.052241
# 96             bad        0.083420            0.133469 -0.050049
# 66          review        0.103754            0.151762 -0.048008
# 32           taste        0.143118            0.189702 -0.046584
# 3             like        0.358968            0.403794 -0.044826
# 81             say        0.082117            0.126016 -0.043899
# 20              go        0.186653            0.228320 -0.041667
# 35               $        0.106882            0.147696 -0.040814
# 111     experience        0.071689            0.110434 -0.038744
# 275           rude        0.029197            0.065718 -0.036521
# 153             ok        0.053702            0.090108 -0.036407
# 33            want        0.148592            0.184959 -0.036367
# 129         minute        0.057873            0.092818 -0.034946
# 152            pay        0.050834            0.084688 -0.033854
# 133           tell        0.059176            0.092818 -0.033642
# 119          maybe        0.071689            0.105014 -0.033324
# 228           will        0.040928            0.073171 -0.032243
# 83            take        0.090459            0.122629 -0.032170
# 9             time        0.256517            0.287940 -0.031423
# 103           well        0.084724            0.115176 -0.030452
# 56            wait        0.096715            0.124661 -0.027946
# 184       business        0.044578            0.071138 -0.026561
# 137          leave        0.058394            0.084688 -0.026294
# 28           think        0.151981            0.178184 -0.026203
# 39         barista        0.131387            0.155827 -0.024440
# 6             come        0.282325            0.306233 -0.023908
# 210           okay        0.041971            0.065041 -0.023070
# ...            ...             ...                 ...       ...
# 10850          tsr        0.000261                 NaN       NaN
# 10851         8.95        0.000261                 NaN       NaN
# 10856       monaco        0.000261                 NaN       NaN
# 10857     accolade        0.000261                 NaN       NaN
# 10858    inventive        0.000261                 NaN       NaN
# 10859       cougar        0.000261                 NaN       NaN
# 10862    superstar        0.000261                 NaN       NaN
# 10863        spelt        0.000261                 NaN       NaN
# 10864       mingle        0.000261                 NaN       NaN
# 10865       bahhhh        0.000261                 NaN       NaN
# 10866      daaaang        0.000261                 NaN       NaN
# 10868    crustless        0.000261                 NaN       NaN
# 10869        beast        0.000261                 NaN       NaN
# 10870       ridick        0.000261                 NaN       NaN
# 10871      divorce        0.000261                 NaN       NaN
# 10872     buuuuuut        0.000261                 NaN       NaN
# 10873        holla        0.000261                 NaN       NaN
# 10874        taken        0.000261                 NaN       NaN
# 10880      gravlax        0.000261                 NaN       NaN
# 10881      bangkok        0.000261                 NaN       NaN
# 10882      romaine        0.000261                 NaN       NaN
# 10883  predictably        0.000261                 NaN       NaN
# 10884     windowed        0.000261                 NaN       NaN
# 10885    irregular        0.000261                 NaN       NaN
# 10886   responsive        0.000261                 NaN       NaN
# 10887    nashville        0.000261                 NaN       NaN
# 10888    actuality        0.000261                 NaN       NaN
# 10889        crass        0.000261                 NaN       NaN
# 10890    digestion        0.000261                 NaN       NaN
# 10891     moroccan        0.000261                 NaN       NaN
#
# [10892 rows x 4 columns]

# %% [markdown]
# ## Stretch Goals
#
# * Analyze another corpus of documents - such as Indeed.com job listings ;).
# * Play the the Spacy API to
#  - Extract Named Entities
#  - Extracting 'noun chunks'
#  - Attempt Document Classification with just Spacy
#  - *Note:* This [course](https://course.spacy.io/) will be of interesting in helping you with these stretch goals.
# * Try to build a plotly dash app with your text data
